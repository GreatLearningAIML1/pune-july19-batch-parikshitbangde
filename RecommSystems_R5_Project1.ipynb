# %% [markdown]
# # Problem Statement -
#
# - Build your own recommendation system for products on an e-commerce website like Amazon.com.
#
# - Dataset Link - https://drive.google.com/file/d/1ClBptsK3V5KgKXtK2GSRzFNAW7GnTPDW/view?usp=sharing

# %% [markdown]
# # Dataset columns
# - first three columns are userId, productId, and ratings and the fourth column is timestamp. You can discard the timestamp column as in this case you may not need to use it.

# %% [markdown]
# # Source
# - Amazon Reviews data (http://jmcauley.ucsd.edu/data/amazon/)  The repository has several datasets. For this case study, we are using the Electronics dataset

# %% [markdown]
# ## Please do the analysis based on steps( 1 to 8) as given below -
#
# Steps -
#
# 1. Read and explore the given dataset.  ( Rename column/add headers, plot histograms, find data characteristics)
# 2. Take a subset of the dataset to make it less sparse/ denser. ( For example, keep the users only who has given 50 or more number of ratings )
# 3. Split the data randomly into train and test dataset. ( For example, split it in 70/30 ratio)
# 4. Build Popularity Recommender model.
# 5. Build Collaborative Filtering model.
# 6 Evaluate both the models. ( Once the model is trained on the training data, it can be used to compute the error (like RMSE) on predictions made on the test data.) You can also use a different method to evaluate the models.
# 7. Get top - K ( K = 5) recommendations. Since our goal is to recommend new products to each user based on his/her habits, we will recommend 5 new products.
# 8. Summarise your insights.

# %% [markdown]
# ### Please Note -
#
# 1. If you are facing any memory issue while working on this project, create a small subset (Let’s say 10% of data) and work on it.
# 2. If you are stuck at the model evaluation part of this project.
#
# #### Please refer to below links -
#
# 1. https://surprise.readthedocs.io/en/stable/accuracy.html (Links to an external site.)Links to an external site.
# 2. http://surpriselib.com/ (Links to an external site.)Links to an external site. - Getting started, example

# %%
# to ignore warning we can import warnings library 
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the necessary libraries 
import pandas as pd # to read the dataset 
import numpy as np  # for Mathematical opreations 
import matplotlib.pyplot as plt # For visualization 
import seaborn as sns # for visualization

# %%
# To read the dataset 
df = pd.read_csv('ratings_Electronics.csv')

# %%
# setting Collumns Header 
df.columns=['userid','productid','rating','timestamp']

# %%
# To see how our dataframe looks like 
df.head()
# Out:
#            userid   productid  rating   timestamp
# 0  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 1  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 2  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 3  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# 4  A1QGNMC6O1VW39  0511189877     5.0  1397433600

# %%
# Understanding the datatype and number entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824481 entries, 0 to 7824480
# Data columns (total 4 columns):
# userid       object
# productid    object
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 238.8+ MB

# %%
# As we dont need timestam we can drop it 
df = df.drop(['timestamp'],axis=1)

# %%
df.shape
# Out:
# (7824481, 3)

# %%
# Checking Nan values are present or not 
df.isna().sum()
# Out:
# userid       0
# productid    0
# rating       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#             count      mean      std  min  25%  50%  75%  max
# rating  7824481.0  4.012337  1.38091  1.0  3.0  5.0  5.0  5.0

# %%
# Fetting idea of unique values in our dataset 
for i  in df.columns:
    print ('Unique vlaues present in {} are : '.format(i),(df[i].nunique()))
# Out:
# Unique vlaues present in userid are :  4201696
# Unique vlaues present in productid are :  476001
# Unique vlaues present in rating are :  5

# %%
# counting frequency 
count = []
for i in df.columns:
    print ('valuse count for column {} is  ='.format(i) ,df[i].value_counts())
    count.append(df[i].value_counts().argmax())
count
# Out:
# valuse count for column userid is  = A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
#                  ...
# AQIID0OAN595Z       1
# A2CMR8WWWQDEFN      1
# A352I1QTH2AWK9      1
# A2DHF3KL71OFSB      1
# A2I1WL2P8JCESU      1
# Name: userid, Length: 4201696, dtype: int64
# valuse count for column productid is  = B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
#               ...
# B002VAK6VU        1
# B0065887HO        1
# B000A9QBPO        1
# B004K6ENL2        1
# B00D4TRO8U        1
# Name: productid, Length: 476001, dtype: int64
# valuse count for column rating is  = 5.0    4347540
# 4.0    1485781
# 1.0     901765
# 3.0     633073
# 2.0     456322
# Name: rating, dtype: int64
# ['A5JLAU2ARJ0BO', 'B0074BW614', 5.0]

# %%
# getting idea about how mean rating of the products 
df.groupby('productid')['rating'].mean().head()
# Out:
# productid
# 0321732944    5.000000
# 0439886341    1.666667
# 0511189877    4.500000
# 0528881469    2.851852
# 0558835155    3.000000
# Name: rating, dtype: float64

# %%
# getting idea about how mean rating of the products are given by users 
df.groupby('productid')['rating'].mean().value_counts().head() 
# It gives idea about how many people have taken the product and rated the product
# Out:
# 5.0    131361
# 4.0     55055
# 3.0     35119
# 1.0     27894
# 4.5     18679
# Name: rating, dtype: int64

# %%
# getting idea about how mean rating of the products are given by users and sorting the values 
df.groupby('productid')['rating'].count().sort_values(ascending=False).head()
# Out:
# productid
# B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
# Name: rating, dtype: int64

# %%
# sorting the products rating 
df.groupby('productid')['rating'].mean().sort_values(ascending=False).head()
# Out:
# productid
# BT008V9J9U    5.0
# B0058PRC0S    5.0
# B0058ORBFU    5.0
# B0058OQ9Q2    5.0
# B0058OKSMS    5.0
# Name: rating, dtype: float64

# %%
# getting an idea about count of each rating given by user 
df.groupby('rating').count()
# Out:
#          userid  productid
# rating
# 1.0      901765     901765
# 2.0      456322     456322
# 3.0      633073     633073
# 4.0     1485781    1485781
# 5.0     4347540    4347540

# %% [markdown]
# #### Observing the distribution plot of rating

# %%
# creating dataframe for plotting 
df_gp = df.groupby(by=['rating']).agg({'userid': 'count'}).reset_index()
df_gp.columns = ['Rating', 'Count']

# %%
#ploting the axis label and ploting name 
plt.barh(df_gp.Rating, df_gp.Count, color='royalblue')
plt.title('Overall Count of Ratings', fontsize=15)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Rating', fontsize=15)
plt.grid(ls='dotted')
plt.show()

# %%
# keeping users only who has given 50 or more number of ratings 
# keeing count of rating of a user in count variable 
count = df.groupby('userid')['rating'].count()

# %%
# creating new dataframe in which we have only those users who have given 50 or more then 50 product
df_50_greater=df[df['userid'].isin(count[count >= 50].index)]
df_50_greater['userid'].value_counts()# To cross check
# Out:
# A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
#                  ...
# A20ZM879PCQQEZ     50
# AY4EXFOO43C3S      50
# A2Y4H3PXB07WQI     50
# A3VZH0PWLQ9BB1     50
# A319Y83RT0MRVR     50
# Name: userid, Length: 1540, dtype: int64

# %%
print('Before removing user who had given rating 50 or more product shape is :',df.shape)
print('After removing user who have not given rating 50 or more product shape is :',df_50_greater.shape)
# Out:
# Before removing user who had given rating 50 or more product shape is : (7824481, 3)
# After removing user who have not given rating 50 or more product shape is : (125871, 3)

# %%
# observing the head of new datafram 
#ratings_mean_count= ratings_mean_count.reset_index(drop = False) # reseting the index
print (df_50_greater.shape)
df_50_greater.head()
# Out:
# (125871, 3)
#              userid   productid  rating
# 93   A3BY5KCNQZXV5U  0594451647     5.0
# 117   AT09WGFUM934H  0594481813     3.0
# 176  A32HSNCNPRUMTR  0970407998     1.0
# 177  A17HMM1M7T9PJ1  0970407998     4.0
# 491  A3CLWR1UUZT6TG  0972683275     5.0

# %%
# Mean rating of each product is captured in 'ratings_mean_count'
ratings_mean_count = pd.DataFrame(df_50_greater.groupby('productid')['rating'].mean())

# %%
# Capturing number of user for each product who had given rating for that product in new column in 'ratings_mean_count'
ratings_mean_count['rating_counts'] =pd.DataFrame(df_50_greater.groupby('productid')['rating'].count())

# %%
ratings_mean_count= ratings_mean_count.reset_index(drop = False)
df_100_product= ratings_mean_count[ratings_mean_count['rating_counts'] >100]
df_100_product
# Out:
#         productid    rating  rating_counts
# 11078  B000N99BBC  4.772455            167
# 21982  B002R5AM7C  4.125000            128
# 22210  B002SZEOLG  4.247788            113
# 22460  B002V88HFE  4.698113            106
# 23378  B0034CL2ZI  4.632075            106
# 24827  B003ES5ZUU  4.864130            184
# 28761  B004CLYEDC  4.669492            118
# 31001  B004T9RR6I  3.871560            109
# 38250  B007WTAJTO  4.701220            164
# 38611  B00829THK0  4.416058            137
# 38615  B00829TIEK  4.436242            149
# 38655  B00834SJNA  4.490909            110
# 38656  B00834SJSK  4.643564            101
# 39003  B0088CJT4U  4.218447            206
# 39338  B008DWCRQW  4.094891            137

# %%
df_100_product_sorted = df_100_product.sort_values('rating',ascending=False)

# %%
# taking head from 'rating_mean_count' dataframe 
rec_count = df_100_product_sorted.head(10)
rec_count # recommended electronics product based on popularity
# Out:
#         productid    rating  rating_counts
# 24827  B003ES5ZUU  4.864130            184
# 11078  B000N99BBC  4.772455            167
# 38250  B007WTAJTO  4.701220            164
# 22460  B002V88HFE  4.698113            106
# 28761  B004CLYEDC  4.669492            118
# 38656  B00834SJSK  4.643564            101
# 23378  B0034CL2ZI  4.632075            106
# 38655  B00834SJNA  4.490909            110
# 38615  B00829TIEK  4.436242            149
# 38611  B00829THK0  4.416058            137

# %% [markdown]
# >- For popularity based recomendation system we recommend popular items which are also rated high
# >- Its not clear if we just recommend the product based on high rating, we may missed on trending items
# >- So it is important to take considreation of how many users had rated the product
# >- So it is good if we select some threshold for products which are rated by minimum number of users
# >- Trending product can be recommended if we consider timestamp but we are ignoring that in this case
# >- We are selecting those products which are rated by atleast 100 user

# %%
popu_reco = ratings_mean_count.groupby('productid')['rating'].mean().sort_values(ascending=False).head()  
popu_reco.head(5) # popularity based best 5 recommendation
# Out:
# productid
# B00LKG1MC8    5.0
# B002QUZM3M    5.0
# B002QWNZHU    5.0
# B002QXZPFE    5.0
# B002R0DWNS    5.0
# Name: rating, dtype: float64

# %%
# Importing Surprise library pakages 
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split

# %%
# As we're loading a custom dataset, we need to define a reader. In the
# ratings_Electronics.csv dataset, each line has the following format:
# 'user item rating ', separated by ',' characters.
reader = Reader(line_format='user item rating ', sep=',',rating_scale=(1, 5))

# %%
# Loading the data into surprise library object
data = Dataset.load_from_df(df_50_greater[['userid', 'productid', 'rating']], reader)

# %%
# tring to observe the data , but its is in surprise.dataset
data

# %%
# Spliting the data into train and test 
trainset, testset = train_test_split(data, test_size=.3)

# %%
#Importing SVD from Surprise
from surprise import SVD
#importing gridsearchcv fro parameter tunning 
from surprise.model_selection import GridSearchCV

# %% [markdown]
# algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
# algo.fit(trainset)

# %%
# defining Parameter Grid 
param_grid = {'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}

#Instantiating gridsearchcv object
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)
# fitting data into the object  
gs.fit(data)

# %% [markdown]
# >- n_epochs – The number of iteration of the SGD procedure. Default is 20.
# >- lr_all – The learning rate for all parameters. Default is 0.005.
# >- reg_all – The regularization term for all parameters. Default is 0.02.

# %%
# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.989587209144332
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
# We can now use the algorithm that yields the best rmse:
algo = gs.best_estimator['rmse']
trainingSet = data.build_full_trainset()
trainingSet = algo.fit(trainingSet)

# %% [markdown]
# >- With the help of the above algo model we can predict the ratings of other electronics products which are not rated by user

# %%
# stroring the results of gridSearch Cv in results_df
results_df = pd.DataFrame.from_dict(gs.cv_results)

# %%
results_df.head()
# Out:
#    split0_test_rmse  split1_test_rmse  split2_test_rmse  mean_test_rmse  \
# 0          1.014365          1.021463          1.016334        1.017388
# 1          1.016389          1.022392          1.017425        1.018735
# 2          0.995831          1.002742          0.997340        0.998637
# 3          0.997933          1.005359          0.999545        1.000946
# 4          0.999938          1.006990          1.001429        1.002786
#
#    std_test_rmse  rank_test_rmse  split0_test_mae  split1_test_mae  \
# 0       0.002992               7         0.781023         0.782746
# 1       0.002620               8         0.783717         0.783993
# 2       0.002967               3         0.757767         0.760046
# 3       0.003189               4         0.761620         0.764243
# 4       0.003034               5         0.763008         0.765057
#
#    split2_test_mae  mean_test_mae  std_test_mae  rank_test_mae  mean_fit_time  \
# 0         0.781272       0.781680      0.000760              7       3.635999
# 1         0.783544       0.783752      0.000185              8       3.595257
# 2         0.758917       0.758910      0.000931              3       3.627027
# 3         0.762881       0.762915      0.001071              4       3.519023
# 4         0.763964       0.764010      0.000837              5       6.801660
#
#    std_fit_time  mean_test_time  std_test_time  \
# 0      0.119478        0.696042       0.058870
# 1      0.067662        0.812409       0.091177
# 2      0.121762        0.685666       0.084934
# 3      0.148582        0.867904       0.115264
# 4      0.229355        0.763263       0.136608
#
#                                               params  param_n_epochs  \
# 0   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.4}               5
# 1   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.6}               5
# 2   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.4}               5
# 3   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.6}               5
# 4  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.4}              10
#
#    param_lr_all  param_reg_all
# 0         0.002            0.4
# 1         0.002            0.6
# 2         0.005            0.4
# 3         0.005            0.6
# 4         0.002            0.4

# %%
# Predicting the values on testset

predictions = algo.test(testset)

# %%
# checking the accuracy 
accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 0.9102
# 0.9101833174457165

# %%
# Understanding and printing the prediction 
predictions
# We will use this prediction data in recommendation 
# predictions will contain all the predicted ratings
# Out:
# [Prediction(uid='A2QRXQPHDMFCQV', iid='B009X2OS72', r_ui=3.0, est=3.657588991385239, details={'was_impossible': False}),
#  Prediction(uid='AMWL7XIWIPXEZ', iid='B002EUCU3O', r_ui=4.0, est=3.8128570281956256, details={'was_impossible': False}),
#  Prediction(uid='A2PJH18W4XHTZW', iid='B008AL9VXI', r_ui=5.0, est=4.396926520603599, details={'was_impossible': False}),
#  Prediction(uid='A3IUW081KXD3PE', iid='B00902SFC4', r_ui=4.0, est=4.311008197444566, details={'was_impossible': False}),
#  Prediction(uid='AWPODHOB4GFWL', iid='B004CLYE8C', r_ui=5.0, est=4.607225007809706, details={'was_impossible': False}),
#  Prediction(uid='AN9WA4C5E7YY5', iid='B00AANQLRI', r_ui=5.0, est=4.604263621919875, details={'was_impossible': False}),
#  Prediction(uid='ACJT8MUC0LRF0', iid='B00ISFNSBW', r_ui=5.0, est=4.90998396673106, details={'was_impossible': False}),
#  Prediction(uid='A1X3ESYZ79H59E', iid='B004CLYEFK', r_ui=5.0, est=4.53114455698883, details={'was_impossible': False}),
#  Prediction(uid='A1CMWB7AWQUQH4', iid='B005CPGHAA', r_ui=2.0, est=3.5863409538894566, details={'was_impossible': False}),
#  Prediction(uid='APBB297H3ZA5E', iid='B002NU5UW8', r_ui=5.0, est=4.165015428535398, details={'was_impossible': False}),
#  Prediction(uid='AYLLSFYS3UP1H', iid='B0046HJLJO', r_ui=3.0, est=4.0541553370324275, details={'was_impossible': False}),
#  Prediction(uid='A15CL28ALB7MTZ', iid='B008ALA6DW', r_ui=5.0, est=4.550369576360987, details={'was_impossible': False}),
#  Prediction(uid='A1RPTVW5VEOSI', iid='B0002ZAILY', r_ui=5.0, est=4.201750012544491, details={'was_impossible': False}),
#  Prediction(uid='AR8LWDT6TUKNZ', iid='B007X4A4RA', r_ui=4.0, est=4.442112716873217, details={'was_impossible': False}),
#  Prediction(uid='AN0JK8OQLUC55', iid='B002BH3I9U', r_ui=5.0, est=3.708675531423613, details={'was_impossible': False}),
#  Prediction(uid='A2IFKH3TJ10387', iid='B00DOWCQB2', r_ui=5.0, est=4.495684104604334, details={'was_impossible': False}),
#  Prediction(uid='A2LTYEYGKBYXRR', iid='B00J46VVKE', r_ui=5.0, est=4.697062603848181, details={'was_impossible': False}),
#  Prediction(uid='AZ515FFZ7I2P7', iid='B001RB1QWW', r_ui=4.0, est=3.876416357423519, details={'was_impossible': False}),
#  Prediction(uid='AT28RL25Q2OLK', iid='B0000ALKF6', r_ui=5.0, est=4.414648503858392, details={'was_impossible': False}),
#  Prediction(uid='A3M82NO6OU1FHS', iid='B004E9SAUU', r_ui=4.0, est=4.295904510643648, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B004JMZPJQ', r_ui=5.0, est=4.60806749389903, details={'was_impossible': False}),
#  Prediction(uid='A2HV76MYH7UL3S', iid='B007PV6PM4', r_ui=5.0, est=4.570229439585377, details={'was_impossible': False}),
#  Prediction(uid='ARBKYIVNYWK3C', iid='B005X0JTP4', r_ui=4.0, est=4.316469779617629, details={'was_impossible': False}),
#  Prediction(uid='ABQWMANK4AR63', iid='B006T7HXI0', r_ui=3.0, est=3.8665788083188537, details={'was_impossible': False}),
#  Prediction(uid='A1AQ8JT2A3UWMY', iid='B000SXI5SI', r_ui=5.0, est=4.108303084617272, details={'was_impossible': False}),
#  Prediction(uid='A1WG97A0EFHYXN', iid='B005WUUFBW', r_ui=5.0, est=4.680979907928505, details={'was_impossible': False}),
#  Prediction(uid='A3AYSYSLHU26U9', iid='B0042LQWXW', r_ui=5.0, est=4.29148837735048, details={'was_impossible': False}),
#  Prediction(uid='A2NP9CGUSFP22E', iid='B0088PUEPK', r_ui=5.0, est=4.8188485557969605, details={'was_impossible': False}),
#  Prediction(uid='A19RGDJPNZ7NZ', iid='B000BP2YLC', r_ui=5.0, est=4.305652476070521, details={'was_impossible': False}),
#  Prediction(uid='AONUCJBC85BL', iid='B0043T7FXE', r_ui=3.0, est=4.050246713781689, details={'was_impossible': False}),
#  Prediction(uid='A18U49406IPPIJ', iid='B00FB2XNCE', r_ui=3.0, est=4.576949317419176, details={'was_impossible': False}),
#  Prediction(uid='A24P4E3RJ6AX94', iid='B006Q4EK7S', r_ui=5.0, est=4.516074522161142, details={'was_impossible': False}),
#  Prediction(uid='A3J8A5L5AF5TX9', iid='B000PO3CTM', r_ui=5.0, est=4.017449168028525, details={'was_impossible': False}),
#  Prediction(uid='AU3GYRAKBUAEU', iid='B0056C4WN8', r_ui=4.0, est=3.837081464641127, details={'was_impossible': False}),
#  Prediction(uid='AN2IZT80ZUNJN', iid='B004FG3DB8', r_ui=5.0, est=4.145246525482016, details={'was_impossible': False}),
#  Prediction(uid='A2LLSFQO8O8XNW', iid='B00CRB53CU', r_ui=5.0, est=4.403351161480121, details={'was_impossible': False}),
#  Prediction(uid='AY6A8KPYCE6B0', iid='B00G6IJ5NI', r_ui=4.0, est=4.336538675368582, details={'was_impossible': False}),
#  Prediction(uid='A3NOBH42C7UI5M', iid='B009O7XUW0', r_ui=3.0, est=3.8330774594952857, details={'was_impossible': False}),
#  Prediction(uid='A3N4I2KRSMACW8', iid='B00IEZGWI2', r_ui=5.0, est=4.157085777765308, details={'was_impossible': False}),
#  Prediction(uid='A2WLNSZ9U0T1S3', iid='B001M5U5AC', r_ui=4.0, est=4.172084106623071, details={'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00JWV1LP6', r_ui=5.0, est=4.630230147562476, details={'was_impossible': False}),
#  Prediction(uid='A1TQZUSOU22E9M', iid='B0009GZAGO', r_ui=5.0, est=4.690961402072497, details={'was_impossible': False}),
#  Prediction(uid='A3N8O68DOEQ2FE', iid='B001CIREXA', r_ui=5.0, est=4.719095222313704, details={'was_impossible': False}),
#  Prediction(uid='A3V7D0LH8L7BG0', iid='B001H8DF0G', r_ui=5.0, est=4.497974222899106, details={'was_impossible': False}),
#  Prediction(uid='A3G5MOHY1U635N', iid='B003EYVP12', r_ui=5.0, est=4.314825362304573, details={'was_impossible': False}),
#  Prediction(uid='A215IN14OKAE2T', iid='B0013L8APW', r_ui=1.0, est=3.3589836158318116, details={'was_impossible': False}),
#  Prediction(uid='A1C47ROOK7BSVL', iid='B006EKIQYM', r_ui=5.0, est=3.6211105931229817, details={'was_impossible': False}),
#  Prediction(uid='A18FLOC8YQY0P8', iid='B001LNO722', r_ui=5.0, est=4.138961021844437, details={'was_impossible': False}),
#  Prediction(uid='A110PC8C5Y7MQD', iid='B000V0ETA6', r_ui=1.0, est=3.844649915561347, details={'was_impossible': False}),
#  Prediction(uid='A1T1YSCDW0PD25', iid='B00IRX1NXK', r_ui=5.0, est=4.33692893744642, details={'was_impossible': False}),
#  Prediction(uid='A11LNPG39A2ZV4', iid='B0079TOG82', r_ui=3.0, est=4.11146921014456, details={'was_impossible': False}),
#  Prediction(uid='AYOTEJ617O60K', iid='B004T2KNS4', r_ui=2.0, est=3.66470846810179, details={'was_impossible': False}),
#  Prediction(uid='ACH055GTTIGC9', iid='B000E8P7Z6', r_ui=5.0, est=4.3272351432236, details={'was_impossible': False}),
#  Prediction(uid='ASCBJEPXTOU0V', iid='B007TMZ1BK', r_ui=4.0, est=4.3808675257493155, details={'was_impossible': False}),
#  Prediction(uid='A31RZMVAFMLB8B', iid='B001KBZ3SC', r_ui=5.0, est=4.305012193794532, details={'was_impossible': False}),
#  Prediction(uid='A3J3ZHGDUDPCFL', iid='B000BFLNA0', r_ui=4.0, est=4.436029225379536, details={'was_impossible': False}),
#  Prediction(uid='AN9WA4C5E7YY5', iid='B0016LCMCG', r_ui=5.0, est=4.469833221539558, details={'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00JEGLLEA', r_ui=5.0, est=4.547454376951836, details={'was_impossible': False}),
#  Prediction(uid='A2TA40MV2H4O6F', iid='B009HQCARY', r_ui=5.0, est=4.479031181254929, details={'was_impossible': False}),
#  Prediction(uid='ABQWMANK4AR63', iid='B003FGWF04', r_ui=5.0, est=4.035433437927082, details={'was_impossible': False}),
#  Prediction(uid='A3TBMGNSEQBWIL', iid='B004VU1KUY', r_ui=4.0, est=4.072142568715753, details={'was_impossible': False}),
#  Prediction(uid='A22MANL4US4RMY', iid='B008V4TFDK', r_ui=5.0, est=4.4538466922093445, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B00F9ZQQ8Q', r_ui=1.0, est=3.8674552988983106, details={'was_impossible': False}),
#  Prediction(uid='A3077MQTAKOVFZ', iid='B003BYRGJU', r_ui=4.0, est=4.3551087483169555, details={'was_impossible': False}),
#  Prediction(uid='A2PSD2R9A1CXG7', iid='B00ENY08VU', r_ui=4.0, est=4.083562344613691, details={'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B006ZW4H4C', r_ui=5.0, est=4.414729206164007, details={'was_impossible': False}),
#  Prediction(uid='AOMEH9W6LHC4S', iid='B00APP6694', r_ui=5.0, est=4.1827976809280845, details={'was_impossible': False}),
#  Prediction(uid='AWHL379EE14K7', iid='B001LJOV40', r_ui=5.0, est=4.463387248909721, details={'was_impossible': False}),
#  Prediction(uid='A1EKSETIBS9ETQ', iid='B000CC9LS8', r_ui=5.0, est=4.2027536241224315, details={'was_impossible': False}),
#  Prediction(uid='A1Z16630QMH8Q6', iid='B000BPGZOY', r_ui=5.0, est=4.586387772035986, details={'was_impossible': False}),
#  Prediction(uid='A2RWHTNM5P3I8Y', iid='B002MF68HA', r_ui=2.0, est=3.8754892852462914, details={'was_impossible': False}),
#  Prediction(uid='A124WZCUIH2T7W', iid='B00009UT2Q', r_ui=5.0, est=4.4159923575332, details={'was_impossible': False}),
#  Prediction(uid='A2T3S3VTW65VO5', iid='B0034JLTNG', r_ui=4.0, est=4.49907248013782, details={'was_impossible': False}),
#  Prediction(uid='A1XXMNLOLKNO0I', iid='B00A2BWAY6', r_ui=5.0, est=4.685120328611942, details={'was_impossible': False}),
#  Prediction(uid='A15QYHQH80W30L', iid='B001J8BPYM', r_ui=5.0, est=4.401248472020348, details={'was_impossible': False}),
#  Prediction(uid='A2N3JSOIQ6ZNFL', iid='B001MA8I1U', r_ui=4.0, est=4.370561208641163, details={'was_impossible': False}),
#  Prediction(uid='A54SG05AV6S4H', iid='B00CMDSYY2', r_ui=5.0, est=4.766424218166337, details={'was_impossible': False}),
#  Prediction(uid='A2OOXVZ6B1VZ9A', iid='B001EFD5CU', r_ui=5.0, est=4.520585884766846, details={'was_impossible': False}),
#  Prediction(uid='A27ADCSD15F3GL', iid='B00FE8MKTM', r_ui=3.0, est=4.108286579684889, details={'was_impossible': False}),
#  Prediction(uid='A1L64KDYO5BOJA', iid='B001CN7EQ2', r_ui=5.0, est=4.478852313300799, details={'was_impossible': False}),
#  Prediction(uid='A21S26XYPGXJZX', iid='B003FG7IG0', r_ui=5.0, est=4.5084176388897115, details={'was_impossible': False}),
#  Prediction(uid='A2M9ME0N2S3R39', iid='B00ESYW40S', r_ui=4.0, est=4.323635056042917, details={'was_impossible': False}),
#  Prediction(uid='A3NEAETOSXDBOM', iid='B0014XKQY2', r_ui=5.0, est=4.357674981369324, details={'was_impossible': False}),
#  Prediction(uid='ASJLXOX1VD4DF', iid='B0081R7XR2', r_ui=4.0, est=3.9457512356819744, details={'was_impossible': False}),
#  Prediction(uid='AU627A4UGIW6V', iid='B002EPF6YO', r_ui=4.0, est=4.3013010343179765, details={'was_impossible': False}),
#  Prediction(uid='A2RW587355CMVA', iid='B005X9Y0YU', r_ui=5.0, est=4.241287385966931, details={'was_impossible': False}),
#  Prediction(uid='AAW7X3GRD8GY9', iid='B000EHCYBC', r_ui=5.0, est=4.538063899276196, details={'was_impossible': False}),
#  Prediction(uid='A3D01HLSUFEZQY', iid='B002TI71HQ', r_ui=5.0, est=4.489639067719658, details={'was_impossible': False}),
#  Prediction(uid='AW63IRQWH10GF', iid='B004T7VI2Y', r_ui=4.0, est=4.03653273400134, details={'was_impossible': False}),
#  Prediction(uid='AU627A4UGIW6V', iid='B005ARQLQK', r_ui=5.0, est=4.538200274257656, details={'was_impossible': False}),
#  Prediction(uid='A28J3123I1QDKI', iid='B0020HRCA2', r_ui=5.0, est=4.1775125172746925, details={'was_impossible': False}),
#  Prediction(uid='AG2YXYIQ8TLTA', iid='B000V1MLBE', r_ui=5.0, est=3.923160409868236, details={'was_impossible': False}),
#  Prediction(uid='A3IUW081KXD3PE', iid='B0043M668G', r_ui=5.0, est=4.600264476813514, details={'was_impossible': False}),
#  Prediction(uid='A21T0D2F7SKG5S', iid='B000CLNHXY', r_ui=4.0, est=3.9408544290847383, details={'was_impossible': False}),
#  Prediction(uid='A1CM4HI4S5P0WO', iid='B000807GJK', r_ui=5.0, est=4.036164529711922, details={'was_impossible': False}),
#  Prediction(uid='A2D1LPEUCTNT8X', iid='B00AWHUGMS', r_ui=5.0, est=4.490960204681986, details={'was_impossible': False}),
#  Prediction(uid='A2503LT8PZIHAD', iid='B001TK3E44', r_ui=5.0, est=4.222793449342048, details={'was_impossible': False}),
#  Prediction(uid='A1F7YU6O5RU432', iid='B00ETH7ERM', r_ui=5.0, est=4.49006561440047, details={'was_impossible': False}),
#  Prediction(uid='A2PJH18W4XHTZW', iid='B001RB21JY', r_ui=5.0, est=4.453198731896059, details={'was_impossible': False}),
#  Prediction(uid='A1AZQCVCDBQP6', iid='B00006HSJH', r_ui=5.0, est=4.444472682005574, details={'was_impossible': False}),
#  Prediction(uid='A74UT8IQCM0I2', iid='B00CEZBKTO', r_ui=5.0, est=4.717905322092964, details={'was_impossible': False}),
#  Prediction(uid='ABH9D1TEOJ56E', iid='B00006LV79', r_ui=4.0, est=4.1318755165078835, details={'was_impossible': False}),
#  Prediction(uid='A5MCDQ60DWUEV', iid='B003EB0AXY', r_ui=5.0, est=4.329359376509247, details={'was_impossible': False}),
#  Prediction(uid='A1E1LEVQ9VQNK', iid='B00D50UNRM', r_ui=5.0, est=4.896957408845534, details={'was_impossible': False}),
#  Prediction(uid='A27M75LRSJ788H', iid='B006CTYL1W', r_ui=5.0, est=4.651987687662834, details={'was_impossible': False}),
#  Prediction(uid='A1I96OYAUJ3HQE', iid='B00CF5OHZ2', r_ui=5.0, est=4.65210975834364, details={'was_impossible': False}),
#  Prediction(uid='A19FRW264WZTGP', iid='B00272NFVA', r_ui=5.0, est=4.473559012996384, details={'was_impossible': False}),
#  Prediction(uid='A2PSC7LUNIDEAH', iid='B000HCT12O', r_ui=4.0, est=4.467250532124894, details={'was_impossible': False}),
#  Prediction(uid='A2YYHSORXIHZCS', iid='B000067SOH', r_ui=1.0, est=4.241533416744029, details={'was_impossible': False}),
#  Prediction(uid='A1J87SYB3JPQWH', iid='B0035JCM5Y', r_ui=4.0, est=4.527207705752877, details={'was_impossible': False}),
#  Prediction(uid='A2WDCAMKCCP1UR', iid='B005NX1DAK', r_ui=5.0, est=4.1004929923060764, details={'was_impossible': False}),
#  Prediction(uid='A16SRDVPBXN69C', iid='B0002YE6EU', r_ui=5.0, est=4.60069369313316, details={'was_impossible': False}),
#  Prediction(uid='A2KIJBT9HRIOM8', iid='B003ZTZE5Y', r_ui=5.0, est=4.473602688878888, details={'was_impossible': False}),
#  Prediction(uid='A3F8T3BRXRX5P3', iid='B006K5520C', r_ui=5.0, est=4.146630682716899, details={'was_impossible': False}),
#  Prediction(uid='A31N0XY2UTB25C', iid='B005E2XQQY', r_ui=5.0, est=4.529483970000359, details={'was_impossible': False}),
#  Prediction(uid='A2EZTM9WY5B5IL', iid='B00316263Y', r_ui=5.0, est=4.273128632048431, details={'was_impossible': False}),
#  Prediction(uid='A1OMXVXXP07F05', iid='B004XIT4NO', r_ui=4.0, est=4.215988188209806, details={'was_impossible': False}),
#  Prediction(uid='A2J8T58Z4X15IO', iid='B005HY4UPK', r_ui=5.0, est=4.119874891033702, details={'was_impossible': False}),
#  Prediction(uid='AJEOFP6ZWY0MK', iid='B00DIJ2DFU', r_ui=4.0, est=4.2094640583454686, details={'was_impossible': False}),
#  Prediction(uid='A9Y5O2R4D6EH5', iid='B002UAUZQW', r_ui=5.0, est=4.1457537449907615, details={'was_impossible': False}),
#  Prediction(uid='AEL6CQNQXONBX', iid='B000OV85NE', r_ui=5.0, est=4.504335856443588, details={'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B001BLV78Q', r_ui=5.0, est=4.242226344651144, details={'was_impossible': False}),
#  Prediction(uid='A1KXJCXS6HFRQZ', iid='B001QJ7656', r_ui=4.0, est=4.155014729957212, details={'was_impossible': False}),
#  Prediction(uid='A2RU4U1JZ3DMP5', iid='B002TG3XXY', r_ui=4.0, est=4.13081303214236, details={'was_impossible': False}),
#  Prediction(uid='AVFJ327UXPXLF', iid='B00CWBABP4', r_ui=4.0, est=3.940357591779725, details={'was_impossible': False}),
#  Prediction(uid='A3VI2VETB90ZG5', iid='B001IBMLKM', r_ui=5.0, est=4.163810955523017, details={'was_impossible': False}),
#  Prediction(uid='A2VJ5ALN1BIV3B', iid='B004Q0PT3I', r_ui=5.0, est=4.612068304323795, details={'was_impossible': False}),
#  Prediction(uid='A3JU990UTN5RQP', iid='B000067SXG', r_ui=5.0, est=4.433810356667887, details={'was_impossible': False}),
#  Prediction(uid='A2XRMQA6PJ5ZJ8', iid='B003VVXUS4', r_ui=5.0, est=4.496943975736161, details={'was_impossible': False}),
#  Prediction(uid='A3UW23DBF2KHWC', iid='B00004TDLD', r_ui=5.0, est=4.6105183438368975, details={'was_impossible': False}),
#  Prediction(uid='A18U49406IPPIJ', iid='B00EUSMQWS', r_ui=5.0, est=4.764806362930097, details={'was_impossible': False}),
#  Prediction(uid='A1PPS91NLI7KEH', iid='B00EL8NJ82', r_ui=5.0, est=4.266020429564434, details={'was_impossible': False}),
#  Prediction(uid='A3UW23DBF2KHWC', iid='B00DZPUOTE', r_ui=4.0, est=4.509521969827445, details={'was_impossible': False}),
#  Prediction(uid='A2Q7OJTVPIO2XH', iid='B00EY3YGBS', r_ui=4.0, est=4.206257839435294, details={'was_impossible': False}),
#  Prediction(uid='A30X750M8V1XXW', iid='B003FGB8FM', r_ui=2.0, est=4.020959954888709, details={'was_impossible': False}),
#  Prediction(uid='A1OMXVXXP07F05', iid='B005EM6IAA', r_ui=5.0, est=4.226545117220987, details={'was_impossible': False}),
#  Prediction(uid='A11R5VW7IM6ISQ', iid='B00198LYMU', r_ui=5.0, est=4.5343076409511065, details={'was_impossible': False}),
#  Prediction(uid='AVFJ327UXPXLF', iid='B000O8WE66', r_ui=4.0, est=4.422068722222428, details={'was_impossible': False}),
#  Prediction(uid='A1F0KPA232MTYC', iid='B000CRFOMK', r_ui=5.0, est=4.469308054033768, details={'was_impossible': False}),
#  Prediction(uid='A1CMD08Z49PGKQ', iid='B003XIJ3MW', r_ui=5.0, est=4.758899834027113, details={'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B0049VR1KI', r_ui=5.0, est=4.458253593641436, details={'was_impossible': False}),
#  Prediction(uid='A1G650TTTHEAL5', iid='B00FA9GXKM', r_ui=5.0, est=4.650114994834213, details={'was_impossible': False}),
#  Prediction(uid='AZ8XSDMIX04VJ', iid='B000ZD0CV4', r_ui=5.0, est=4.509482391664996, details={'was_impossible': False}),
#  Prediction(uid='A2XPK6XCL0UH1S', iid='B0001EMLXE', r_ui=5.0, est=3.9851088942182153, details={'was_impossible': False}),
#  Prediction(uid='A3U41ZL33SS92P', iid='B0002YE6EU', r_ui=5.0, est=3.868501582966281, details={'was_impossible': False}),
#  Prediction(uid='A1QNYLBG73QRNF', iid='B00007GQLT', r_ui=3.0, est=4.003360539420884, details={'was_impossible': False}),
#  Prediction(uid='A2Y3WWPUKIJ59I', iid='B0096FB61W', r_ui=5.0, est=4.066480007576182, details={'was_impossible': False}),
#  Prediction(uid='A3TP31S61PPE3G', iid='B003DZ165W', r_ui=4.0, est=4.16783063255939, details={'was_impossible': False}),
#  Prediction(uid='AFH97KY1SBP2C', iid='B000DZH5W8', r_ui=5.0, est=4.311476922726417, details={'was_impossible': False}),
#  Prediction(uid='A4WEZJOIZIV4U', iid='B004J3V90Y', r_ui=5.0, est=4.428435037266883, details={'was_impossible': False}),
#  Prediction(uid='A1E1LEVQ9VQNK', iid='B0002DF0FU', r_ui=5.0, est=4.666761147834571, details={'was_impossible': False}),
#  Prediction(uid='AGYH5U11ZKPFB', iid='B003X7TRWE', r_ui=4.0, est=4.5476207346911455, details={'was_impossible': False}),
#  Prediction(uid='A15T9G38F589KM', iid='B00882OHL0', r_ui=3.0, est=4.036253166701801, details={'was_impossible': False}),
#  Prediction(uid='A379DLIAF0MFM5', iid='B004Z57WDO', r_ui=5.0, est=4.430000077370577, details={'was_impossible': False}),
#  Prediction(uid='A3U41ZL33SS92P', iid='B001F0RPGG', r_ui=5.0, est=3.8872274883604376, details={'was_impossible': False}),
#  Prediction(uid='A2HDTOF8222KN3', iid='B007P4VOWC', r_ui=5.0, est=4.827759412396878, details={'was_impossible': False}),
#  Prediction(uid='A38KK0SZYEH5UD', iid='B00009X3UA', r_ui=5.0, est=4.4435201494566625, details={'was_impossible': False}),
#  Prediction(uid='A38Z6QG6988WS7', iid='B004UVJCPO', r_ui=5.0, est=4.6874120505191845, details={'was_impossible': False}),
#  Prediction(uid='A1R377IPZOKLMM', iid='B002IGT7IK', r_ui=5.0, est=4.613995535303479, details={'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B0037258L4', r_ui=5.0, est=4.5794108058684015, details={'was_impossible': False}),
#  Prediction(uid='ARIDN94LOCQFD', iid='B004G6002M', r_ui=5.0, est=4.550265851360921, details={'was_impossible': False}),
#  Prediction(uid='ADKZOXAOV8EXD', iid='B000ZMCILW', r_ui=5.0, est=4.240569286234294, details={'was_impossible': False}),
#  Prediction(uid='A3284KYDZ00BZA', iid='B002SZEOLG', r_ui=5.0, est=4.074456273869558, details={'was_impossible': False}),
#  Prediction(uid='A3LGT6UZL99IW1', iid='B00HH5DDCI', r_ui=5.0, est=4.028709138069621, details={'was_impossible': False}),
#  Prediction(uid='A292TRC6DX2GKK', iid='B000FBK3QK', r_ui=5.0, est=4.517169441828996, details={'was_impossible': False}),
#  Prediction(uid='A3D0UM4ZD2CMAW', iid='B004GUT344', r_ui=5.0, est=4.7471818425276116, details={'was_impossible': False}),
#  Prediction(uid='A1VQHH85U7PX0', iid='B00J3HMY1E', r_ui=3.0, est=3.845786062550885, details={'was_impossible': False}),
#  Prediction(uid='A240FRPD4MEXND', iid='B0013IWYHU', r_ui=5.0, est=4.289881750119872, details={'was_impossible': False}),
#  Prediction(uid='A3J8A5L5AF5TX9', iid='B004MME6RU', r_ui=4.0, est=4.0264657045577446, details={'was_impossible': False}),
#  Prediction(uid='A28X0LT2100RL1', iid='B002WE4HE2', r_ui=5.0, est=4.589089717621904, details={'was_impossible': False}),
#  Prediction(uid='A18EA7MNLXP9H5', iid='B006BUN7MG', r_ui=3.0, est=3.9518251055675937, details={'was_impossible': False}),
#  Prediction(uid='A3U029B8Z5WGI2', iid='B00BUHXQWQ', r_ui=5.0, est=4.518317486586866, details={'was_impossible': False}),
#  Prediction(uid='A23GFTVIETX7DS', iid='B00F39J4L4', r_ui=5.0, est=4.428338823670353, details={'was_impossible': False}),
#  Prediction(uid='A2PY5ED630H0QJ', iid='B006EKIQYM', r_ui=2.0, est=4.217938514488593, details={'was_impossible': False}),
#  Prediction(uid='AEZJTA4KDIWY8', iid='B00966IREK', r_ui=5.0, est=4.42968849841758, details={'was_impossible': False}),
#  Prediction(uid='A1G650TTTHEAL5', iid='B00G4V0QSK', r_ui=5.0, est=4.833328070285298, details={'was_impossible': False}),
#  Prediction(uid='A1F9Z42CFF9IAY', iid='B007Y4BL1C', r_ui=4.0, est=3.615465768838527, details={'was_impossible': False}),
#  Prediction(uid='A10Y058K7B96C6', iid='B00ADG5FLK', r_ui=4.0, est=4.003680290396951, details={'was_impossible': False}),
#  Prediction(uid='A2JXS1JII6SAUD', iid='B005FPT38A', r_ui=5.0, est=4.522757334680561, details={'was_impossible': False}),
#  Prediction(uid='A2BLFCOPSMBOZ9', iid='B001T9NUJE', r_ui=5.0, est=4.482222149560562, details={'was_impossible': False}),
#  Prediction(uid='A2D0CO1OA6DSWY', iid='B00E3AKF1C', r_ui=5.0, est=4.457899044238306, details={'was_impossible': False}),
#  Prediction(uid='A34UVV757IKPVB', iid='B000Z9R2QQ', r_ui=4.0, est=3.740949710311183, details={'was_impossible': False}),
#  Prediction(uid='A8P6GIIQ6YQV8', iid='B0032O6S70', r_ui=5.0, est=4.353723622394592, details={'was_impossible': False}),
#  Prediction(uid='A16HXVNPU5TCGE', iid='B008SFSIXU', r_ui=5.0, est=4.548267582744058, details={'was_impossible': False}),
#  Prediction(uid='A3CG93783LP0FO', iid='B004WKSY1G', r_ui=4.0, est=4.205160845935579, details={'was_impossible': False}),
#  Prediction(uid='A3DWO5RJDA430F', iid='B0048JG5UI', r_ui=5.0, est=4.188247780909747, details={'was_impossible': False}),
#  Prediction(uid='A2JRDFIGWTX50J', iid='B000GT47I6', r_ui=4.0, est=3.7057732069628853, details={'was_impossible': False}),
#  Prediction(uid='A16RI68PS6T5CA', iid='B001RHJ60K', r_ui=5.0, est=4.267690238555911, details={'was_impossible': False}),
#  Prediction(uid='A3LGT6UZL99IW1', iid='B00GNPPJW0', r_ui=5.0, est=4.263329685580051, details={'was_impossible': False}),
#  Prediction(uid='A15CL28ALB7MTZ', iid='B0088CJT4U', r_ui=2.0, est=4.322756337703936, details={'was_impossible': False}),
#  Prediction(uid='A1R76R4E6A8S3B', iid='B00829TIEK', r_ui=5.0, est=4.26542066550309, details={'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B00CMJZAOI', r_ui=5.0, est=4.456922585589923, details={'was_impossible': False}),
#  Prediction(uid='A226VGZWOEBPGL', iid='B005Y8JM7A', r_ui=5.0, est=4.418456360137989, details={'was_impossible': False}),
#  Prediction(uid='A1VOFY3QFT9WCG', iid='B007NZGPAY', r_ui=5.0, est=4.845745082122429, details={'was_impossible': False}),
#  Prediction(uid='A1JZFGZEZVWQPY', iid='B002P3KH80', r_ui=4.0, est=4.195009235512091, details={'was_impossible': False}),
#  Prediction(uid='A2X695AM08AIN1', iid='B004PNZFZ8', r_ui=5.0, est=4.279936817027047, details={'was_impossible': False}),
#  Prediction(uid='AOEDWQLH2WKKW', iid='B0081FLFQE', r_ui=4.0, est=4.259829321541882, details={'was_impossible': False}),
#  Prediction(uid='A2N75ADJSRW0AH', iid='B003ZK5NZY', r_ui=5.0, est=4.394567593417407, details={'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B00BB6DCUC', r_ui=5.0, est=4.73457296619786, details={'was_impossible': False}),
#  Prediction(uid='AYOMAHLWRQHUG', iid='B003GAMO6Y', r_ui=3.0, est=4.0018909316252245, details={'was_impossible': False}),
#  Prediction(uid='A3AYSYSLHU26U9', iid='B003AILH6U', r_ui=4.0, est=4.124558931315964, details={'was_impossible': False}),
#  Prediction(uid='A353U0L2HAMSHV', iid='B008X9Z6EA', r_ui=4.0, est=4.025063336401027, details={'was_impossible': False}),
#  Prediction(uid='ACH055GTTIGC9', iid='B0043955ZO', r_ui=4.0, est=4.3542491933224765, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0009FUSBW', r_ui=4.0, est=4.173455031052306, details={'was_impossible': False}),
#  Prediction(uid='A2ZWJVKITA32OV', iid='B00DR0PDNE', r_ui=3.0, est=3.780599474226244, details={'was_impossible': False}),
#  Prediction(uid='A2W9GX82SLKROQ', iid='B007BXD66E', r_ui=5.0, est=4.2874398140199945, details={'was_impossible': False}),
#  Prediction(uid='A2SZLNSI5KOQJT', iid='B009XNBFJK', r_ui=5.0, est=4.237543858221345, details={'was_impossible': False}),
#  Prediction(uid='A2YEOR4XJ8N3QE', iid='B005P99KWU', r_ui=2.0, est=3.977424897486519, details={'was_impossible': False}),
#  Prediction(uid='A1EH2S92FHWZRP', iid='B00006I5J7', r_ui=5.0, est=4.273622175965707, details={'was_impossible': False}),
#  Prediction(uid='A2ZY49IDE6TY5I', iid='B0097CZHAU', r_ui=4.0, est=4.057518520341196, details={'was_impossible': False}),
#  Prediction(uid='A2HRHF83I3NDGT', iid='B002R0DZXU', r_ui=5.0, est=4.531862101166284, details={'was_impossible': False}),
#  Prediction(uid='A4S2WAQVQR6PI', iid='B009QBIZ60', r_ui=5.0, est=4.20927596060163, details={'was_impossible': False}),
#  Prediction(uid='A33SX0AD5PYD9B', iid='B003CFATT2', r_ui=4.0, est=4.466551340740429, details={'was_impossible': False}),
#  Prediction(uid='A2S26YGSVXBCFL', iid='B003STVG80', r_ui=3.0, est=3.5165109868272895, details={'was_impossible': False}),
#  Prediction(uid='A3JUHP1E3WUHEA', iid='B003ES5ZUU', r_ui=5.0, est=4.717469866181581, details={'was_impossible': False}),
#  Prediction(uid='A1MNN0ZMHYPJDU', iid='B00DVFLJDS', r_ui=4.0, est=4.598380137778899, details={'was_impossible': False}),
#  Prediction(uid='A11OTLEDSW8ZXD', iid='B008R7EVE4', r_ui=5.0, est=4.074236827826013, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B004MMEI0K', r_ui=4.0, est=4.129626499493804, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B00F37K6VS', r_ui=4.0, est=4.135131074947189, details={'was_impossible': False}),
#  Prediction(uid='A149RNR5RH19YY', iid='B0001G6UGG', r_ui=4.0, est=4.099196365926448, details={'was_impossible': False}),
#  Prediction(uid='A12DQZKRKTNF5E', iid='B001U3ZH7W', r_ui=2.0, est=4.08806252112487, details={'was_impossible': False}),
#  Prediction(uid='A4H4KYSM2KQ85', iid='B00G4JZ2T0', r_ui=5.0, est=4.385364317923905, details={'was_impossible': False}),
#  Prediction(uid='A3LWC833HQIG7J', iid='B001VEJEGK', r_ui=4.0, est=4.072597318679605, details={'was_impossible': False}),
#  Prediction(uid='A17W0GMB0YY83M', iid='B005DTBCD2', r_ui=5.0, est=4.4236842615475656, details={'was_impossible': False}),
#  Prediction(uid='A1A5KUIIIHFF4U', iid='B002HK5AW4', r_ui=5.0, est=4.128908802716527, details={'was_impossible': False}),
#  Prediction(uid='AVTJEWTCJ3PBE', iid='B00GX6F78K', r_ui=4.0, est=4.426475027681953, details={'was_impossible': False}),
#  Prediction(uid='A27AF4DLLOBQDQ', iid='B0039NLS4C', r_ui=4.0, est=4.351020800216519, details={'was_impossible': False}),
#  Prediction(uid='A110VKXAVLAYKY', iid='B0000BZMIH', r_ui=4.0, est=4.271948526843975, details={'was_impossible': False}),
#  Prediction(uid='A3V0YR50F1XSKP', iid='B002YIG9AQ', r_ui=5.0, est=4.391483614421152, details={'was_impossible': False}),
#  Prediction(uid='A12LH2100CKQO', iid='B0002J1I32', r_ui=5.0, est=4.6205478878488755, details={'was_impossible': False}),
#  Prediction(uid='A34BZM6S9L7QI4', iid='B00INTDOT4', r_ui=4.0, est=4.507790553153476, details={'was_impossible': False}),
#  Prediction(uid='A38C12950IM24P', iid='B00G4UQ6U8', r_ui=5.0, est=4.847463391766246, details={'was_impossible': False}),
#  Prediction(uid='A2UTZ4O5E2W4DK', iid='B000AMLVTM', r_ui=5.0, est=4.565431412033934, details={'was_impossible': False}),
#  Prediction(uid='A2V0I904FH7ABY', iid='B00003WGP5', r_ui=4.0, est=4.409402974710877, details={'was_impossible': False}),
#  Prediction(uid='AN81JUYW2SL24', iid='B005PCOKEK', r_ui=5.0, est=4.192261557375222, details={'was_impossible': False}),
#  Prediction(uid='A3SMD3T0QTN109', iid='B009C98NPY', r_ui=3.0, est=4.277498681399622, details={'was_impossible': False}),
#  Prediction(uid='A3INN916E4VION', iid='B003YLUC0K', r_ui=3.0, est=4.310157143107953, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B00GLJGJTA', r_ui=5.0, est=4.124919649414698, details={'was_impossible': False}),
#  Prediction(uid='A26EQ8U96JA92T', iid='B002RM08RE', r_ui=5.0, est=4.647057141345794, details={'was_impossible': False}),
#  Prediction(uid='A3HPCRD9RX351S', iid='B00B3YQGHS', r_ui=5.0, est=4.568866753164769, details={'was_impossible': False}),
#  Prediction(uid='A231WM2Z2JL0U3', iid='B00006HCCK', r_ui=5.0, est=4.365541750522939, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B00HLDFUM2', r_ui=4.0, est=4.314492295774024, details={'was_impossible': False}),
#  Prediction(uid='AGILRZOT49R0V', iid='B006W8U2MU', r_ui=5.0, est=4.648111623642977, details={'was_impossible': False}),
#  Prediction(uid='A18A5VSD0IPN14', iid='B003VSTDFG', r_ui=5.0, est=4.612222137710312, details={'was_impossible': False}),
#  Prediction(uid='ARBKYIVNYWK3C', iid='B001ACXHXE', r_ui=4.0, est=4.360472477455834, details={'was_impossible': False}),
#  Prediction(uid='A3EK2KTYHJCPB9', iid='B00BB0ZSIC', r_ui=5.0, est=4.322222123673699, details={'was_impossible': False}),
#  Prediction(uid='ACH055GTTIGC9', iid='B00009UHAM', r_ui=5.0, est=4.476410728768766, details={'was_impossible': False}),
#  Prediction(uid='AAQ9NJ480N9W5', iid='B002DUKPN2', r_ui=4.0, est=4.481365549954237, details={'was_impossible': False}),
#  Prediction(uid='AKCZIJ6ZHE41D', iid='B00G4UQ6U8', r_ui=2.0, est=4.129970191482555, details={'was_impossible': False}),
#  Prediction(uid='A1IU4UAV9QIJAI', iid='B009NXFLWW', r_ui=3.0, est=4.133395064121906, details={'was_impossible': False}),
#  Prediction(uid='A8FKL1DHTHC12', iid='B005INALWG', r_ui=5.0, est=4.436055643881771, details={'was_impossible': False}),
#  Prediction(uid='ABXANRX4GPYRZ', iid='B000UVBVQ6', r_ui=5.0, est=4.264959201121512, details={'was_impossible': False}),
#  Prediction(uid='A105S56ODHGJEK', iid='B002MCZJ78', r_ui=5.0, est=4.207287416572135, details={'was_impossible': False}),
#  Prediction(uid='A30KPB2ILF6K6J', iid='B007B5QOHK', r_ui=4.0, est=4.380159086236588, details={'was_impossible': False}),
#  Prediction(uid='A1Z7U9K6X3FEOU', iid='B001BJAJ64', r_ui=2.0, est=4.120460204227134, details={'was_impossible': False}),
#  Prediction(uid='A11I1I9QLMAM1A', iid='B002JP6K7Q', r_ui=5.0, est=4.502747237816013, details={'was_impossible': False}),
#  Prediction(uid='A313H6238N589', iid='B00A42Y0PA', r_ui=2.0, est=3.8678441833126276, details={'was_impossible': False}),
#  Prediction(uid='A2SH6A32BE6NEV', iid='B002PHLZE6', r_ui=5.0, est=4.309593071321436, details={'was_impossible': False}),
#  Prediction(uid='A7Y6AVS576M03', iid='B00006IAAL', r_ui=3.0, est=4.481109281092802, details={'was_impossible': False}),
#  Prediction(uid='A2FRKEXDXDN1KI', iid='B001NEK0PC', r_ui=3.0, est=4.234271199661443, details={'was_impossible': False}),
#  Prediction(uid='A2TRXEZYU9GYY8', iid='B005NI5XSI', r_ui=5.0, est=4.561373358977869, details={'was_impossible': False}),
#  Prediction(uid='A1VRANSQ0WF1YS', iid='B0081RNO52', r_ui=4.0, est=4.133390183738641, details={'was_impossible': False}),
#  Prediction(uid='AM9APPMIE1BHZ', iid='B0081FLFQE', r_ui=5.0, est=4.468570618492051, details={'was_impossible': False}),
#  Prediction(uid='A2M9ME0N2S3R39', iid='B00299G80Q', r_ui=5.0, est=4.3402306453710375, details={'was_impossible': False}),
#  Prediction(uid='A2QDOJFFLFGF18', iid='B0053NBLFW', r_ui=3.0, est=4.476865834606089, details={'was_impossible': False}),
#  Prediction(uid='A6XLG77BC9R8R', iid='B003FPD3IS', r_ui=5.0, est=4.402082404069077, details={'was_impossible': False}),
#  Prediction(uid='ACQYIC13JXAOI', iid='B002R5AM7C', r_ui=4.0, est=4.314887706560552, details={'was_impossible': False}),
#  Prediction(uid='A2PSD2R9A1CXG7', iid='B00007B4DM', r_ui=5.0, est=4.243025042237419, details={'was_impossible': False}),
#  Prediction(uid='A32HSNCNPRUMTR', iid='B00006B7DA', r_ui=5.0, est=4.086027955759918, details={'was_impossible': False}),
#  Prediction(uid='A11KZ906QD08C5', iid='B00KU4RD4M', r_ui=5.0, est=4.482822792346419, details={'was_impossible': False}),
#  Prediction(uid='A361M14PU2GUEG', iid='B0088PU86K', r_ui=5.0, est=4.248775239846004, details={'was_impossible': False}),
#  Prediction(uid='A2UQK3DAZ8NO2T', iid='B0007WK8MQ', r_ui=4.0, est=4.287213126662802, details={'was_impossible': False}),
#  Prediction(uid='A10AFVU66A79Y1', iid='B000VJWJW2', r_ui=5.0, est=4.250171994513197, details={'was_impossible': False}),
#  Prediction(uid='A20WUUD9EDWY4N', iid='B009BZX340', r_ui=5.0, est=4.674209923280824, details={'was_impossible': False}),
#  Prediction(uid='A3AYSYSLHU26U9', iid='B0041OSQB6', r_ui=4.0, est=4.153846027544058, details={'was_impossible': False}),
#  Prediction(uid='ASRA2UZ3JV87B', iid='B000EWD4TS', r_ui=4.0, est=3.8197112758969296, details={'was_impossible': False}),
#  Prediction(uid='A12DQZKRKTNF5E', iid='B004INGZCM', r_ui=3.0, est=3.818981680213478, details={'was_impossible': False}),
#  Prediction(uid='A2L4ZGN7GZJ95T', iid='B008X9Z528', r_ui=3.0, est=3.9421446279652725, details={'was_impossible': False}),
#  Prediction(uid='AHF4I1FSIHABC', iid='B00004WCID', r_ui=5.0, est=4.46247863619687, details={'was_impossible': False}),
#  Prediction(uid='A15Q2L6DYRTFIU', iid='B00404LAPQ', r_ui=5.0, est=4.593850179789943, details={'was_impossible': False}),
#  Prediction(uid='A5MCDQ60DWUEV', iid='B00114LG7K', r_ui=2.0, est=4.223872380984053, details={'was_impossible': False}),
#  Prediction(uid='A3HSDV9Y0TV5Z2', iid='B00822SZ2S', r_ui=5.0, est=4.518999638849403, details={'was_impossible': False}),
#  Prediction(uid='AFFVUZEGP1FDQ', iid='B004HKJTT2', r_ui=4.0, est=4.107371403844232, details={'was_impossible': False}),
#  Prediction(uid='AN2IZT80ZUNJN', iid='B007CAQTKG', r_ui=5.0, est=4.071693966200379, details={'was_impossible': False}),
#  Prediction(uid='AONUCJBC85BL', iid='B0001FTVEK', r_ui=1.0, est=3.749914460826204, details={'was_impossible': False}),
#  Prediction(uid='A11D1KHM7DVOQK', iid='B0007ZAK4O', r_ui=5.0, est=3.5761026468706945, details={'was_impossible': False}),
#  Prediction(uid='A1ZVFCPHCWFV71', iid='B00005RKSK', r_ui=5.0, est=4.359704993506735, details={'was_impossible': False}),
#  Prediction(uid='A2ED50E3KWKUKW', iid='B001N44ULM', r_ui=4.0, est=4.51740216542182, details={'was_impossible': False}),
#  Prediction(uid='A2SZLNSI5KOQJT', iid='B0058D8D94', r_ui=4.0, est=4.130396238656265, details={'was_impossible': False}),
#  Prediction(uid='A3QDY9I0CNMD2W', iid='B000096B01', r_ui=5.0, est=4.423030555069781, details={'was_impossible': False}),
#  Prediction(uid='AAR7CEPXYJA0T', iid='B0030BJEUS', r_ui=3.0, est=3.8883302351585827, details={'was_impossible': False}),
#  Prediction(uid='A213J54E63SYOP', iid='B008CXTX7S', r_ui=4.0, est=3.964145262435104, details={'was_impossible': False}),
#  Prediction(uid='A3077MQTAKOVFZ', iid='B005FVNGRI', r_ui=5.0, est=4.339342486102816, details={'was_impossible': False}),
#  Prediction(uid='AH5BCMZELZSKG', iid='B000VJRSB4', r_ui=5.0, est=4.14619223891436, details={'was_impossible': False}),
#  Prediction(uid='ADZF3QDGSZE7K', iid='B002JTX8T0', r_ui=5.0, est=4.219062760598037, details={'was_impossible': False}),
#  Prediction(uid='A27GITTN6AVW5I', iid='B001DXGBII', r_ui=5.0, est=4.21107122716471, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B002ZIN9DU', r_ui=5.0, est=4.303653249760783, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B000067RVL', r_ui=5.0, est=4.561975039865545, details={'was_impossible': False}),
#  Prediction(uid='A2XA8CW5DF4MNZ', iid='B00IVPU6GO', r_ui=5.0, est=4.720966511548137, details={'was_impossible': False}),
#  Prediction(uid='ALQ4USPEQ9L5N', iid='B00BEHQKPC', r_ui=2.0, est=4.039287488938024, details={'was_impossible': False}),
#  Prediction(uid='A19EKT8H85AKO5', iid='B000EEU2YG', r_ui=5.0, est=4.455305827076394, details={'was_impossible': False}),
#  Prediction(uid='ABDR6IJ93HFIO', iid='B00E83AM44', r_ui=5.0, est=4.696625845337878, details={'was_impossible': False}),
#  Prediction(uid='AXU8RH1DEV21H', iid='B005CLPP84', r_ui=5.0, est=4.5529238283884315, details={'was_impossible': False}),
#  Prediction(uid='A1YEPFLLH42OU1', iid='B001EQQW1A', r_ui=5.0, est=4.458200603588701, details={'was_impossible': False}),
#  Prediction(uid='ATDE9JYCPI0L1', iid='B004CR3XEW', r_ui=3.0, est=3.9940300719647226, details={'was_impossible': False}),
#  Prediction(uid='A3G7BEJJCPD6DS', iid='B00G6CLN3Y', r_ui=2.0, est=3.576573473287348, details={'was_impossible': False}),
#  Prediction(uid='A319Y83RT0MRVR', iid='B00D96LZ6K', r_ui=5.0, est=4.384458337403702, details={'was_impossible': False}),
#  Prediction(uid='A3J6Q0Y0SKY7AR', iid='B002JPITXY', r_ui=5.0, est=4.357819664751066, details={'was_impossible': False}),
#  Prediction(uid='A17BUUBOU0598B', iid='B0054L8N7M', r_ui=4.0, est=3.792205136311214, details={'was_impossible': False}),
#  Prediction(uid='A1QNYLBG73QRNF', iid='B008OPSWHQ', r_ui=4.0, est=3.8936581919725404, details={'was_impossible': False}),
#  Prediction(uid='AWPODHOB4GFWL', iid='B000FJ89UO', r_ui=5.0, est=4.2808391843358935, details={'was_impossible': False}),
#  Prediction(uid='A1SX9PHJWTDMF9', iid='B0010HE2CY', r_ui=5.0, est=4.62689047755713, details={'was_impossible': False}),
#  Prediction(uid='A10H24TDLK2VDP', iid='B000FL2DRC', r_ui=1.0, est=4.112582584637289, details={'was_impossible': False}),
#  Prediction(uid='A2EHYCA29NSQLU', iid='B007TLCM2C', r_ui=1.0, est=2.91880539737324, details={'was_impossible': False}),
#  Prediction(uid='A22MANL4US4RMY', iid='B007NJ0S1W', r_ui=5.0, est=4.580793258965963, details={'was_impossible': False}),
#  Prediction(uid='A294BKN913UOGP', iid='B00007EDYY', r_ui=5.0, est=4.542229472466721, details={'was_impossible': False}),
#  Prediction(uid='AT53ZTTO707MB', iid='B0078LN0K6', r_ui=4.0, est=4.343731360425418, details={'was_impossible': False}),
#  Prediction(uid='A20L63B48RPSOH', iid='B00B9OTEVM', r_ui=3.0, est=3.9781234169864788, details={'was_impossible': False}),
#  Prediction(uid='A3IOQ7NVVLAUEE', iid='B000IF51UQ', r_ui=5.0, est=4.358630713112356, details={'was_impossible': False}),
#  Prediction(uid='A1DO9LRCO23EOM', iid='B0017PG8KS', r_ui=5.0, est=4.501458993065811, details={'was_impossible': False}),
#  Prediction(uid='A303SNZ4AR7TDQ', iid='B005IA843W', r_ui=5.0, est=4.334361907455728, details={'was_impossible': False}),
#  Prediction(uid='A8WEXFRWX1ZHH', iid='B00DTWBRU8', r_ui=2.0, est=3.436729482361681, details={'was_impossible': False}),
#  Prediction(uid='A18OTCHQ6MXD6X', iid='B008MNLU7Y', r_ui=4.0, est=4.251549539657046, details={'was_impossible': False}),
#  Prediction(uid='A32T2H8150OJLU', iid='B00AWLCJ6K', r_ui=4.0, est=4.448048281824457, details={'was_impossible': False}),
#  Prediction(uid='A3CG93783LP0FO', iid='B002FYL7PG', r_ui=5.0, est=4.193555665960401, details={'was_impossible': False}),
#  Prediction(uid='A11KQADBYE0UZL', iid='B0036Q7MV0', r_ui=5.0, est=4.745370531577893, details={'was_impossible': False}),
#  Prediction(uid='A3HQAPXAJV7PRX', iid='B004P7GAPI', r_ui=5.0, est=4.068452481512679, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B002TOJXNU', r_ui=4.0, est=4.160955925926241, details={'was_impossible': False}),
#  Prediction(uid='A10ZBR6O8S8OCY', iid='B005UA65YK', r_ui=3.0, est=3.855239528210471, details={'was_impossible': False}),
#  Prediction(uid='A2JMJVNTBL7K7E', iid='B00ESLEAFI', r_ui=5.0, est=3.861766271838613, details={'was_impossible': False}),
#  Prediction(uid='A1Y85GQ09Y95JL', iid='B00005Y1S2', r_ui=5.0, est=3.5821050953023548, details={'was_impossible': False}),
#  Prediction(uid='A1FR68QH6Z4YZM', iid='B00005LE72', r_ui=4.0, est=4.4347393123889125, details={'was_impossible': False}),
#  Prediction(uid='A3963R7EPE3A7E', iid='B0007MXZB2', r_ui=4.0, est=4.39505775443734, details={'was_impossible': False}),
#  Prediction(uid='AU2UJF4I7KAWL', iid='B005EN32RG', r_ui=5.0, est=4.272384503727755, details={'was_impossible': False}),
#  Prediction(uid='A3R1GJY2MY8041', iid='B0014DURIW', r_ui=5.0, est=4.783698093211228, details={'was_impossible': False}),
#  Prediction(uid='AC1YLEFC9AN5X', iid='B00829TIEK', r_ui=5.0, est=4.240909466495424, details={'was_impossible': False}),
#  Prediction(uid='A225G2TFM76GYX', iid='B00119T6NQ', r_ui=5.0, est=4.56892247722991, details={'was_impossible': False}),
#  Prediction(uid='AW6FQE5QRF2LM', iid='B006W8U2MU', r_ui=4.0, est=4.913930984011181, details={'was_impossible': False}),
#  Prediction(uid='A23ZNGL704AW7O', iid='B00ECKG706', r_ui=5.0, est=4.267552820393767, details={'was_impossible': False}),
#  Prediction(uid='A84FLVDK2R5JF', iid='B0054YF0C0', r_ui=2.0, est=3.2446107575484477, details={'was_impossible': False}),
#  Prediction(uid='A3EHJ5519LG7TR', iid='B008OEHPKM', r_ui=5.0, est=4.171833354871956, details={'was_impossible': False}),
#  Prediction(uid='A3VBZDYGHF4NK8', iid='B00AXVXXNC', r_ui=5.0, est=4.463035962406219, details={'was_impossible': False}),
#  Prediction(uid='A18S2VGUH9SCV5', iid='B0076POAI0', r_ui=4.0, est=3.573348194993182, details={'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B00A81SXHI', r_ui=5.0, est=4.633655142539437, details={'was_impossible': False}),
#  Prediction(uid='A37IRE9GZ0CZ7I', iid='B008OEHV6U', r_ui=5.0, est=3.923411558340971, details={'was_impossible': False}),
#  Prediction(uid='A2GMZZ6TDYOHY7', iid='B00006RVPW', r_ui=5.0, est=4.717697071714474, details={'was_impossible': False}),
#  Prediction(uid='A294BKN913UOGP', iid='B0015DYMVO', r_ui=5.0, est=4.480163049375525, details={'was_impossible': False}),
#  Prediction(uid='A1VLE2SH9J8WYS', iid='B000RQSGYO', r_ui=5.0, est=4.505018705225089, details={'was_impossible': False}),
#  Prediction(uid='A2NJQF2UI60VGT', iid='B009LENJ90', r_ui=4.0, est=4.381626400673371, details={'was_impossible': False}),
#  Prediction(uid='A2I18AO597DSDI', iid='B001OOZ1X2', r_ui=5.0, est=4.1006278535248875, details={'was_impossible': False}),
#  Prediction(uid='A2NU9H8H5MJZSL', iid='B00904JILO', r_ui=2.0, est=2.732147538365487, details={'was_impossible': False}),
#  Prediction(uid='A36IHC0K68NS2', iid='B00HFW1DY8', r_ui=3.0, est=3.7846825925750265, details={'was_impossible': False}),
#  Prediction(uid='AWH2AY17ZU7W2', iid='B005IHAIJ8', r_ui=5.0, est=4.339992433816635, details={'was_impossible': False}),
#  Prediction(uid='A341HCMGNZCBIT', iid='B0011ZCDKS', r_ui=5.0, est=4.847093985648078, details={'was_impossible': False}),
#  Prediction(uid='A3K91X9X2ARDOK', iid='B0012IJYZ6', r_ui=5.0, est=4.475435449291247, details={'was_impossible': False}),
#  Prediction(uid='AT28RL25Q2OLK', iid='B00836H2CC', r_ui=4.0, est=4.366664585910984, details={'was_impossible': False}),
#  Prediction(uid='A2HKUM9OEBQKDW', iid='B009K62HQ0', r_ui=5.0, est=4.374409358160528, details={'was_impossible': False}),
#  Prediction(uid='APOGXH3A74CM3', iid='B003WU6KFO', r_ui=5.0, est=4.651481735721169, details={'was_impossible': False}),
#  Prediction(uid='A3D6OI36USYOU1', iid='B00B3JLXSA', r_ui=5.0, est=4.201412073147495, details={'was_impossible': False}),
#  Prediction(uid='A3LWC833HQIG7J', iid='B00452V66G', r_ui=3.0, est=4.309702837826159, details={'was_impossible': False}),
#  Prediction(uid='A5JLAU2ARJ0BO', iid='B000BM6Z60', r_ui=2.0, est=3.8402872285698435, details={'was_impossible': False}),
#  Prediction(uid='A33775AIB1A664', iid='B001441Y56', r_ui=4.0, est=3.962063971463497, details={'was_impossible': False}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B000CDG4TQ', r_ui=4.0, est=4.273094028890275, details={'was_impossible': False}),
#  Prediction(uid='A1W4F91DH3XPB2', iid='B0023B14TK', r_ui=5.0, est=4.170000342113206, details={'was_impossible': False}),
#  Prediction(uid='A1K4G5YJDJQI6Q', iid='B003VAHYXW', r_ui=3.0, est=3.19715761695651, details={'was_impossible': False}),
#  Prediction(uid='A274MXTX3DYLUV', iid='B004GQN768', r_ui=5.0, est=4.29757984999122, details={'was_impossible': False}),
#  Prediction(uid='A3V0YR50F1XSKP', iid='B00763WKZW', r_ui=5.0, est=4.46846939606215, details={'was_impossible': False}),
#  Prediction(uid='A11ULAZ4B5ZXC8', iid='B000N99BBC', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='A2WJ5XSE4I9F55', iid='B001KUYF5K', r_ui=4.0, est=3.524833410801268, details={'was_impossible': False}),
#  Prediction(uid='A1PVJICI412IN4', iid='B00E9QK2MW', r_ui=4.0, est=3.9747615588979803, details={'was_impossible': False}),
#  Prediction(uid='A35KBAQ4VBNQ6L', iid='B001BO7PHA', r_ui=5.0, est=4.545323727982314, details={'was_impossible': False}),
#  Prediction(uid='A3077MQTAKOVFZ', iid='B005HIS6JM', r_ui=3.0, est=4.222418385730808, details={'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B00GO1UV4E', r_ui=5.0, est=4.474628008744918, details={'was_impossible': False}),
#  Prediction(uid='A1UTM65Y3G9HUL', iid='B00C9FLSLY', r_ui=4.0, est=4.108871385178677, details={'was_impossible': False}),
#  Prediction(uid='A10PEXB6XAQ5XF', iid='B0042BUXG4', r_ui=1.0, est=3.8071768596209, details={'was_impossible': False}),
#  Prediction(uid='A34LQ791ACZ0JC', iid='B003L62T7W', r_ui=5.0, est=4.7599228289828455, details={'was_impossible': False}),
#  Prediction(uid='A3Q4TYJVAM4IRM', iid='B000P9ZG00', r_ui=5.0, est=4.317074624304221, details={'was_impossible': False}),
#  Prediction(uid='A1X2LENOF84LCQ', iid='B00007KDVI', r_ui=2.0, est=3.4125703078315106, details={'was_impossible': False}),
#  Prediction(uid='AG35JCCQWDRCS', iid='B008JCVF0U', r_ui=5.0, est=4.534229745764611, details={'was_impossible': False}),
#  Prediction(uid='AUK79PXTAOJP9', iid='B000068O3C', r_ui=5.0, est=4.592304533051135, details={'was_impossible': False}),
#  Prediction(uid='AZBXKUH4AIW3X', iid='B00000J4GE', r_ui=4.0, est=3.9713837214472907, details={'was_impossible': False}),
#  Prediction(uid='AEAFHD09X8044', iid='B001G5ZAC6', r_ui=5.0, est=4.2691423669593656, details={'was_impossible': False}),
#  Prediction(uid='A1VR1HIOVQWN09', iid='B0012S4APK', r_ui=5.0, est=4.453326085590301, details={'was_impossible': False}),
#  Prediction(uid='A212MDP6K4VJS5', iid='B001UI2FPE', r_ui=5.0, est=4.8013486986435865, details={'was_impossible': False}),
#  Prediction(uid='A3VC74TJ06WDDD', iid='B003D8OSPY', r_ui=5.0, est=4.378702582079886, details={'was_impossible': False}),
#  Prediction(uid='A23ONMGKEWDG4M', iid='B0043332OG', r_ui=5.0, est=4.344254513941983, details={'was_impossible': False}),
#  Prediction(uid='A1KD8NJPZ01R37', iid='B0009JKVZG', r_ui=5.0, est=3.6246847670776132, details={'was_impossible': False}),
#  Prediction(uid='A1EH2S92FHWZRP', iid='B004CLYEA0', r_ui=5.0, est=4.103247242961729, details={'was_impossible': False}),
#  Prediction(uid='A3IMALU0RM8UT9', iid='B000VZS2EU', r_ui=5.0, est=4.603170814751044, details={'was_impossible': False}),
#  Prediction(uid='A8P6GIIQ6YQV8', iid='B00ENPQ1GK', r_ui=4.0, est=4.176068118044794, details={'was_impossible': False}),
#  Prediction(uid='A2HRHF83I3NDGT', iid='B006VCP72W', r_ui=5.0, est=4.6963396398206205, details={'was_impossible': False}),
#  Prediction(uid='AAR7CEPXYJA0T', iid='B00002EQCW', r_ui=2.0, est=3.963045070799861, details={'was_impossible': False}),
#  Prediction(uid='A215WH6RUDUCMP', iid='B00F1CRTLK', r_ui=5.0, est=4.652907448370553, details={'was_impossible': False}),
#  Prediction(uid='AQ55H30MZSV0Q', iid='B000CLT67A', r_ui=4.0, est=3.6092060851840517, details={'was_impossible': False}),
#  Prediction(uid='A2QI2NTDTMK2FV', iid='B004GK0GKO', r_ui=5.0, est=3.7262952007723156, details={'was_impossible': False}),
#  Prediction(uid='A20H1M28WLI9J2', iid='B002TOJXOY', r_ui=4.0, est=4.053262943206263, details={'was_impossible': False}),
#  Prediction(uid='ADKZOXAOV8EXD', iid='B007JGAR8I', r_ui=4.0, est=3.989569869241256, details={'was_impossible': False}),
# ...
#  Prediction(uid='A24HWYHR28JJ7A', iid='B001AYW91I', r_ui=4.0, est=4.187242176943217, details={'was_impossible': False}),
#  Prediction(uid='A23QII83UGZP5U', iid='B00524W8CM', r_ui=5.0, est=4.133051204564285, details={'was_impossible': False}),
#  Prediction(uid='A3DWO5RJDA430F', iid='B002YTDE5I', r_ui=5.0, est=4.310501540033897, details={'was_impossible': False}),
#  Prediction(uid='AYB4ELCS5AM8P', iid='B000VZS2EU', r_ui=5.0, est=4.689587318478822, details={'was_impossible': False}),
#  Prediction(uid='A1FLJCHN5CG5M5', iid='B00009R94Q', r_ui=5.0, est=4.430963820893945, details={'was_impossible': False}),
#  Prediction(uid='A2NOW4U7W3F7RI', iid='B00D029NNA', r_ui=4.0, est=4.604625774431741, details={'was_impossible': False}),
#  Prediction(uid='A3P1508PZ0UADD', iid='B00AU0HMGA', r_ui=3.0, est=3.855126320040001, details={'was_impossible': False}),
#  Prediction(uid='AT8V3JOZD3KWK', iid='B00BDS3N1G', r_ui=3.0, est=4.15489102139412, details={'was_impossible': False}),
#  Prediction(uid='A1TQZUSOU22E9M', iid='B002U334NK', r_ui=5.0, est=4.568179787397583, details={'was_impossible': False}),
#  Prediction(uid='A2QDOJFFLFGF18', iid='B00DQZQG3G', r_ui=5.0, est=4.583903167789963, details={'was_impossible': False}),
#  Prediction(uid='ASJSX783R5HTZ', iid='B0045CAOPK', r_ui=1.0, est=3.819382355601792, details={'was_impossible': False}),
#  Prediction(uid='A1TR1R2QKWRSRA', iid='B000SBCA7C', r_ui=4.0, est=4.009082677676564, details={'was_impossible': False}),
#  Prediction(uid='A1PL7QILVQV3IF', iid='B00D29Z1TQ', r_ui=4.0, est=4.059452646357292, details={'was_impossible': False}),
#  Prediction(uid='A3LWC833HQIG7J', iid='B009LPV766', r_ui=5.0, est=4.210117124941512, details={'was_impossible': False}),
#  Prediction(uid='AQIJ3ZEEVCIKU', iid='B003IT6Z86', r_ui=3.0, est=4.119114756471208, details={'was_impossible': False}),
#  Prediction(uid='A3NHUQ33CFH3VM', iid='B008X9Z528', r_ui=5.0, est=4.192577843211973, details={'was_impossible': False}),
#  Prediction(uid='A3V8P0O224OBDB', iid='B00139TXY6', r_ui=5.0, est=4.538503054845663, details={'was_impossible': False}),
#  Prediction(uid='ATS2855497V0I', iid='B003GR0WGQ', r_ui=5.0, est=4.046452868452804, details={'was_impossible': False}),
#  Prediction(uid='A2T689YVOAYGGD', iid='B0000936B6', r_ui=5.0, est=4.314520226144625, details={'was_impossible': False}),
#  Prediction(uid='A185O1MX1RP964', iid='B0009RKL62', r_ui=5.0, est=4.366452590652198, details={'was_impossible': False}),
#  Prediction(uid='A1UTM65Y3G9HUL', iid='B00FXLMMK2', r_ui=1.0, est=3.8331106355575466, details={'was_impossible': False}),
#  Prediction(uid='AWPODHOB4GFWL', iid='B0009GUDVQ', r_ui=5.0, est=4.3979803217243445, details={'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B000CR78C4', r_ui=5.0, est=4.3546109185687705, details={'was_impossible': False}),
#  Prediction(uid='AEL6CQNQXONBX', iid='B00BI4JXGO', r_ui=3.0, est=4.266961313137667, details={'was_impossible': False}),
#  Prediction(uid='A3HXGSMCIOZEW8', iid='B004D9WXCM', r_ui=5.0, est=4.512959116528878, details={'was_impossible': False}),
#  Prediction(uid='A27GITTN6AVW5I', iid='B007PA1K84', r_ui=4.0, est=4.183851945024835, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B001OC6DCW', r_ui=5.0, est=4.67865648436546, details={'was_impossible': False}),
#  Prediction(uid='A2T689YVOAYGGD', iid='B0034CSTFY', r_ui=5.0, est=4.256371502996718, details={'was_impossible': False}),
#  Prediction(uid='A2B7BUH8834Y6M', iid='B000BNP2KE', r_ui=5.0, est=4.413469666640356, details={'was_impossible': False}),
#  Prediction(uid='AHD3NZHDUZ5I6', iid='B00252W1YY', r_ui=5.0, est=4.264649987472923, details={'was_impossible': False}),
#  Prediction(uid='A3CIET1UO3G51E', iid='B005JPG4TW', r_ui=5.0, est=4.254206966691215, details={'was_impossible': False}),
#  Prediction(uid='A1YVO5V1SO18DZ', iid='B000OX06DY', r_ui=5.0, est=4.35451187931979, details={'was_impossible': False}),
#  Prediction(uid='A1MNN0ZMHYPJDU', iid='B004BBHYBM', r_ui=5.0, est=4.653730753168116, details={'was_impossible': False}),
#  Prediction(uid='A2K6CDQ9HZ359G', iid='B00114PN1U', r_ui=5.0, est=4.453850896230745, details={'was_impossible': False}),
#  Prediction(uid='A3GX0FAMEXV6FB', iid='B005B3VO24', r_ui=4.0, est=4.1668940071497405, details={'was_impossible': False}),
#  Prediction(uid='A2EN82VBJT44QP', iid='B00017LSPI', r_ui=5.0, est=4.775087427690465, details={'was_impossible': False}),
#  Prediction(uid='A29KJ32G75L7G9', iid='B00GUA1V0M', r_ui=5.0, est=4.516285768418218, details={'was_impossible': False}),
#  Prediction(uid='A3LPL35P7FH78Y', iid='B00004Z6N6', r_ui=5.0, est=4.722959390252948, details={'was_impossible': False}),
#  Prediction(uid='A1VS1LL905P5L5', iid='B00G024X32', r_ui=5.0, est=4.309351867778782, details={'was_impossible': False}),
#  Prediction(uid='A1PM7HH4F77NEH', iid='B00004Z5LZ', r_ui=5.0, est=4.053862001037413, details={'was_impossible': False}),
#  Prediction(uid='A2L4W1M5YU5QX3', iid='B005HJWWW8', r_ui=5.0, est=3.816164976677962, details={'was_impossible': False}),
#  Prediction(uid='A215WH6RUDUCMP', iid='B005QCDY50', r_ui=2.0, est=4.152706647873128, details={'was_impossible': False}),
#  Prediction(uid='A198CCH4NNLI2E', iid='B0001IXUDK', r_ui=1.0, est=2.765331382993928, details={'was_impossible': False}),
#  Prediction(uid='A1OGCPMSIVK7G4', iid='B00989QKA8', r_ui=5.0, est=4.053524837552756, details={'was_impossible': False}),
#  Prediction(uid='A1P4XD7IORSEFN', iid='B000X3C8L8', r_ui=4.0, est=3.9550737517089725, details={'was_impossible': False}),
#  Prediction(uid='A2PB325LKXYDOL', iid='B00009XFVR', r_ui=5.0, est=4.805183256238967, details={'was_impossible': False}),
#  Prediction(uid='A23NSKTMSPPBTR', iid='B0000AC88K', r_ui=2.0, est=3.7613596860163567, details={'was_impossible': False}),
#  Prediction(uid='A38RMU1Y5TDP9', iid='B0033WSDR4', r_ui=5.0, est=4.357936773122628, details={'was_impossible': False}),
#  Prediction(uid='A38KK0SZYEH5UD', iid='B002FL507A', r_ui=4.0, est=4.202038568392033, details={'was_impossible': False}),
#  Prediction(uid='A32HSNCNPRUMTR', iid='9985696999', r_ui=2.0, est=3.782144758228034, details={'was_impossible': False}),
#  Prediction(uid='A1RJKTYC03L0JY', iid='B008OYMTEE', r_ui=5.0, est=4.203174973522536, details={'was_impossible': False}),
#  Prediction(uid='A18GJ9MYYO6GCQ', iid='B002MPPHKY', r_ui=4.0, est=4.708116040865642, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B000R9AAJA', r_ui=3.0, est=4.158447191008686, details={'was_impossible': False}),
#  Prediction(uid='A18EA7MNLXP9H5', iid='B001RB24S2', r_ui=5.0, est=4.158441439684402, details={'was_impossible': False}),
#  Prediction(uid='A3284KYDZ00BZA', iid='B00BUJBHGG', r_ui=4.0, est=4.264751413928639, details={'was_impossible': False}),
#  Prediction(uid='A19X4BF861LQST', iid='B000I4WHD6', r_ui=5.0, est=4.014494038990929, details={'was_impossible': False}),
#  Prediction(uid='A24QFMD1RXLJMB', iid='B003Y60DZO', r_ui=4.0, est=4.068878878807826, details={'was_impossible': False}),
#  Prediction(uid='A3QX0ERX4D03TF', iid='B001V9KG0I', r_ui=5.0, est=4.2519227211461175, details={'was_impossible': False}),
#  Prediction(uid='A16HXVNPU5TCGE', iid='B000FCT9Y6', r_ui=5.0, est=4.600977368081158, details={'was_impossible': False}),
#  Prediction(uid='A1UQUDT2Q0YENM', iid='B004CLYEE6', r_ui=4.0, est=4.0441582270887855, details={'was_impossible': False}),
#  Prediction(uid='ARX0KOX5Q01BJ', iid='B000NJP4PY', r_ui=5.0, est=3.936880803831195, details={'was_impossible': False}),
#  Prediction(uid='A3DOPYDOS49I3T', iid='B007FPIQZ4', r_ui=5.0, est=4.723381134920528, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B001NPDA44', r_ui=4.0, est=4.304650984856216, details={'was_impossible': False}),
#  Prediction(uid='A3VI2VETB90ZG5', iid='B00B7Y7M1S', r_ui=4.0, est=4.414036894003639, details={'was_impossible': False}),
#  Prediction(uid='AWJWCKB92RJX2', iid='B000LRMS66', r_ui=4.0, est=4.196544892206676, details={'was_impossible': False}),
#  Prediction(uid='A1QJ10LEINDRWW', iid='B003XDZKMO', r_ui=4.0, est=4.215597371145301, details={'was_impossible': False}),
#  Prediction(uid='A3TRY87JJCA5Y8', iid='B00009R957', r_ui=2.0, est=4.016779502120797, details={'was_impossible': False}),
#  Prediction(uid='AM0QLU79O05JR', iid='B0057AVXJA', r_ui=5.0, est=3.3024300331969214, details={'was_impossible': False}),
#  Prediction(uid='A3D2VIUT2HWP0Z', iid='B005LAIFE2', r_ui=5.0, est=4.6064381095385185, details={'was_impossible': False}),
#  Prediction(uid='A2B7BUH8834Y6M', iid='B0083T1KDG', r_ui=5.0, est=4.438102231164719, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B0039213XY', r_ui=5.0, est=4.187940159178947, details={'was_impossible': False}),
#  Prediction(uid='A1K4G5YJDJQI6Q', iid='B004WCPMBE', r_ui=2.0, est=3.2035247016303363, details={'was_impossible': False}),
#  Prediction(uid='A1VFX417XDNWIU', iid='B0000X0VU6', r_ui=4.0, est=4.174012563801601, details={'was_impossible': False}),
#  Prediction(uid='A1EKSETIBS9ETQ', iid='B00005LEOO', r_ui=4.0, est=4.219669020559004, details={'was_impossible': False}),
#  Prediction(uid='A1T7EHCMZ92TKC', iid='B001ENOZY4', r_ui=5.0, est=4.381668492620849, details={'was_impossible': False}),
#  Prediction(uid='A38NHXL5257E3B', iid='B00GMGDFPI', r_ui=5.0, est=4.463755835627475, details={'was_impossible': False}),
#  Prediction(uid='ASFW4ZMNZJKDA', iid='B005KTIX50', r_ui=5.0, est=4.442364625564311, details={'was_impossible': False}),
#  Prediction(uid='A11KZ906QD08C5', iid='B002B8ZYPK', r_ui=4.0, est=4.393275015827272, details={'was_impossible': False}),
#  Prediction(uid='A1DQHS7MOVYYYA', iid='B0012GK3MQ', r_ui=4.0, est=4.322814192806989, details={'was_impossible': False}),
#  Prediction(uid='A11D1KHM7DVOQK', iid='B000059L44', r_ui=1.0, est=3.296291112443765, details={'was_impossible': False}),
#  Prediction(uid='A1CMD08Z49PGKQ', iid='B0015YJOK2', r_ui=5.0, est=4.768362938438098, details={'was_impossible': False}),
#  Prediction(uid='A2UQK3DAZ8NO2T', iid='B00138MVBY', r_ui=5.0, est=4.352909949069352, details={'was_impossible': False}),
#  Prediction(uid='A1KY5G5FP31F2F', iid='B001U02JZ8', r_ui=5.0, est=4.683704324972788, details={'was_impossible': False}),
#  Prediction(uid='AOMEH9W6LHC4S', iid='B002VPE1X4', r_ui=5.0, est=4.381014614157167, details={'was_impossible': False}),
#  Prediction(uid='A3V7D0LH8L7BG0', iid='B00AQUO5RI', r_ui=5.0, est=4.55919429953336, details={'was_impossible': False}),
#  Prediction(uid='A1NNMOD9H36Q8E', iid='B00009MDBQ', r_ui=5.0, est=4.299984563680755, details={'was_impossible': False}),
#  Prediction(uid='A3094EPI56GKZ6', iid='B00DQZQHBW', r_ui=5.0, est=4.7262293324577715, details={'was_impossible': False}),
#  Prediction(uid='A6TBR6L2D4XKC', iid='B00FXYTLIK', r_ui=4.0, est=4.058260222082044, details={'was_impossible': False}),
#  Prediction(uid='AEJAGHLC675A7', iid='B0064EL2DK', r_ui=5.0, est=4.704565123265142, details={'was_impossible': False}),
#  Prediction(uid='A35Q0RBM3YNQNF', iid='B0096R5V0M', r_ui=5.0, est=4.509322512511489, details={'was_impossible': False}),
#  Prediction(uid='A1M7HP5CHDXXOU', iid='B002NP13C4', r_ui=4.0, est=4.3709787290464455, details={'was_impossible': False}),
#  Prediction(uid='A9LNWA25IM2DX', iid='B001IOY4Z4', r_ui=5.0, est=4.095154374335085, details={'was_impossible': False}),
#  Prediction(uid='AWH2AY17ZU7W2', iid='B008R91OZ6', r_ui=5.0, est=4.36809380525776, details={'was_impossible': False}),
#  Prediction(uid='AR6APXLK7TJU2', iid='B001U0O7RG', r_ui=1.0, est=4.002654765790064, details={'was_impossible': False}),
#  Prediction(uid='AENULRBQ2IE5I', iid='B001MS0OKU', r_ui=5.0, est=4.567333541292078, details={'was_impossible': False}),
#  Prediction(uid='A38RMU1Y5TDP9', iid='B0010TEOLQ', r_ui=4.0, est=4.429267192081576, details={'was_impossible': False}),
#  Prediction(uid='ATDQ9CGCWTT8D', iid='B0084CCCI4', r_ui=5.0, est=4.309154154544021, details={'was_impossible': False}),
#  Prediction(uid='A1ZA5SXZS8Z3CK', iid='B007PJVB3Y', r_ui=5.0, est=4.558680956660997, details={'was_impossible': False}),
#  Prediction(uid='A2GOHNFBHUU3UI', iid='B001AO4MWW', r_ui=3.0, est=3.771426779418843, details={'was_impossible': False}),
#  Prediction(uid='A1OO9N1MRNQ7K0', iid='B002AULS7C', r_ui=5.0, est=4.676204957076557, details={'was_impossible': False}),
#  Prediction(uid='A1I96OYAUJ3HQE', iid='B00EJPO3GE', r_ui=5.0, est=4.680161006970723, details={'was_impossible': False}),
#  Prediction(uid='A8X8D4BUY5DFU', iid='B000RQSGYO', r_ui=4.0, est=4.212630062136496, details={'was_impossible': False}),
#  Prediction(uid='AOMEH9W6LHC4S', iid='B00ITI058W', r_ui=5.0, est=4.255753989182131, details={'was_impossible': False}),
#  Prediction(uid='A1DO9LRCO23EOM', iid='B00013BN66', r_ui=5.0, est=4.410475850312792, details={'was_impossible': False}),
#  Prediction(uid='A26LD9FQHTM8ZH', iid='B001HN5HOS', r_ui=5.0, est=3.9644577040415876, details={'was_impossible': False}),
#  Prediction(uid='A2WBVO6X3KPMDT', iid='B002NI6SG2', r_ui=5.0, est=4.623806740996519, details={'was_impossible': False}),
#  Prediction(uid='A1FMU4CJLIDHR9', iid='B00519RW1U', r_ui=3.0, est=4.318328838590496, details={'was_impossible': False}),
#  Prediction(uid='A1L1N3J6XNABO2', iid='B0000AI0N1', r_ui=5.0, est=4.634520519405473, details={'was_impossible': False}),
#  Prediction(uid='A2MOD50IHEDH3G', iid='B007HAWUO0', r_ui=5.0, est=4.390822707365603, details={'was_impossible': False}),
#  Prediction(uid='A3SL0HA6422W4M', iid='B00ELAM8LE', r_ui=5.0, est=4.5553698863932786, details={'was_impossible': False}),
#  Prediction(uid='A2LTYEYGKBYXRR', iid='B00JWVSEJM', r_ui=5.0, est=4.692591750430154, details={'was_impossible': False}),
#  Prediction(uid='A1Z16630QMH8Q6', iid='B002V88HFE', r_ui=5.0, est=4.921530341738933, details={'was_impossible': False}),
#  Prediction(uid='A2BMZRO0H7TFCS', iid='B005C95NCY', r_ui=5.0, est=4.1872340062932, details={'was_impossible': False}),
#  Prediction(uid='A3TAS1AG6FMBQW', iid='B0067WUVF4', r_ui=5.0, est=4.6161172295599915, details={'was_impossible': False}),
#  Prediction(uid='A3MQ15651KGVLJ', iid='B005I6EU48', r_ui=5.0, est=4.5448351570976415, details={'was_impossible': False}),
#  Prediction(uid='A225G2TFM76GYX', iid='B001HSOFI2', r_ui=4.0, est=4.514294182321293, details={'was_impossible': False}),
#  Prediction(uid='AYMD77ITD15PT', iid='B001R4CJRU', r_ui=5.0, est=4.296436103692251, details={'was_impossible': False}),
#  Prediction(uid='A2K6CDQ9HZ359G', iid='B000VPOYJC', r_ui=3.0, est=4.293405288794272, details={'was_impossible': False}),
#  Prediction(uid='A2RG1B0K8YBJ4A', iid='B0056ET5RY', r_ui=4.0, est=4.170439757792856, details={'was_impossible': False}),
#  Prediction(uid='ACYZXQ2JKPZKT', iid='B000BMNMAM', r_ui=1.0, est=3.500268554202676, details={'was_impossible': False}),
#  Prediction(uid='A2ZFBTGPDP6PH6', iid='B0007Y836W', r_ui=5.0, est=4.359369623656547, details={'was_impossible': False}),
#  Prediction(uid='A2J96FILPQA01', iid='B0054YQO5C', r_ui=5.0, est=4.708814875897093, details={'was_impossible': False}),
#  Prediction(uid='ANRS196NKFVUU', iid='B008GVETNE', r_ui=5.0, est=4.662407450287828, details={'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B007I5JT4S', r_ui=4.0, est=4.014865926556364, details={'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B004L9MBH6', r_ui=5.0, est=4.374952760187991, details={'was_impossible': False}),
#  Prediction(uid='A3B20R4ZAH0Y2Y', iid='B007AHJNF4', r_ui=5.0, est=4.308893390390508, details={'was_impossible': False}),
#  Prediction(uid='A2SH6A32BE6NEV', iid='B0002BEPJY', r_ui=5.0, est=4.367403092854272, details={'was_impossible': False}),
#  Prediction(uid='A30JPZ9TZ7I61U', iid='B0009WQFVC', r_ui=2.0, est=4.163741313223073, details={'was_impossible': False}),
#  Prediction(uid='A1UQBFCERIP7VJ', iid='B00J5DGDCM', r_ui=5.0, est=4.615641716695409, details={'was_impossible': False}),
#  Prediction(uid='A3LZA698SQPCXE', iid='B005KKJPCO', r_ui=5.0, est=4.39310872794354, details={'was_impossible': False}),
#  Prediction(uid='A197T2N6RU7K56', iid='B001BYB620', r_ui=5.0, est=4.490985065493096, details={'was_impossible': False}),
#  Prediction(uid='A2M9ME0N2S3R39', iid='B0054L8N7M', r_ui=5.0, est=4.38141024796948, details={'was_impossible': False}),
#  ...]

# %%
from collections import defaultdict
def get_top_n(predictions,n=10):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
# Genrating top 5 recommendation for user 
top_n = get_top_n(predictions, n= 5)

# %%
# Print the recommended items for each user
user_list= []
for uid, user_ratings in top_n.items():
    single_user= (uid, [iid for (iid, _) in user_ratings])
    user_list.append(single_user)

# %%
recommendation_for_user = pd.DataFrame(user_list,columns=['userid','recommended electronics_id'])

# %%
# all recommendations for al user
recommendation_for_user
# Out:
#               userid                         recommended electronics_id
# 0     A2QRXQPHDMFCQV  [B009NB8WR0, B008O2HWTI, B00AQUO5RI, B005CWHZP...
# 1      AMWL7XIWIPXEZ  [B007M506WS, B001U0OGQS, B006VCP72W, B00006HSD...
# 2     A2PJH18W4XHTZW  [B002WE6D44, B005PZDVF6, B001RB21JY, B00CBE17J...
# 3     A3IUW081KXD3PE  [B0043M668G, B005I6EU48, B001IJYLL6, B001O9EUS...
# 4      AWPODHOB4GFWL  [B001TH7GSW, B00DTZYHX4, B00CMJZAOI, B002WE4HE...
# ...              ...                                                ...
# 1535  A16CVJUQOB6GIB  [B004I540HW, B00455M9AK, B00ARYTBFY, B007BJC75...
# 1536  A2HPJKM7L4EOQB  [B0017RQ98W, B00000J48J, B000EBK3FW, B001L9O73...
# 1537   A57Q87B0TC9IJ  [B00005UM9R, B007ZZ6OW6, B007PJ4PLO, B000050NP...
# 1538  A3KTWUXXB8KKC7  [B006DDT6JO, B000RZQZM0, B000EPJL1A, B000E21TY...
# 1539   ANEDXRFDZDL18  [B001ELK2NY, B00EOI2SR2, B00JAZGUBE, B0071BTJP...
#
# [1540 rows x 2 columns]

# %%
user_id = 'A1NMM0RDRF6R84'
def rec_5 (user_id):
    return recommendation_for_user[recommendation_for_user['userid']== user_id]['recommended electronics_id'].tolist()

# %%
top_5_recommendation= pd.DataFrame(rec_5(user_id))
top_5_recommendation.iloc[0,0]
# Out:
# 'B002PX9BX2'

# %% [markdown]
# >- Get top - K ( K = 5) recommendations. Since our goal is to recommend new products to each user based on his/her habits, we will recommend 5 new products

# %%
# Getting all the products rated by given user 
product_id_check = df_50_greater[df_50_greater['userid']== 'A1NMM0RDRF6R84']
# product_id_check contains all the product rated by user an

# %%
# checking the recommended product exist in user rating history or not  
product_id_check[product_id_check['productid']== top_5_recommendation.iloc[0,0] ]
# Out:
#                  userid   productid  rating
# 2773978  A1NMM0RDRF6R84  B002PX9BX2     5.0

# %%
# conformation that we are recommending same product which is rated by user 
product_id_check[product_id_check['productid'] =='B000QUUFRW']
# Out:
#                  userid   productid  rating
# 1312777  A1NMM0RDRF6R84  B000QUUFRW     5.0

# %% [markdown]
# >- It is observed that we are not able to recommendan any new electronic product

# %%
#recommendation_for_user['recommended electronics_id']

# %%
# Recommended movies suggested 
reco_list= ['B000QUUFRW', 'B0040JHVC2', 'B00007IFED', 'B004WB8EYM', 'B002J9HBIO']

# %%
# Uncommon products should be present product rated by user and recommendations
set(reco_list) - set(product_id_check['productid'])
# Out:
# set()

# %% [markdown]
# >- As we can observe that set is empty which gives us clear idea that no new electronic items were recommended new

# %%
## Creating Dataframe from predictions to fetch new products
def get_Iu(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
df_pred = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
df_pred['Iu'] = df_pred.uid.apply(get_Iu)
df_pred['Ui'] = df_pred.iid.apply(get_Ui)
df_pred['err'] = abs(df_pred.est - df_pred.rui)
best_predictions = df_pred.sort_values(by='err')[:]
#worst_predictions = df_pred.sort_values(by='err')[-10:]

# %%
# DataFrame to observe inner iid and outer iids for better understanding 
best_predictions
# Out:
#                   uid         iid  rui       est                    details  \
# 18313  A1H55L0BLPCWYF  B0046TJG1U  5.0  5.000000  {'was_impossible': False}
# 37630  A2PB325LKXYDOL  B000HPV3RW  5.0  5.000000  {'was_impossible': False}
# 21168  A10O7THJ2O20AG  B006W8U2MU  5.0  5.000000  {'was_impossible': False}
# 33640   A2J96FILPQA01  B0019EHU8G  5.0  5.000000  {'was_impossible': False}
# 18860  A25HBO5V8S8SEA  B003ES5ZUU  5.0  5.000000  {'was_impossible': False}
# ...               ...         ...  ...       ...                        ...
# 13173   AZCE11PSTCH1L  B000BQ7GW8  1.0  4.614935  {'was_impossible': False}
# 6913    AHF4I1FSIHABC  B006TT91TW  1.0  4.627296  {'was_impossible': False}
# 33415  A1KY5G5FP31F2F  B000LRMS66  1.0  4.629463  {'was_impossible': False}
# 31402   A6KL17KKN0A5L  B000JE7GPY  1.0  4.666741  {'was_impossible': False}
# 10963  A3V8P0O224OBDB  B0002L5R78  1.0  4.689766  {'was_impossible': False}
#
#         Iu   Ui       err
# 18313   44   16  0.000000
# 37630   41   40  0.000000
# 21168   56   37  0.000000
# 33640   40   63  0.000000
# 18860  125  117  0.000000
# ...    ...  ...       ...
# 13173   44   37  3.614935
# 6913    50   20  3.627296
# 33415   63   50  3.629463
# 31402   42   41  3.666741
# 10963   45   42  3.689766
#
# [37762 rows x 8 columns]

# %%
# As we have to recomment new elctronics id we should not consider rated ids.
# creating DF of only those elctronic product which are not rated by user

# %%
# all electronics product rated by user 'A1NMM0RDRF6R84'
rated_iid = best_predictions[best_predictions['uid'] == 'AVPNQUVZWMDSX']['iid']

# %%
# all electronics items which are present 
all_iid = best_predictions['iid']

# %%
# Product which are not rated by user which means he haven't purchased it 
not_rated_uid =pd.DataFrame(list(set(all_iid) - set(rated_iid)),columns= ['prod_id'])

# %%
not_rated_uid
# Out:
#           prod_id
# 0      B00D7GGIQE
# 1      B001IEXK8G
# 2      B002NFZSL6
# 3      B0026S3GTQ
# 4      B004Q2X3P2
# ...           ...
# 21193  B00DTPYQBM
# 21194  B000A6TN9I
# 21195  B000PD29HO
# 21196  B00026BQJ6
# 21197  B001IOHAVO
#
# [21198 rows x 1 columns]

# %%
# Finding all the products which we can recommend 
# which means all the product which are not rated by user
# We can select top 5 product which are rated highly 
corpus_for_recomendation = best_predictions[best_predictions['iid'].isin(not_rated_uid['prod_id'])]

# %%
corpus_for_recomendation['est'].sort_values(ascending = False)
# Out:
# 18313    5.000000
# 15883    5.000000
# 6619     5.000000
# 409      5.000000
# 19038    5.000000
#            ...
# 8909     2.591335
# 12631    2.560949
# 13559    2.530726
# 1605     2.443294
# 5400     2.370787
# Name: est, Length: 37373, dtype: float64

# %%
# Recommendations to be done
reco =(( corpus_for_recomendation.sort_values('est',na_position='first',ascending=False))[['iid','est']]).iloc[:5]

# %%
# Printing top 5 recommendation
reco = corpus_for_recomendation[['iid','est']]
reco.iloc[:5]
# Out:
#               iid  est
# 18313  B0046TJG1U  5.0
# 37630  B000HPV3RW  5.0
# 21168  B006W8U2MU  5.0
# 33640  B0019EHU8G  5.0
# 18860  B003ES5ZUU  5.0

# %%
# Writing Defination for genralizing the above steps 
def  recomendation (uid):
    # Finding those product which are not rated by user
    not_rated_items_byUser =pd.DataFrame(list(set(best_predictions['iid']) - 
                                              set(best_predictions[best_predictions['uid'] == uid]['iid']))
                                              ,columns= ['prod_id'])
    # creating New dataframe which consist of only those electronic item which are not rated by user
    Items_to_be_recommended_from = best_predictions[best_predictions['iid'].isin(not_rated_items_byUser['prod_id'])]
    # sorting electronic product in ascending order and slecting top 5 products as a recomendation to a perticular user
    top_5_recommendation = ((Items_to_be_recommended_from.sort_values('est',na_position='first'
                                                                      ,ascending=False))[['iid','est']]).iloc[:5]
    return top_5_recommendation

# %%
# Recommendation for a given user 
recomendation('A1NMM0RDRF6R84')
# Out:
#               iid  est
# 18313  B0046TJG1U  5.0
# 22299  B002K9IHGI  5.0
# 19038  B007PJ4P4G  5.0
# 9334   B000BQ7GW8  5.0
# 367    B000N99BBC  5.0

# %%
# Getting all the products rated by given user 
product_id_check = df_50_greater[df_50_greater['userid']== 'A1NMM0RDRF6R84']
# product_id_check contains all the product rated by user an

# %%
# checking the recommended product exist in user rating history or not  
product_id_check[product_id_check['productid']== 'B006W8U2MU' ]
# Out:
# Empty DataFrame
# Columns: [userid, productid, rating]
# Index: []

# %% [markdown]
# >-  From the above output we can say all recommendation which are given were not rated by user
