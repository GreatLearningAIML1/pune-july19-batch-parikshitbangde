# %% [markdown]
# # Problem Statement -
#
# - Build your own recommendation system for products on an e-commerce website like Amazon.com.
#
# - Dataset Link - https://drive.google.com/file/d/1ClBptsK3V5KgKXtK2GSRzFNAW7GnTPDW/view?usp=sharing

# %% [markdown]
# # Dataset columns
# - first three columns are userId, productId, and ratings and the fourth column is timestamp. You can discard the timestamp column as in this case you may not need to use it.

# %% [markdown]
# # Source
# - Amazon Reviews data (http://jmcauley.ucsd.edu/data/amazon/)  The repository has several datasets. For this case study, we are using the Electronics dataset

# %% [markdown]
# ## Please do the analysis based on steps( 1 to 8) as given below -
#
# Steps -
#
# 1. Read and explore the given dataset.  ( Rename column/add headers, plot histograms, find data characteristics)
# 2. Take a subset of the dataset to make it less sparse/ denser. ( For example, keep the users only who has given 50 or more number of ratings )
# 3. Split the data randomly into train and test dataset. ( For example, split it in 70/30 ratio)
# 4. Build Popularity Recommender model.
# 5. Build Collaborative Filtering model.
# 6 Evaluate both the models. ( Once the model is trained on the training data, it can be used to compute the error (like RMSE) on predictions made on the test data.) You can also use a different method to evaluate the models.
# 7. Get top - K ( K = 5) recommendations. Since our goal is to recommend new products to each user based on his/her habits, we will recommend 5 new products.
# 8. Summarise your insights.

# %% [markdown]
# ### Please Note -
#
# 1. If you are facing any memory issue while working on this project, create a small subset (Let’s say 10% of data) and work on it.
# 2. If you are stuck at the model evaluation part of this project.
#
# #### Please refer to below links -
#
# 1. https://surprise.readthedocs.io/en/stable/accuracy.html (Links to an external site.)Links to an external site.
# 2. http://surpriselib.com/ (Links to an external site.)Links to an external site. - Getting started, example

# %%
# to ignore warning we can import warnings library 
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the necessary libraries 
import pandas as pd # to read the dataset 
import numpy as np  # for Mathematical opreations 
import matplotlib.pyplot as plt # For visualization 
import seaborn as sns # for visualization

# %%
# To read the dataset 
df = pd.read_csv('ratings_Electronics.csv')

# %%
# setting Collumns Header 
df.columns=['userid','productid','rating','timestamp']

# %%
# To see how our dataframe looks like 
df.head()
# Out:
#            userid   productid  rating   timestamp
# 0  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 1  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 2  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 3  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# 4  A1QGNMC6O1VW39  0511189877     5.0  1397433600

# %%
# Understanding the datatype and number entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824481 entries, 0 to 7824480
# Data columns (total 4 columns):
# userid       object
# productid    object
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 238.8+ MB

# %%
# As we dont need timestam we can drop it 
df = df.drop(['timestamp'],axis=1)

# %%
df.shape
# Out:
# (7824481, 3)

# %%
# Checking Nan values are present or not 
df.isna().sum()
# Out:
# userid       0
# productid    0
# rating       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#             count      mean      std  min  25%  50%  75%  max
# rating  7824481.0  4.012337  1.38091  1.0  3.0  5.0  5.0  5.0

# %%
# Fetting idea of unique values in our dataset 
for i  in df.columns:
    print ('Unique vlaues present in {} are : '.format(i),(df[i].nunique()))
# Out:
# Unique vlaues present in userid are :  4201696
# Unique vlaues present in productid are :  476001
# Unique vlaues present in rating are :  5

# %%
# counting frequency 
count = []
for i in df.columns:
    print ('valuse count for column {} is  ='.format(i) ,df[i].value_counts())
    count.append(df[i].value_counts().argmax())
count
# Out:
# valuse count for column userid is  = A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
#                  ...
# A3PWDBUNRLAFH8      1
# A1CJVG6GOW0N3J      1
# AE1YAAGHN8ZOF       1
# A3BUSJD9XLBSN0      1
# A28OXRXHUPM7GR      1
# Name: userid, Length: 4201696, dtype: int64
# valuse count for column productid is  = B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
#               ...
# B00GI13WKA        1
# B00BU72AG4        1
# B004G55U3W        1
# B00AA71LY2        1
# B00BBH9KSY        1
# Name: productid, Length: 476001, dtype: int64
# valuse count for column rating is  = 5.0    4347540
# 4.0    1485781
# 1.0     901765
# 3.0     633073
# 2.0     456322
# Name: rating, dtype: int64
# ['A5JLAU2ARJ0BO', 'B0074BW614', 5.0]

# %%
# getting idea about how mean rating of the products 
df.groupby('productid')['rating'].mean().head()
# Out:
# productid
# 0321732944    5.000000
# 0439886341    1.666667
# 0511189877    4.500000
# 0528881469    2.851852
# 0558835155    3.000000
# Name: rating, dtype: float64

# %%
# getting idea about how mean rating of the products are given by users 
df.groupby('productid')['rating'].mean().value_counts().head() 
# It gives idea about how many people have taken the product and rated the product
# Out:
# 5.0    131361
# 4.0     55055
# 3.0     35119
# 1.0     27894
# 4.5     18679
# Name: rating, dtype: int64

# %%
# getting idea about how mean rating of the products are given by users and sorting the values 
df.groupby('productid')['rating'].count().sort_values(ascending=False).head()
# Out:
# productid
# B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
# Name: rating, dtype: int64

# %%
# sorting the products rating 
df.groupby('productid')['rating'].mean().sort_values(ascending=False).head()
# Out:
# productid
# BT008V9J9U    5.0
# B0058PRC0S    5.0
# B0058ORBFU    5.0
# B0058OQ9Q2    5.0
# B0058OKSMS    5.0
# Name: rating, dtype: float64

# %%
# getting an idea about count of each rating given by user 
df.groupby('rating').count()
# Out:
#          userid  productid
# rating
# 1.0      901765     901765
# 2.0      456322     456322
# 3.0      633073     633073
# 4.0     1485781    1485781
# 5.0     4347540    4347540

# %% [markdown]
# #### Observing the distribution plot of rating

# %%
# creating dataframe for plotting 
df_gp = df.groupby(by=['rating']).agg({'userid': 'count'}).reset_index()
df_gp.columns = ['Rating', 'Count']

# %%
#ploting the axis label and ploting name 
plt.barh(df_gp.Rating, df_gp.Count, color='royalblue')
plt.title('Overall Count of Ratings', fontsize=15)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Rating', fontsize=15)
plt.grid(ls='dotted')
plt.show()

# %%
# keeping users only who has given 50 or more number of ratings 
# keeing count of rating of a user in count variable 
count = df.groupby('userid')['rating'].count()

# %%
# creating new dataframe in which we have only those users who have given 50 or more then 50 product
df_50_greater=df[df['userid'].isin(count[count > 50].index)]
df_50_greater['userid'].value_counts()# To cross check
# Out:
# A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
#                  ...
# A2858RV2VLI14X     51
# A1UMSB7LAW0RIR     51
# A1FMU4CJLIDHR9     51
# A12LH2100CKQO      51
# A1BXVZSQOJE6UE     51
# Name: userid, Length: 1466, dtype: int64

# %%
print('Before removing user who had given rating 50 or more product shape is :',df.shape)
print('After removing user who have not given rating 50 or more product shape is :',df_50_greater.shape)
# Out:
# Before removing user who had given rating 50 or more product shape is : (7824481, 3)
# After removing user who have not given rating 50 or more product shape is : (122171, 3)

# %%
# observing the head of new datafram 
#ratings_mean_count= ratings_mean_count.reset_index(drop = False) # reseting the index
df_50_greater.head()
# Out:
#              userid   productid  rating
# 117   AT09WGFUM934H  0594481813     3.0
# 176  A32HSNCNPRUMTR  0970407998     1.0
# 177  A17HMM1M7T9PJ1  0970407998     4.0
# 491  A3CLWR1UUZT6TG  0972683275     5.0
# 630  A3TAS1AG6FMBQW  0972683275     5.0

# %%
# Mean rating of each product is captured in 'ratings_mean_count'
ratings_mean_count = pd.DataFrame(df_50_greater.groupby('productid')['rating'].mean())

# %%
# Capturing number of user for each product who had given rating for that product in new column in 'ratings_mean_count'
ratings_mean_count['rating_counts'] =pd.DataFrame(df_50_greater.groupby('productid')['rating'].count())

# %%
ratings_mean_count= ratings_mean_count.reset_index(drop = False)
df_100_product= ratings_mean_count[ratings_mean_count['rating_counts'] >100]
df_100_product
# Out:
#         productid    rating  rating_counts
# 10820  B000N99BBC  4.773006            163
# 21486  B002R5AM7C  4.118110            127
# 21708  B002SZEOLG  4.287037            108
# 21954  B002V88HFE  4.702970            101
# 22850  B0034CL2ZI  4.628571            105
# 24262  B003ES5ZUU  4.858757            177
# 28121  B004CLYEDC  4.666667            117
# 30312  B004T9RR6I  3.870370            108
# 37407  B007WTAJTO  4.692308            156
# 37761  B00829THK0  4.409091            132
# 37765  B00829TIEK  4.431507            146
# 37803  B00834SJNA  4.495327            107
# 38146  B0088CJT4U  4.215686            204
# 38471  B008DWCRQW  4.088889            135

# %%
df_100_product_sorted = df_100_product.sort_values('rating',ascending=False)

# %%
# taking head from 'rating_mean_count' dataframe 
rec_count = df_100_product_sorted.head(10)
rec_count # recommended electronics product based on popularity
# Out:
#         productid    rating  rating_counts
# 24262  B003ES5ZUU  4.858757            177
# 10820  B000N99BBC  4.773006            163
# 21954  B002V88HFE  4.702970            101
# 37407  B007WTAJTO  4.692308            156
# 28121  B004CLYEDC  4.666667            117
# 22850  B0034CL2ZI  4.628571            105
# 37803  B00834SJNA  4.495327            107
# 37765  B00829TIEK  4.431507            146
# 37761  B00829THK0  4.409091            132
# 21708  B002SZEOLG  4.287037            108

# %% [markdown]
# >- For popularity based recomendation system we recommend popular items which are also rated high
# >- Its not clear if we just recommend the product based on high rating, we may missed on trending items
# >- So it is important to take considreation of how many users had rated the product
# >- So it is good if we select some threshold for products which are rated by minimum number of users
# >- Trending product can be recommended if we consider timestamp but we are ignoring that in this case
# >- We are selecting those products which are rated by atleast 100 user

# %%
ratings_mean_count.groupby('productid')['rating'].mean().sort_values(ascending=False).head()
# Out:
# productid
# B00LKG1MC8    5.0
# B000H8WLKC    5.0
# B000HA4EZK    5.0
# B004EHZZDW    5.0
# B004EI0EG4    5.0
# Name: rating, dtype: float64

# %%
# Importing Surprise library pakages 
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split

# %%
# As we're loading a custom dataset, we need to define a reader. In the
# ratings_Electronics.csv dataset, each line has the following format:
# 'user item rating ', separated by ',' characters.
reader = Reader(line_format='user item rating ', sep=',',rating_scale=(1, 5))

# %%
# Loading the data into surprise library object
data = Dataset.load_from_df(df_50_greater[['userid', 'productid', 'rating']], reader)

# %%
# tring to observe the data , but its is in surprise.dataset
data

# %%
# Spliting the data into train and test 
trainset, testset = train_test_split(data, test_size=.3)

# %%
#Importing SVD from Surprise
from surprise import SVD
#importing gridsearchcv fro parameter tunning 
from surprise.model_selection import GridSearchCV

# %% [markdown]
# algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
# algo.fit(trainset)

# %%
# defining Parameter Grid 
param_grid = {'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}

#Instantiating gridsearchcv object
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)
# fitting data into the object  
gs.fit(data)

# %% [markdown]
# >- n_epochs – The number of iteration of the SGD procedure. Default is 20.
# >- lr_all – The learning rate for all parameters. Default is 0.005.
# >- reg_all – The regularization term for all parameters. Default is 0.02.

# %%
# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.9864536573839798
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
# We can now use the algorithm that yields the best rmse:
algo = gs.best_estimator['rmse']
trainingSet = data.build_full_trainset()
trainingSet = algo.fit(trainingSet)

# %%
# stroring the results of gridSearch Cv in results_df
results_df = pd.DataFrame.from_dict(gs.cv_results)

# %%
results_df.head()
# Out:
#    split0_test_rmse  split1_test_rmse  split2_test_rmse  mean_test_rmse  \
# 0          1.016873          1.005575          1.020098        1.014182
# 1          1.018129          1.006961          1.020766        1.015285
# 2          0.998504          0.986474          1.001153        0.995377
# 3          1.000778          0.989114          1.003176        0.997689
# 4          1.002614          0.990332          1.005321        0.999422
#
#    std_test_rmse  rank_test_rmse  split0_test_mae  split1_test_mae  \
# 0       0.006227               7         0.780228         0.774902
# 1       0.005984               8         0.782228         0.777354
# 2       0.006388               3         0.757653         0.752126
# 3       0.006142               4         0.761683         0.756384
# 4       0.006522               5         0.762952         0.757094
#
#    split2_test_mae  mean_test_mae  std_test_mae  rank_test_mae  mean_fit_time  \
# 0         0.782216       0.779115      0.003087              7       3.077704
# 1         0.783662       0.781081      0.002700              8       3.186968
# 2         0.759371       0.756383      0.003091              3       3.260999
# 3         0.763045       0.760371      0.002873              4       3.229078
# 4         0.764541       0.761529      0.003202              5       6.031132
#
#    std_fit_time  mean_test_time  std_test_time  \
# 0      0.156618        0.656804       0.063031
# 1      0.258825        0.685323       0.066057
# 2      0.129217        0.631999       0.087528
# 3      0.102166        0.644161       0.059823
# 4      0.247806        0.679952       0.063122
#
#                                               params  param_n_epochs  \
# 0   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.4}               5
# 1   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.6}               5
# 2   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.4}               5
# 3   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.6}               5
# 4  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.4}              10
#
#    param_lr_all  param_reg_all
# 0         0.002            0.4
# 1         0.002            0.6
# 2         0.005            0.4
# 3         0.005            0.6
# 4         0.002            0.4

# %%
# Predicting the values on testset

predictions = algo.test(testset)

# %%
# checking the accuracy 
accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 0.9082
# 0.9081898199763105

# %%
# Understanding and printing the prediction 
predictions
# Out:
# [Prediction(uid='A3VONQL7YW8UPM', iid='B005FN5DJA', r_ui=5.0, est=4.196989824048176, details={'was_impossible': False}),
#  Prediction(uid='A1MRRMHGV3PN5W', iid='B00IVEHSV6', r_ui=4.0, est=4.259147289700172, details={'was_impossible': False}),
#  Prediction(uid='A3F3B1JPACN215', iid='B00HK5B3PO', r_ui=4.0, est=4.111312375535511, details={'was_impossible': False}),
#  Prediction(uid='A38KK0SZYEH5UD', iid='B001FWBUUG', r_ui=5.0, est=4.526095366745605, details={'was_impossible': False}),
#  Prediction(uid='A2LFWJ8X817QGX', iid='B0040MV82I', r_ui=5.0, est=4.284119429551083, details={'was_impossible': False}),
#  Prediction(uid='A21Q9JVG4SII51', iid='B003M8HWDA', r_ui=5.0, est=4.3978409734085, details={'was_impossible': False}),
#  Prediction(uid='A14Z6D3IRJ23F7', iid='B0000DBML2', r_ui=5.0, est=4.803062650779446, details={'was_impossible': False}),
#  Prediction(uid='A361U4SXK7FCQE', iid='B008DWCRQW', r_ui=4.0, est=4.196890218209673, details={'was_impossible': False}),
#  Prediction(uid='A3VBXQKRM7A4JR', iid='B002R0JJY4', r_ui=4.0, est=4.090668975009952, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0002DG9XW', r_ui=5.0, est=4.15107236282189, details={'was_impossible': False}),
#  Prediction(uid='ABVYGB2TKBO8F', iid='B0016120M8', r_ui=5.0, est=4.378530840716015, details={'was_impossible': False}),
#  Prediction(uid='A25HBO5V8S8SEA', iid='B00005ICE1', r_ui=5.0, est=4.795325486804172, details={'was_impossible': False}),
#  Prediction(uid='AW5JSQCHC2ZJO', iid='B00DR0B31U', r_ui=4.0, est=4.274094653252796, details={'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B005HY4UG4', r_ui=3.0, est=4.162489695920956, details={'was_impossible': False}),
#  Prediction(uid='A3IY316DRNF5F2', iid='B0039NLS3I', r_ui=4.0, est=3.9225267418787824, details={'was_impossible': False}),
#  Prediction(uid='AVU1ILDDYW301', iid='B005DIPWFC', r_ui=2.0, est=3.981042955979828, details={'was_impossible': False}),
#  Prediction(uid='A3L6L5O89JTX2T', iid='B002U6KT8U', r_ui=1.0, est=4.046783942256127, details={'was_impossible': False}),
#  Prediction(uid='A18HE80910BTZI', iid='B000VE4PNS', r_ui=5.0, est=3.8274605496130114, details={'was_impossible': False}),
#  Prediction(uid='A2VALCFTOWFYXZ', iid='B008PINWWC', r_ui=1.0, est=3.4461009874716293, details={'was_impossible': False}),
#  Prediction(uid='A1NZLRAZJGD99W', iid='B00865MZKY', r_ui=5.0, est=4.0830982901312245, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B004FVMKV2', r_ui=4.0, est=4.1337558738999345, details={'was_impossible': False}),
#  Prediction(uid='A2BCDZO1XQLDH', iid='B004CR7TE2', r_ui=5.0, est=4.180822049978807, details={'was_impossible': False}),
#  Prediction(uid='ABQWMANK4AR63', iid='B0000658CE', r_ui=1.0, est=3.7171167111431314, details={'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B001L4RLHY', r_ui=4.0, est=3.8929605954675286, details={'was_impossible': False}),
#  Prediction(uid='A2NB2E5DXE319Z', iid='B003WU4MS6', r_ui=5.0, est=4.396130033540229, details={'was_impossible': False}),
#  Prediction(uid='A7EJERNB7IK3Z', iid='B0001IM95U', r_ui=3.0, est=4.137689729651636, details={'was_impossible': False}),
#  Prediction(uid='AL42PIIG5DXYD', iid='B000HPV3RW', r_ui=3.0, est=4.258927226533029, details={'was_impossible': False}),
#  Prediction(uid='A22R9L5DAVYYWR', iid='B000I223MI', r_ui=4.0, est=3.86849634896404, details={'was_impossible': False}),
#  Prediction(uid='A2MSBIA18RXYQC', iid='B003LT8OPU', r_ui=4.0, est=3.5979590018495866, details={'was_impossible': False}),
#  Prediction(uid='AYNAH993VDECT', iid='B005EOWBKE', r_ui=4.0, est=4.515130521053093, details={'was_impossible': False}),
#  Prediction(uid='A33CNFK776MTWR', iid='B000AMAWOM', r_ui=5.0, est=4.237811734580025, details={'was_impossible': False}),
#  Prediction(uid='A1MNN0ZMHYPJDU', iid='B004XFZTSQ', r_ui=5.0, est=4.639281759488213, details={'was_impossible': False}),
#  Prediction(uid='A3JV071KO43Q5X', iid='B0035WTVWI', r_ui=5.0, est=3.880207612784648, details={'was_impossible': False}),
#  Prediction(uid='A6XLG77BC9R8R', iid='B009VPP69K', r_ui=5.0, est=4.3281654563708924, details={'was_impossible': False}),
#  Prediction(uid='A2NB2E5DXE319Z', iid='B002IEE9D0', r_ui=5.0, est=4.44421519824639, details={'was_impossible': False}),
#  Prediction(uid='A11EXFO14WEJM1', iid='B0001ELYOQ', r_ui=3.0, est=4.28049225081682, details={'was_impossible': False}),
#  Prediction(uid='A2DXENZNO2JT4F', iid='B00B1HV7YO', r_ui=4.0, est=4.234433048463635, details={'was_impossible': False}),
#  Prediction(uid='A6XLG77BC9R8R', iid='B0009MIP8I', r_ui=5.0, est=4.1710328187680545, details={'was_impossible': False}),
#  Prediction(uid='A1NAA1R38JSNHV', iid='B000ID7QNI', r_ui=4.0, est=4.6632304670649125, details={'was_impossible': False}),
#  Prediction(uid='A3639Z6O5JBLIZ', iid='B00AP9QLAY', r_ui=5.0, est=4.606122419090802, details={'was_impossible': False}),
#  Prediction(uid='AKSQNMIKOU01H', iid='B0029LHXM6', r_ui=5.0, est=4.258650012014097, details={'was_impossible': False}),
#  Prediction(uid='ARXU3FESTWMJJ', iid='B0002DOXKI', r_ui=5.0, est=3.910195243576784, details={'was_impossible': False}),
#  Prediction(uid='A2Q204DY2L7YRP', iid='B008TLQ5RY', r_ui=5.0, est=4.552066583218729, details={'was_impossible': False}),
#  Prediction(uid='A2UOHALGF2X77Q', iid='B004QK7HI8', r_ui=2.0, est=4.305808623083258, details={'was_impossible': False}),
#  Prediction(uid='A2OBDNQ5ZYU1L8', iid='B00175VDY4', r_ui=5.0, est=4.380414133432723, details={'was_impossible': False}),
#  Prediction(uid='A2YYHSORXIHZCS', iid='B000KFWUMG', r_ui=4.0, est=4.344107240703187, details={'was_impossible': False}),
#  Prediction(uid='A1KWPIORLG2QV', iid='B0051PGX2I', r_ui=5.0, est=4.557900733153831, details={'was_impossible': False}),
#  Prediction(uid='A34VRVI4CSI5RQ', iid='B003X26LXW', r_ui=4.0, est=4.145782745469188, details={'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B00HZ9GNGY', r_ui=5.0, est=4.637756762827283, details={'was_impossible': False}),
#  Prediction(uid='A1E1LEVQ9VQNK', iid='B003ELYQGG', r_ui=5.0, est=4.473043148049485, details={'was_impossible': False}),
#  Prediction(uid='A2I2KPNJDQ9SL0', iid='B002LKWKWS', r_ui=3.0, est=4.301757325552002, details={'was_impossible': False}),
#  Prediction(uid='A1EQ5D5JRSW23K', iid='B00HJEHBLQ', r_ui=5.0, est=4.52268958753643, details={'was_impossible': False}),
#  Prediction(uid='AYP0YPLSP9ISM', iid='B001RB21JY', r_ui=5.0, est=3.9734692658835087, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0000C4DX6', r_ui=5.0, est=4.2461581084056395, details={'was_impossible': False}),
#  Prediction(uid='A2J8T58Z4X15IO', iid='B002DYGQI6', r_ui=5.0, est=4.351309690627097, details={'was_impossible': False}),
#  Prediction(uid='AN2IZT80ZUNJN', iid='B004J3V90Y', r_ui=4.0, est=3.9898978105963026, details={'was_impossible': False}),
#  Prediction(uid='A8X478DM3KAWM', iid='B009OX22B4', r_ui=3.0, est=4.099560857327769, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B0081TXIXI', r_ui=3.0, est=3.9740954461317894, details={'was_impossible': False}),
#  Prediction(uid='A203OCQQ12MAVT', iid='B0006A05QI', r_ui=1.0, est=4.172961748010035, details={'was_impossible': False}),
#  Prediction(uid='A5GPH59NDWJRB', iid='B00B50CEH6', r_ui=5.0, est=4.3707093315762, details={'was_impossible': False}),
#  Prediction(uid='AAR7CEPXYJA0T', iid='B000UVM0ES', r_ui=4.0, est=3.773000401016195, details={'was_impossible': False}),
#  Prediction(uid='AEWYUPCNDV7HY', iid='B0014TMYPU', r_ui=2.0, est=3.9816990826749343, details={'was_impossible': False}),
#  Prediction(uid='AGGAQLXPVGM5D', iid='B002BDU6IU', r_ui=5.0, est=4.449923438566031, details={'was_impossible': False}),
#  Prediction(uid='A30XZK10EZN9V4', iid='B00008Y0VN', r_ui=2.0, est=4.365090840445598, details={'was_impossible': False}),
#  Prediction(uid='A3F3B6HY9RJI04', iid='B009X01C64', r_ui=5.0, est=4.537038114656828, details={'was_impossible': False}),
#  Prediction(uid='A3N4I2KRSMACW8', iid='B000IN04EG', r_ui=5.0, est=4.258814518065645, details={'was_impossible': False}),
#  Prediction(uid='AWZR0O65DL2Q', iid='B001T9NUJE', r_ui=5.0, est=4.490215314969878, details={'was_impossible': False}),
#  Prediction(uid='A2PICNZWHEINQC', iid='B0076AYNXM', r_ui=5.0, est=4.592146850115643, details={'was_impossible': False}),
#  Prediction(uid='A23D13HKTA95WX', iid='B004IZN3K2', r_ui=5.0, est=4.224325766019103, details={'was_impossible': False}),
#  Prediction(uid='A11ED8O95W2103', iid='B0007R4LI8', r_ui=5.0, est=4.097803082099521, details={'was_impossible': False}),
#  Prediction(uid='A2AC6GQ24S45GA', iid='B001B8CU8U', r_ui=3.0, est=4.122486989004252, details={'was_impossible': False}),
#  Prediction(uid='A2WXURU33RBGQS', iid='B001OORMVQ', r_ui=4.0, est=3.957680627702155, details={'was_impossible': False}),
#  Prediction(uid='A32T2H8150OJLU', iid='B000HJPK2C', r_ui=5.0, est=4.698409785599699, details={'was_impossible': False}),
#  Prediction(uid='A17HMM1M7T9PJ1', iid='B0010Z28XG', r_ui=5.0, est=4.578188871419926, details={'was_impossible': False}),
#  Prediction(uid='A3V0YR50F1XSKP', iid='B00461E7JE', r_ui=5.0, est=4.767089814668459, details={'was_impossible': False}),
#  Prediction(uid='AFNG8O2DXRCUV', iid='B00CSKC5VW', r_ui=4.0, est=4.3448516583816845, details={'was_impossible': False}),
#  Prediction(uid='A296QED1MV1V0J', iid='B00232YRJ8', r_ui=4.0, est=4.257857737291988, details={'was_impossible': False}),
#  Prediction(uid='A3V0YR50F1XSKP', iid='B005ARQV6U', r_ui=5.0, est=4.611715480731227, details={'was_impossible': False}),
#  Prediction(uid='A3F8T3BRXRX5P3', iid='B000Q82PIQ', r_ui=4.0, est=4.272691968153832, details={'was_impossible': False}),
#  Prediction(uid='A2TKWMX4563NR6', iid='B003B48UQ8', r_ui=1.0, est=3.7508310665187445, details={'was_impossible': False}),
#  Prediction(uid='AEWYUPCNDV7HY', iid='B001G5ZTN6', r_ui=5.0, est=4.2314443790966845, details={'was_impossible': False}),
#  Prediction(uid='A28BX3MM90A6FI', iid='B001NLYVIM', r_ui=5.0, est=4.396344106198489, details={'was_impossible': False}),
#  Prediction(uid='A2ALRZ0ENQLYY5', iid='B0043T7FXE', r_ui=5.0, est=4.4523630260466005, details={'was_impossible': False}),
#  Prediction(uid='A18L9A64XNGVGU', iid='B00FG7N7RA', r_ui=2.0, est=3.4546622070690125, details={'was_impossible': False}),
#  Prediction(uid='ACP9S40H3SHY1', iid='B009DL0LOW', r_ui=5.0, est=4.773403478106657, details={'was_impossible': False}),
#  Prediction(uid='A1X3DA7C61WZLQ', iid='B00020S7XK', r_ui=3.0, est=3.9527403016091074, details={'was_impossible': False}),
#  Prediction(uid='A3H6NNGCINPLEC', iid='B002HJ9Q66', r_ui=4.0, est=4.288731809864995, details={'was_impossible': False}),
#  Prediction(uid='A18U49406IPPIJ', iid='B00GTLN1BO', r_ui=5.0, est=4.894859421577028, details={'was_impossible': False}),
#  Prediction(uid='A3S5EXYZDEBF3K', iid='B00F5LEMBC', r_ui=4.0, est=3.906737305433378, details={'was_impossible': False}),
#  Prediction(uid='A196JN53PG0C7R', iid='B008JJLW4M', r_ui=5.0, est=4.949640684312186, details={'was_impossible': False}),
#  Prediction(uid='A1ODOGXEYECQQ8', iid='B00CJRZ31S', r_ui=4.0, est=4.365943836085373, details={'was_impossible': False}),
#  Prediction(uid='A3P1508PZ0UADD', iid='B0015VW3BM', r_ui=5.0, est=4.13546136501888, details={'was_impossible': False}),
#  Prediction(uid='A1NAA1R38JSNHV', iid='B000LAY3DO', r_ui=5.0, est=4.453885554603248, details={'was_impossible': False}),
#  Prediction(uid='A2VODABWSVHV8E', iid='B003ES5ZUU', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='A1VVRA3P6G1TWH', iid='B00021EE4U', r_ui=5.0, est=4.084433478585811, details={'was_impossible': False}),
#  Prediction(uid='A2F92M62KN324B', iid='B000OFSN4G', r_ui=5.0, est=4.186589741640367, details={'was_impossible': False}),
#  Prediction(uid='A2VODABWSVHV8E', iid='B003VKPAPQ', r_ui=5.0, est=4.686992154005987, details={'was_impossible': False}),
#  Prediction(uid='A5KMMY627T3W', iid='B003MAJMXQ', r_ui=4.0, est=4.459269895411495, details={'was_impossible': False}),
#  Prediction(uid='A2FWZ58M6IQMD7', iid='B00D2LR76E', r_ui=4.0, est=3.961214422409729, details={'was_impossible': False}),
#  Prediction(uid='A204K1OFE8OB9Y', iid='B0046SB920', r_ui=4.0, est=3.4011645029088795, details={'was_impossible': False}),
#  Prediction(uid='A9J4UURM4OSDW', iid='B001BP432E', r_ui=4.0, est=4.343689170068017, details={'was_impossible': False}),
#  Prediction(uid='A2HDTOF8222KN3', iid='B009SJ9PIM', r_ui=5.0, est=4.805272971177921, details={'was_impossible': False}),
#  Prediction(uid='AX05DBU8IRUWY', iid='B00142DV5Y', r_ui=5.0, est=4.127684372926948, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B00B08IO7C', r_ui=4.0, est=4.213578040992876, details={'was_impossible': False}),
#  Prediction(uid='A2858RV2VLI14X', iid='B004QBUL1C', r_ui=4.0, est=4.613079069928387, details={'was_impossible': False}),
#  Prediction(uid='AEWYUPCNDV7HY', iid='B004HKJTT2', r_ui=4.0, est=4.317441225646657, details={'was_impossible': False}),
#  Prediction(uid='A1G3DKT38DNZJP', iid='B003672SQS', r_ui=5.0, est=4.33494723656682, details={'was_impossible': False}),
#  Prediction(uid='AGOH8N902URMW', iid='B000W6POQW', r_ui=4.0, est=3.8654384455425608, details={'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B004YLAYHA', r_ui=5.0, est=4.293345958512202, details={'was_impossible': False}),
#  Prediction(uid='A1KD8NJPZ01R37', iid='B0002F3G7M', r_ui=1.0, est=3.5881537954553613, details={'was_impossible': False}),
#  Prediction(uid='A26EQ8U96JA92T', iid='B004GW25WY', r_ui=5.0, est=4.726981272249114, details={'was_impossible': False}),
#  Prediction(uid='A34JKODTSKCGEN', iid='B000KFSERG', r_ui=5.0, est=4.5536017700522535, details={'was_impossible': False}),
#  Prediction(uid='A1435P5AMCPB3X', iid='B000P6H89U', r_ui=5.0, est=4.488003707231678, details={'was_impossible': False}),
#  Prediction(uid='A3R19YKNL641X3', iid='B00J3YE24O', r_ui=5.0, est=4.346845216223342, details={'was_impossible': False}),
#  Prediction(uid='AT6CZDCP4TRGA', iid='B0000C2KB7', r_ui=3.0, est=3.8708305146427957, details={'was_impossible': False}),
#  Prediction(uid='A1VOFY3QFT9WCG', iid='B003MTTJOY', r_ui=5.0, est=4.966580240515569, details={'was_impossible': False}),
#  Prediction(uid='AZBXKUH4AIW3X', iid='B004M5H660', r_ui=4.0, est=4.090191339917159, details={'was_impossible': False}),
#  Prediction(uid='A36A1ZYZH8568P', iid='B00CHH0JF0', r_ui=5.0, est=4.451107191703633, details={'was_impossible': False}),
#  Prediction(uid='A240FRPD4MEXND', iid='B0038KRDMM', r_ui=5.0, est=4.344757692069234, details={'was_impossible': False}),
#  Prediction(uid='A20L63B48RPSOH', iid='B003LSTD38', r_ui=4.0, est=4.382899450961808, details={'was_impossible': False}),
#  Prediction(uid='A1WXG10FJ353K0', iid='B001TUYTZM', r_ui=5.0, est=4.659100581587267, details={'was_impossible': False}),
#  Prediction(uid='A17UNMURMLX0ZE', iid='B008DWCRQW', r_ui=4.0, est=4.003211741088842, details={'was_impossible': False}),
#  Prediction(uid='A1QVFHPY8418HC', iid='B000WVAW6O', r_ui=5.0, est=4.4843039059798775, details={'was_impossible': False}),
#  Prediction(uid='A3PJJTAKISAFI9', iid='B0047E8XTU', r_ui=5.0, est=3.48472173417894, details={'was_impossible': False}),
#  Prediction(uid='A25TQLMIAPI1T6', iid='B00E4AZEFS', r_ui=5.0, est=4.361953321499414, details={'was_impossible': False}),
#  Prediction(uid='A3N0P5AAMP6XD2', iid='B00C28L6EW', r_ui=4.0, est=3.927948963240354, details={'was_impossible': False}),
#  Prediction(uid='A3D01HLSUFEZQY', iid='B000VPOYJC', r_ui=5.0, est=4.3436078767829684, details={'was_impossible': False}),
#  Prediction(uid='A2H4OMJLE7JFM2', iid='B00GTGSU6A', r_ui=5.0, est=4.650861492740934, details={'was_impossible': False}),
#  Prediction(uid='A2L42QEWR77PKZ', iid='B005KSAG3S', r_ui=5.0, est=4.46618374215768, details={'was_impossible': False}),
#  Prediction(uid='A13WOT3RSXKRD5', iid='B000067S60', r_ui=4.0, est=4.62495681454158, details={'was_impossible': False}),
#  Prediction(uid='A15J9K7O10A3M6', iid='B002SSL920', r_ui=5.0, est=4.314359779565765, details={'was_impossible': False}),
#  Prediction(uid='AQ2FC1DLKVD8H', iid='B001TH7T2U', r_ui=5.0, est=4.680137851513719, details={'was_impossible': False}),
#  Prediction(uid='ABUE0ALHKWKHC', iid='B002BWQA9K', r_ui=5.0, est=4.633835554508089, details={'was_impossible': False}),
#  Prediction(uid='A3RGHO0Q938FRS', iid='B00JXUUVWU', r_ui=5.0, est=4.378218533095227, details={'was_impossible': False}),
#  Prediction(uid='A1H0D7635GEEJ1', iid='B00009R89L', r_ui=5.0, est=4.230584141031145, details={'was_impossible': False}),
#  Prediction(uid='A38NELQT98S4H8', iid='B003XQ6FDE', r_ui=4.0, est=4.0990836377226865, details={'was_impossible': False}),
#  Prediction(uid='A1VLVWTLV3LVHR', iid='B0025VKUPW', r_ui=3.0, est=4.343748444386388, details={'was_impossible': False}),
#  Prediction(uid='A1QVFHPY8418HC', iid='B004TKTOWC', r_ui=3.0, est=4.220208960675509, details={'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B001FA1NK0', r_ui=4.0, est=3.978858156987314, details={'was_impossible': False}),
#  Prediction(uid='A1TDR7Y90SVCHL', iid='B0041OSQ9I', r_ui=3.0, est=4.343106880817575, details={'was_impossible': False}),
#  Prediction(uid='A2J4XMWKR8PPD0', iid='B008TTCJOY', r_ui=5.0, est=4.822117090583188, details={'was_impossible': False}),
#  Prediction(uid='A3L1VJMHFWONCB', iid='B00HRJ4FN0', r_ui=4.0, est=4.278566095515612, details={'was_impossible': False}),
#  Prediction(uid='A3PJJTAKISAFI9', iid='B000I963FE', r_ui=1.0, est=3.5275101899167622, details={'was_impossible': False}),
#  Prediction(uid='A1L5TA5UQF7EWE', iid='B00CSIOLXY', r_ui=5.0, est=3.9544430736947382, details={'was_impossible': False}),
#  Prediction(uid='A2GOHNFBHUU3UI', iid='B00CHT6CRC', r_ui=4.0, est=3.9523868363535697, details={'was_impossible': False}),
#  Prediction(uid='A2WW57XX2UVLM6', iid='B003BEDRJI', r_ui=3.0, est=4.149948818339174, details={'was_impossible': False}),
#  Prediction(uid='A215IN14OKAE2T', iid='B000SDW84K', r_ui=5.0, est=3.971307835548549, details={'was_impossible': False}),
#  Prediction(uid='A5KMMY627T3W', iid='B001G5ZTPY', r_ui=5.0, est=4.61630029587324, details={'was_impossible': False}),
#  Prediction(uid='A34JKODTSKCGEN', iid='B002QGDWLK', r_ui=5.0, est=4.660123538562675, details={'was_impossible': False}),
#  Prediction(uid='ACYZXQ2JKPZKT', iid='B00903HKOC', r_ui=3.0, est=3.6900607510289385, details={'was_impossible': False}),
#  Prediction(uid='A2N75ADJSRW0AH', iid='B002M78L6E', r_ui=3.0, est=3.739961585939505, details={'was_impossible': False}),
#  Prediction(uid='A3TCMJ6GKZJFBQ', iid='B000N20BF4', r_ui=4.0, est=4.087621808902343, details={'was_impossible': False}),
#  Prediction(uid='A27TN8D0CZ8LUY', iid='B0015YU0FA', r_ui=2.0, est=3.9644738193369284, details={'was_impossible': False}),
#  Prediction(uid='A2KYRPDKVBI2R4', iid='B003XU763S', r_ui=5.0, est=4.6063203492642035, details={'was_impossible': False}),
#  Prediction(uid='A2NP9CGUSFP22E', iid='B00004Z5D1', r_ui=5.0, est=4.438627347278787, details={'was_impossible': False}),
#  Prediction(uid='A2JWF9IG8PJAOA', iid='B002GXIT6Q', r_ui=5.0, est=4.457640250240848, details={'was_impossible': False}),
#  Prediction(uid='A3F9CBHV4OHFBS', iid='B005V3KVU0', r_ui=5.0, est=4.489545872546072, details={'was_impossible': False}),
#  Prediction(uid='A21I62TCDL4754', iid='B0007WQ5LE', r_ui=5.0, est=4.1046588539936915, details={'was_impossible': False}),
#  Prediction(uid='A2D1LPEUCTNT8X', iid='B00BA8596G', r_ui=5.0, est=4.544858568883397, details={'was_impossible': False}),
#  Prediction(uid='A15J9K7O10A3M6', iid='B0093Y0CXE', r_ui=2.0, est=4.011667589141243, details={'was_impossible': False}),
#  Prediction(uid='A2X06FP2PQ6EK0', iid='B00128GKHG', r_ui=4.0, est=3.5558767561963425, details={'was_impossible': False}),
#  Prediction(uid='ABQWMANK4AR63', iid='B00DTPYRTI', r_ui=5.0, est=4.107479420917116, details={'was_impossible': False}),
#  Prediction(uid='A1SB9BNNGKNX2Z', iid='B001LNO722', r_ui=5.0, est=4.395618700909335, details={'was_impossible': False}),
#  Prediction(uid='A1P0JSFW184ZXJ', iid='B00CQ3ZP22', r_ui=5.0, est=4.639056644993081, details={'was_impossible': False}),
#  Prediction(uid='AJX9A4Q19UTJU', iid='B00DT04I9W', r_ui=5.0, est=4.698330835858514, details={'was_impossible': False}),
#  Prediction(uid='A3V15SFD7918WZ', iid='B000V70JPS', r_ui=4.0, est=4.026648384263029, details={'was_impossible': False}),
#  Prediction(uid='A2LB4FLRZG6CUV', iid='B0056OB8GK', r_ui=5.0, est=4.304876866176757, details={'was_impossible': False}),
#  Prediction(uid='A209G57KXCBF4C', iid='B00COHALOM', r_ui=3.0, est=3.935418785896763, details={'was_impossible': False}),
#  Prediction(uid='A19XMHRB3G4DIR', iid='B004CLYEFK', r_ui=5.0, est=4.654832477276442, details={'was_impossible': False}),
#  Prediction(uid='A38RMU1Y5TDP9', iid='B00564TF4W', r_ui=4.0, est=4.283743246913934, details={'was_impossible': False}),
#  Prediction(uid='A3TNM3C9ENUCFW', iid='B004Q3R9B0', r_ui=5.0, est=4.320360350222443, details={'was_impossible': False}),
#  Prediction(uid='A3OZA8HNJM26DC', iid='B00F3SOHNU', r_ui=3.0, est=3.849875995720504, details={'was_impossible': False}),
#  Prediction(uid='A3EZFFPVS34AMO', iid='B001XURPR2', r_ui=4.0, est=4.510352913622149, details={'was_impossible': False}),
#  Prediction(uid='A3V2EZ6MA32FF6', iid='B005JW6WQU', r_ui=5.0, est=4.777775987007818, details={'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B001AO2274', r_ui=5.0, est=4.393562677950381, details={'was_impossible': False}),
#  Prediction(uid='A33CNFK776MTWR', iid='B000065BVZ', r_ui=1.0, est=3.972133101080246, details={'was_impossible': False}),
#  Prediction(uid='A32O98PFC3OP7K', iid='B008YDTRLS', r_ui=2.0, est=3.990045461568431, details={'was_impossible': False}),
#  Prediction(uid='A3R4794K2RVU1S', iid='B00A45JEX0', r_ui=5.0, est=4.4894253238110675, details={'was_impossible': False}),
#  Prediction(uid='AOEAD7DPLZE53', iid='B001DL9WDG', r_ui=5.0, est=4.049178416847727, details={'was_impossible': False}),
#  Prediction(uid='AT6CZDCP4TRGA', iid='B000068PL7', r_ui=5.0, est=3.9882930702928396, details={'was_impossible': False}),
#  Prediction(uid='A2L36AGL8CKY3D', iid='B000068O16', r_ui=5.0, est=4.789166344374976, details={'was_impossible': False}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B00829THK0', r_ui=5.0, est=4.398557303104087, details={'was_impossible': False}),
#  Prediction(uid='A24J2Y1O22JYZX', iid='B001A4LVYY', r_ui=4.0, est=4.374905137911524, details={'was_impossible': False}),
#  Prediction(uid='A3D822N1K2IAQD', iid='B00E055H5O', r_ui=5.0, est=4.326760250253548, details={'was_impossible': False}),
#  Prediction(uid='AOJA1LC8PN7K1', iid='B000VJ0YQ0', r_ui=1.0, est=3.5558007639832234, details={'was_impossible': False}),
#  Prediction(uid='A11KZ906QD08C5', iid='B003PBB4ME', r_ui=5.0, est=4.335335756129601, details={'was_impossible': False}),
#  Prediction(uid='A9Y5O2R4D6EH5', iid='B00EB7UIO6', r_ui=4.0, est=4.199369753522245, details={'was_impossible': False}),
#  Prediction(uid='A3S3VSXEFXBMRC', iid='B0080DTFIM', r_ui=5.0, est=4.255434310923752, details={'was_impossible': False}),
#  Prediction(uid='A15Q2L6DYRTFIU', iid='B007BD4BRC', r_ui=5.0, est=4.636572193577414, details={'was_impossible': False}),
#  Prediction(uid='A2WPL6Y08K6ZQH', iid='B001GT185K', r_ui=5.0, est=4.272056435450603, details={'was_impossible': False}),
#  Prediction(uid='A250AXLRBVYKB4', iid='B001TP4RRC', r_ui=4.0, est=4.142717490896197, details={'was_impossible': False}),
#  Prediction(uid='A12DQZKRKTNF5E', iid='B002Q5XFCM', r_ui=4.0, est=4.278616549830098, details={'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00INNEWKK', r_ui=5.0, est=4.544915863372222, details={'was_impossible': False}),
#  Prediction(uid='A1GWG5CWLKJ7ET', iid='B00DBX371C', r_ui=4.0, est=4.343537732518229, details={'was_impossible': False}),
#  Prediction(uid='A1BXVZSQOJE6UE', iid='B00BOE1HXA', r_ui=5.0, est=4.138686393330755, details={'was_impossible': False}),
#  Prediction(uid='AVBLGXSWRN666', iid='B000089GN3', r_ui=4.0, est=4.193146266260406, details={'was_impossible': False}),
#  Prediction(uid='A3FPSY1M6G7XIB', iid='B000HJPK2C', r_ui=4.0, est=4.6039122177787535, details={'was_impossible': False}),
#  Prediction(uid='A2DG63DN704LOI', iid='B00ATM1M92', r_ui=4.0, est=4.394544010170189, details={'was_impossible': False}),
#  Prediction(uid='A3MUSWDCTZINQZ', iid='B009NHWVIA', r_ui=4.0, est=4.6353278004418526, details={'was_impossible': False}),
#  Prediction(uid='A2CIQEY05SPHTZ', iid='B002DPTQ8W', r_ui=4.0, est=3.6738129886139417, details={'was_impossible': False}),
#  Prediction(uid='A1UCAVBNJUZMPR', iid='B0018BQR84', r_ui=5.0, est=4.6838639158472475, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B00FG38L16', r_ui=5.0, est=4.4240748968721, details={'was_impossible': False}),
#  Prediction(uid='A2J7FHZFKOKGZ6', iid='B005VG5DLY', r_ui=5.0, est=4.011458093655279, details={'was_impossible': False}),
#  Prediction(uid='A3G007LQX6KGOD', iid='B00HSQAIQU', r_ui=4.0, est=4.355130637116407, details={'was_impossible': False}),
#  Prediction(uid='A1B0NL8UWAELI7', iid='B0016MMYKA', r_ui=5.0, est=4.572080591614264, details={'was_impossible': False}),
#  Prediction(uid='A14NA0W8ESGDSI', iid='B00832NCWU', r_ui=3.0, est=3.307886040048491, details={'was_impossible': False}),
#  Prediction(uid='A38RMU1Y5TDP9', iid='B0035FZJJ4', r_ui=4.0, est=4.4013965167686875, details={'was_impossible': False}),
#  Prediction(uid='A3N0P5AAMP6XD2', iid='B002C5IK3A', r_ui=1.0, est=3.6041259221220368, details={'was_impossible': False}),
#  Prediction(uid='A21I62TCDL4754', iid='B003HKRVAW', r_ui=4.0, est=3.961195048834568, details={'was_impossible': False}),
#  Prediction(uid='A2XX2A4OJCDNLZ', iid='B006B8SB56', r_ui=4.0, est=4.411321489574475, details={'was_impossible': False}),
#  Prediction(uid='A3O5ASFUXC32UA', iid='B000VDCTCI', r_ui=5.0, est=4.462479123150606, details={'was_impossible': False}),
#  Prediction(uid='A1ZM846Y7AUYD', iid='B000Q6JMB6', r_ui=4.0, est=4.122075632726814, details={'was_impossible': False}),
#  Prediction(uid='A2HXEJXEQQTM1D', iid='B003UE52ME', r_ui=5.0, est=4.207199597438349, details={'was_impossible': False}),
#  Prediction(uid='A18U49406IPPIJ', iid='B00AHBOSNM', r_ui=5.0, est=4.767993491547662, details={'was_impossible': False}),
#  Prediction(uid='A4GHPW9AAH1NY', iid='B001EPVOQY', r_ui=5.0, est=4.595031680261582, details={'was_impossible': False}),
#  Prediction(uid='AKCZIJ6ZHE41D', iid='B002M78E9I', r_ui=3.0, est=3.717359601553036, details={'was_impossible': False}),
#  Prediction(uid='A1X3ESYZ79H59E', iid='B005QCDY50', r_ui=5.0, est=4.055710422306975, details={'was_impossible': False}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B009D79VH4', r_ui=4.0, est=4.525888305221637, details={'was_impossible': False}),
#  Prediction(uid='A29KJ32G75L7G9', iid='B00AI5UOJ4', r_ui=5.0, est=4.487640582736101, details={'was_impossible': False}),
#  Prediction(uid='A253IOATGMT2UP', iid='B005E2XLNM', r_ui=5.0, est=4.417292823946935, details={'was_impossible': False}),
#  Prediction(uid='A1ZA5SXZS8Z3CK', iid='B0085IWW7S', r_ui=3.0, est=4.239137467422958, details={'was_impossible': False}),
#  Prediction(uid='AR18DH5SL9F73', iid='B000WH6H1M', r_ui=5.0, est=4.325313895306575, details={'was_impossible': False}),
#  Prediction(uid='AEAFHD09X8044', iid='B00139O10W', r_ui=5.0, est=4.253921484090591, details={'was_impossible': False}),
#  Prediction(uid='A1H0D7635GEEJ1', iid='B002IKLJVE', r_ui=4.0, est=4.369619090376325, details={'was_impossible': False}),
#  Prediction(uid='A1OH33MR6K4G5J', iid='B009D9K2S4', r_ui=1.0, est=3.7751897046928655, details={'was_impossible': False}),
#  Prediction(uid='A7FDGFK0KN7QG', iid='B0028Y5GKK', r_ui=5.0, est=4.511675323270213, details={'was_impossible': False}),
#  Prediction(uid='A2GOHNFBHUU3UI', iid='B002S53LJ2', r_ui=5.0, est=4.190721020939325, details={'was_impossible': False}),
#  Prediction(uid='A197T2N6RU7K56', iid='B0046TJG1U', r_ui=5.0, est=4.896461552384842, details={'was_impossible': False}),
#  Prediction(uid='A1N3EH28S4DI8L', iid='B005NFW9PG', r_ui=4.0, est=4.053683463028612, details={'was_impossible': False}),
#  Prediction(uid='A21INUA35HX4XQ', iid='B004NEULF8', r_ui=2.0, est=3.875902748445762, details={'was_impossible': False}),
#  Prediction(uid='AFNG8O2DXRCUV', iid='B00144KS6W', r_ui=5.0, est=4.349154398880306, details={'was_impossible': False}),
#  Prediction(uid='A1ODOGXEYECQQ8', iid='B0053G6GI6', r_ui=5.0, est=4.461369737596591, details={'was_impossible': False}),
#  Prediction(uid='A2ED50E3KWKUKW', iid='B003N0XDT4', r_ui=5.0, est=4.5273407744037915, details={'was_impossible': False}),
#  Prediction(uid='A2W0XCWOK3MW6F', iid='B009YT6PPC', r_ui=5.0, est=4.954620475534509, details={'was_impossible': False}),
#  Prediction(uid='ADOR3TR7GDF68', iid='B0027AGK3M', r_ui=5.0, est=4.342070829210944, details={'was_impossible': False}),
#  Prediction(uid='A1H4IVXNXWWBLV', iid='B007M4XML6', r_ui=5.0, est=4.368355580095893, details={'was_impossible': False}),
#  Prediction(uid='AOWF9T81XMX2S', iid='B004N85YEW', r_ui=5.0, est=4.364629035133147, details={'was_impossible': False}),
#  Prediction(uid='A2UEB48LAWFUCW', iid='B00966OWKI', r_ui=4.0, est=4.102260475703861, details={'was_impossible': False}),
#  Prediction(uid='A100UD67AHFODS', iid='B0053T4PHC', r_ui=5.0, est=4.510729378114014, details={'was_impossible': False}),
#  Prediction(uid='A1V3TRGWOMA8LC', iid='B003X26LYG', r_ui=5.0, est=4.297635283037426, details={'was_impossible': False}),
#  Prediction(uid='A253IOATGMT2UP', iid='B002O11LQA', r_ui=5.0, est=4.48749598684574, details={'was_impossible': False}),
#  Prediction(uid='A19EKT8H85AKO5', iid='B000J1H4VI', r_ui=5.0, est=4.526682350305172, details={'was_impossible': False}),
#  Prediction(uid='A1HYH206E18XVC', iid='B003M8HWDA', r_ui=4.0, est=4.0973092893945315, details={'was_impossible': False}),
#  Prediction(uid='A3872Y2XH0YDX1', iid='B000Y9YJI6', r_ui=5.0, est=4.725567729892609, details={'was_impossible': False}),
#  Prediction(uid='A3QRR8PSCBI07C', iid='B006507Q88', r_ui=5.0, est=4.377337057606112, details={'was_impossible': False}),
#  Prediction(uid='A24P4E3RJ6AX94', iid='B007P7ZO8O', r_ui=4.0, est=4.470774892272735, details={'was_impossible': False}),
#  Prediction(uid='A2NP9CGUSFP22E', iid='B007V5A1BK', r_ui=5.0, est=4.574416158352163, details={'was_impossible': False}),
#  Prediction(uid='A3077MQTAKOVFZ', iid='B003B22U8Y', r_ui=1.0, est=4.051814543593346, details={'was_impossible': False}),
#  Prediction(uid='A2LW5AL0KQ9P1M', iid='B00AW4J35W', r_ui=3.0, est=3.9045710729468066, details={'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B002M78JA2', r_ui=5.0, est=4.096651619491448, details={'was_impossible': False}),
#  Prediction(uid='A2VIYTWXANL343', iid='B0095VPBM2', r_ui=5.0, est=4.625619392425189, details={'was_impossible': False}),
#  Prediction(uid='A2AF0NOCM71J0B', iid='B008LTBHYU', r_ui=4.0, est=4.384009020773813, details={'was_impossible': False}),
#  Prediction(uid='ARXU3FESTWMJJ', iid='B0079TOEQQ', r_ui=3.0, est=3.716685276122105, details={'was_impossible': False}),
#  Prediction(uid='A3CKI6VEH0HBMJ', iid='B003O5LLFG', r_ui=5.0, est=4.672163150840975, details={'was_impossible': False}),
#  Prediction(uid='A2SKEQT0WTB954', iid='B0076T9WZM', r_ui=1.0, est=4.225843723379177, details={'was_impossible': False}),
#  Prediction(uid='A1GWG5CWLKJ7ET', iid='B009QV72VY', r_ui=2.0, est=4.176771904129179, details={'was_impossible': False}),
#  Prediction(uid='A18YMFFJW974QS', iid='B003ZUIHY8', r_ui=5.0, est=4.452355284890421, details={'was_impossible': False}),
#  Prediction(uid='A11FX8HL2ANK6T', iid='B001P6IYBK', r_ui=5.0, est=4.39849799455547, details={'was_impossible': False}),
#  Prediction(uid='A1N5FSCYN4796F', iid='B00A8FCX8E', r_ui=5.0, est=3.863006708430825, details={'was_impossible': False}),
#  Prediction(uid='A3FEGTOLCWXSV4', iid='B009O7XGCY', r_ui=3.0, est=3.9244888875212633, details={'was_impossible': False}),
#  Prediction(uid='A1143YEAZYMYHJ', iid='B000M17AVO', r_ui=4.0, est=4.6273658048951285, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0019MCQIM', r_ui=5.0, est=4.22526345433072, details={'was_impossible': False}),
#  Prediction(uid='A2UWPPU5GZLMQZ', iid='B00030CHRQ', r_ui=4.0, est=4.2900738285577065, details={'was_impossible': False}),
#  Prediction(uid='A294BKN913UOGP', iid='B000LY5OWE', r_ui=1.0, est=4.183895029792214, details={'was_impossible': False}),
#  Prediction(uid='ALUNVOQRXOZIA', iid='B003ZX871I', r_ui=1.0, est=3.530339061023262, details={'was_impossible': False}),
#  Prediction(uid='A3R1WFO4KIUQXZ', iid='B00CL8F98W', r_ui=4.0, est=3.8137737364732653, details={'was_impossible': False}),
#  Prediction(uid='A3B20R4ZAH0Y2Y', iid='B0012OV61K', r_ui=4.0, est=4.284092322044527, details={'was_impossible': False}),
#  Prediction(uid='A3IOQ7NVVLAUEE', iid='B002782LTG', r_ui=3.0, est=4.031597341156603, details={'was_impossible': False}),
#  Prediction(uid='A3775OP5VTX5ON', iid='B003B48UQ8', r_ui=1.0, est=3.567505604054295, details={'was_impossible': False}),
#  Prediction(uid='A2NU9H8H5MJZSL', iid='B000Z4AQFU', r_ui=2.0, est=2.9362810078890353, details={'was_impossible': False}),
#  Prediction(uid='A11KZ906QD08C5', iid='B003GR6IUK', r_ui=1.0, est=4.100351051008769, details={'was_impossible': False}),
#  Prediction(uid='AQIJ3ZEEVCIKU', iid='B0046A9RA4', r_ui=5.0, est=4.085743440500816, details={'was_impossible': False}),
#  Prediction(uid='A1GYEGLX3P2Y7P', iid='B00G4FCKB2', r_ui=4.0, est=3.957739271879256, details={'was_impossible': False}),
#  Prediction(uid='AELK0E5DK7LIZ', iid='B003NTZFLO', r_ui=4.0, est=4.081581181039695, details={'was_impossible': False}),
#  Prediction(uid='A3FPSY1M6G7XIB', iid='B000RN2KRQ', r_ui=5.0, est=4.450091054560367, details={'was_impossible': False}),
#  Prediction(uid='A3G5MOHY1U635N', iid='B005F0XRAU', r_ui=4.0, est=4.088587622315863, details={'was_impossible': False}),
#  Prediction(uid='ATS2855497V0I', iid='B00GD962OA', r_ui=4.0, est=3.9641499274789282, details={'was_impossible': False}),
#  Prediction(uid='AT6CZDCP4TRGA', iid='B00022TN9A', r_ui=5.0, est=4.044838588837671, details={'was_impossible': False}),
#  Prediction(uid='A1GNYV0RA0EQSS', iid='B003Y74AX4', r_ui=4.0, est=4.073302014843328, details={'was_impossible': False}),
#  Prediction(uid='A2XXBZPQT5EXHV', iid='B00DW374W4', r_ui=5.0, est=4.781377865802474, details={'was_impossible': False}),
#  Prediction(uid='A2L4ZGN7GZJ95T', iid='B008X9Z528', r_ui=3.0, est=3.9199073249262355, details={'was_impossible': False}),
#  Prediction(uid='A2QRXQPHDMFCQV', iid='B004GXAL42', r_ui=4.0, est=3.6331525281029067, details={'was_impossible': False}),
#  Prediction(uid='A3V7D0LH8L7BG0', iid='B005DKZTNK', r_ui=5.0, est=4.406001271034231, details={'was_impossible': False}),
#  Prediction(uid='A20L63B48RPSOH', iid='B004XZL980', r_ui=5.0, est=4.201232636044456, details={'was_impossible': False}),
#  Prediction(uid='A1VQHH85U7PX0', iid='B0041H8PH8', r_ui=4.0, est=4.226953757484405, details={'was_impossible': False}),
#  Prediction(uid='A3HRDRQ5VAFPQS', iid='B007RFW1NA', r_ui=4.0, est=3.6674943986265554, details={'was_impossible': False}),
#  Prediction(uid='A31N0XY2UTB25C', iid='B007CNL35E', r_ui=5.0, est=4.534559988586443, details={'was_impossible': False}),
#  Prediction(uid='A2ED50E3KWKUKW', iid='B000PIB6DW', r_ui=4.0, est=4.577771173729626, details={'was_impossible': False}),
#  Prediction(uid='A1GW7V6S6XSXX3', iid='B00009UT28', r_ui=5.0, est=4.193661001142246, details={'was_impossible': False}),
#  Prediction(uid='A2V1J3JT5OOZFO', iid='B0011TS8LM', r_ui=1.0, est=3.7078070278430677, details={'was_impossible': False}),
#  Prediction(uid='A1901NTE8LFJF6', iid='B003VANO7C', r_ui=4.0, est=4.298457808461965, details={'was_impossible': False}),
#  Prediction(uid='A15G70V9OBTOVO', iid='B0013DCOZC', r_ui=4.0, est=3.8839970717237517, details={'was_impossible': False}),
#  Prediction(uid='AYB4ELCS5AM8P', iid='B003BKW2K2', r_ui=5.0, est=4.819620037414786, details={'was_impossible': False}),
#  Prediction(uid='A2HJY7418G1KV1', iid='B001TZWNF0', r_ui=3.0, est=4.114756482560854, details={'was_impossible': False}),
#  Prediction(uid='ABVYGB2TKBO8F', iid='B0009JZSKO', r_ui=5.0, est=4.434777520661326, details={'was_impossible': False}),
#  Prediction(uid='A3EZEP0FX5BC1P', iid='B007PTCFFW', r_ui=5.0, est=4.2461486579904, details={'was_impossible': False}),
#  Prediction(uid='AAQ9NJ480N9W5', iid='B000089GN4', r_ui=4.0, est=4.395528756046582, details={'was_impossible': False}),
#  Prediction(uid='AWHL379EE14K7', iid='B00E58AA0I', r_ui=5.0, est=4.439258740003927, details={'was_impossible': False}),
#  Prediction(uid='ARX0KOX5Q01BJ', iid='B005HBN3CE', r_ui=1.0, est=3.5910440463838915, details={'was_impossible': False}),
#  Prediction(uid='A3GVXKCTFN3YDN', iid='B007TWK8AE', r_ui=5.0, est=4.6480913545401075, details={'was_impossible': False}),
#  Prediction(uid='ARBKYIVNYWK3C', iid='B002CFSTRC', r_ui=5.0, est=4.368512804036507, details={'was_impossible': False}),
#  Prediction(uid='A2L42QEWR77PKZ', iid='B0098Y77U0', r_ui=4.0, est=4.261881057770647, details={'was_impossible': False}),
#  Prediction(uid='A27M75LRSJ788H', iid='B007WTAJTO', r_ui=5.0, est=4.940827756047697, details={'was_impossible': False}),
#  Prediction(uid='A1NQFT941TOTT7', iid='B00129CDGC', r_ui=1.0, est=3.245788061731313, details={'was_impossible': False}),
#  Prediction(uid='A5JLAU2ARJ0BO', iid='B0001IXUEY', r_ui=5.0, est=3.9726312109528696, details={'was_impossible': False}),
#  Prediction(uid='A2WW57XX2UVLM6', iid='B0007GIXS8', r_ui=5.0, est=4.3071965913856385, details={'was_impossible': False}),
#  Prediction(uid='A2LB4FLRZG6CUV', iid='B004YDUZ22', r_ui=5.0, est=4.5042285477957105, details={'was_impossible': False}),
#  Prediction(uid='A1RL1OTV8IJMVD', iid='B00ITI04YM', r_ui=4.0, est=4.088047779997173, details={'was_impossible': False}),
#  Prediction(uid='A1VQHH85U7PX0', iid='B0001YFXCA', r_ui=5.0, est=4.468147498361047, details={'was_impossible': False}),
#  Prediction(uid='AVBLGXSWRN666', iid='B0006VHZJ2', r_ui=4.0, est=3.9785326886108345, details={'was_impossible': False}),
#  Prediction(uid='AZCE11PSTCH1L', iid='B004EHT538', r_ui=5.0, est=4.418286459167085, details={'was_impossible': False}),
#  Prediction(uid='A3QDMDSANPYGUX', iid='B007AL0372', r_ui=5.0, est=4.654406920845937, details={'was_impossible': False}),
#  Prediction(uid='ABIVKBMSIPEDY', iid='B00E964X1S', r_ui=4.0, est=3.9758931860658184, details={'was_impossible': False}),
#  Prediction(uid='A3BKNXX8QFIXIV', iid='B004CLYEFK', r_ui=5.0, est=4.655262817259593, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B00B728JY4', r_ui=5.0, est=4.2967838580724536, details={'was_impossible': False}),
#  Prediction(uid='A2UQK3DAZ8NO2T', iid='B000FA7PQ2', r_ui=5.0, est=4.406858976732019, details={'was_impossible': False}),
#  Prediction(uid='A11ED8O95W2103', iid='B0000A0AJH', r_ui=2.0, est=3.8932065543198537, details={'was_impossible': False}),
#  Prediction(uid='A1F1A0QQP2XVH5', iid='B004X8R7VA', r_ui=1.0, est=3.6839370650613708, details={'was_impossible': False}),
#  Prediction(uid='A2EMUM49CE0JV4', iid='B00513TYY4', r_ui=5.0, est=4.58658931819179, details={'was_impossible': False}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B004SGSHDY', r_ui=4.0, est=3.849570449974905, details={'was_impossible': False}),
#  Prediction(uid='AGEWOMQ90BV8R', iid='B0042JM9WM', r_ui=1.0, est=3.852329340501202, details={'was_impossible': False}),
#  Prediction(uid='ASJZT7DM51QEM', iid='B0048JJH5S', r_ui=4.0, est=4.072481688361095, details={'was_impossible': False}),
#  Prediction(uid='A1EH2S92FHWZRP', iid='B000JLHDOG', r_ui=5.0, est=4.100992349026771, details={'was_impossible': False}),
#  Prediction(uid='A1MZL91Z44RN06', iid='B00766BF1E', r_ui=4.0, est=4.412422122947137, details={'was_impossible': False}),
#  Prediction(uid='A9Y5O2R4D6EH5', iid='B00066EK40', r_ui=4.0, est=4.057271132682707, details={'was_impossible': False}),
#  Prediction(uid='A25HBO5V8S8SEA', iid='B0000X0VCE', r_ui=5.0, est=4.764846991439028, details={'was_impossible': False}),
#  Prediction(uid='A1MFAPVBW9BEGD', iid='B00568BV68', r_ui=5.0, est=3.6624851287130817, details={'was_impossible': False}),
#  Prediction(uid='A1987V5OCO6QHS', iid='B00AI46RZK', r_ui=3.0, est=3.324369250300082, details={'was_impossible': False}),
#  Prediction(uid='A2BYV7S1QP2YIG', iid='B00JF0D7RE', r_ui=5.0, est=4.742141275341885, details={'was_impossible': False}),
#  Prediction(uid='A1Y4EWMUTW73GD', iid='B001ISKNKU', r_ui=5.0, est=4.49132127150572, details={'was_impossible': False}),
#  Prediction(uid='A1HFT68GJ42LTM', iid='B005SN3I4O', r_ui=5.0, est=4.38361246686258, details={'was_impossible': False}),
#  Prediction(uid='A2V1J3JT5OOZFO', iid='B0064S7YQU', r_ui=5.0, est=4.248654378049507, details={'was_impossible': False}),
#  Prediction(uid='A506HOOCVL8GW', iid='B000I6QWP8', r_ui=5.0, est=4.502654917201306, details={'was_impossible': False}),
#  Prediction(uid='AW68KVDV7BBRS', iid='B002JCSV8U', r_ui=5.0, est=4.557273218101768, details={'was_impossible': False}),
#  Prediction(uid='A18FLOC8YQY0P8', iid='B004HYFX0C', r_ui=4.0, est=4.059785096063844, details={'was_impossible': False}),
#  Prediction(uid='A3R4794K2RVU1S', iid='B007PJ4Q4A', r_ui=5.0, est=4.62491719104654, details={'was_impossible': False}),
#  Prediction(uid='A2B7BUH8834Y6M', iid='B0025VKUQQ', r_ui=5.0, est=4.717656066648269, details={'was_impossible': False}),
#  Prediction(uid='AY6A8KPYCE6B0', iid='B0062XB9FE', r_ui=5.0, est=4.275946994764831, details={'was_impossible': False}),
#  Prediction(uid='AGXV8E7XK9J6H', iid='B00004WCIC', r_ui=4.0, est=4.2483349782607736, details={'was_impossible': False}),
#  Prediction(uid='A1X1CEGHTHMBL1', iid='B000NH7SZ0', r_ui=5.0, est=4.617878322415488, details={'was_impossible': False}),
#  Prediction(uid='A1CMD08Z49PGKQ', iid='B0053HZEAQ', r_ui=5.0, est=4.672375976815341, details={'was_impossible': False}),
#  Prediction(uid='AGOH8N902URMW', iid='B00HFAEBWG', r_ui=4.0, est=4.2117735456547525, details={'was_impossible': False}),
#  Prediction(uid='A2NOW4U7W3F7RI', iid='B0009RGLSE', r_ui=5.0, est=4.6783356924902, details={'was_impossible': False}),
#  Prediction(uid='A1KI7YHQEOS1RB', iid='B004GF8TIK', r_ui=5.0, est=4.781404227965646, details={'was_impossible': False}),
#  Prediction(uid='A1HFT68GJ42LTM', iid='B00DQZOD8Q', r_ui=4.0, est=4.025108383637042, details={'was_impossible': False}),
#  Prediction(uid='A6VPK7X53QNAQ', iid='B0015DNIKU', r_ui=4.0, est=3.9982459159764576, details={'was_impossible': False}),
#  Prediction(uid='AG0PM9IAHQ06C', iid='B006GJU33I', r_ui=5.0, est=4.40304391153743, details={'was_impossible': False}),
#  Prediction(uid='A2UKE7GIVC7XFW', iid='B00829TIA4', r_ui=5.0, est=4.388781702363448, details={'was_impossible': False}),
#  Prediction(uid='ATS2855497V0I', iid='B0063705PE', r_ui=5.0, est=3.8829053846796486, details={'was_impossible': False}),
#  Prediction(uid='ATS2855497V0I', iid='B00EZ9XG62', r_ui=4.0, est=3.8283475825098363, details={'was_impossible': False}),
#  Prediction(uid='APQQK1V695AUE', iid='B001QTXKF6', r_ui=3.0, est=4.54183180645119, details={'was_impossible': False}),
#  Prediction(uid='A1ZCSSCAGBCD49', iid='B00BDRSCKY', r_ui=4.0, est=3.9722929943780554, details={'was_impossible': False}),
#  Prediction(uid='A3GVXKCTFN3YDN', iid='B002P39DI0', r_ui=5.0, est=4.615831762512936, details={'was_impossible': False}),
#  Prediction(uid='A2UOHALGF2X77Q', iid='B006VJT1K4', r_ui=4.0, est=4.27099565159208, details={'was_impossible': False}),
#  Prediction(uid='A2I357I10ZY7CI', iid='B003ZX7VBU', r_ui=5.0, est=4.333375830998811, details={'was_impossible': False}),
#  Prediction(uid='A17HMM1M7T9PJ1', iid='B00109Y2DQ', r_ui=4.0, est=4.360622621149056, details={'was_impossible': False}),
#  Prediction(uid='A24J2Y1O22JYZX', iid='B0038KLM9W', r_ui=4.0, est=4.185141500873028, details={'was_impossible': False}),
#  Prediction(uid='A5GPH59NDWJRB', iid='B000KI81XK', r_ui=1.0, est=3.737825531239432, details={'was_impossible': False}),
#  Prediction(uid='ABVYGB2TKBO8F', iid='B002VH3FQG', r_ui=4.0, est=4.2999451572378025, details={'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00GVQL5J2', r_ui=4.0, est=4.509398767298361, details={'was_impossible': False}),
#  Prediction(uid='A2IFGGXG3YV3Y6', iid='B00DMS0GTC', r_ui=5.0, est=4.610973634519615, details={'was_impossible': False}),
#  Prediction(uid='AU3GYRAKBUAEU', iid='B004JK8BDK', r_ui=3.0, est=3.665984320747623, details={'was_impossible': False}),
#  Prediction(uid='A17UNMURMLX0ZE', iid='B00IORDBPC', r_ui=4.0, est=3.953257569953917, details={'was_impossible': False}),
#  Prediction(uid='A3F3B6HY9RJI04', iid='B00008VF63', r_ui=5.0, est=4.450730998728565, details={'was_impossible': False}),
#  Prediction(uid='AEL6CQNQXONBX', iid='B00JX1ZS5O', r_ui=5.0, est=4.596961021366077, details={'was_impossible': False}),
#  Prediction(uid='AGVWTYW0ULXHT', iid='B007MDQIH2', r_ui=4.0, est=3.9419674720321214, details={'was_impossible': False}),
#  Prediction(uid='AX05DBU8IRUWY', iid='B00BM9Q5N4', r_ui=5.0, est=4.138521669154527, details={'was_impossible': False}),
#  Prediction(uid='ANW6EGY12V5XS', iid='B003UGZ9UW', r_ui=3.0, est=4.072733774844827, details={'was_impossible': False}),
#  Prediction(uid='A3UKWQS8SRW6IO', iid='B00E7LSCNK', r_ui=5.0, est=4.753895926629543, details={'was_impossible': False}),
#  Prediction(uid='A3QRR8PSCBI07C', iid='B00AAKLE00', r_ui=4.0, est=4.323726181607487, details={'was_impossible': False}),
#  Prediction(uid='A17NVM7IAPF2NS', iid='B000TNZBFW', r_ui=5.0, est=4.357169334194815, details={'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0014H16OM', r_ui=5.0, est=4.215421920366331, details={'was_impossible': False}),
#  Prediction(uid='A3SOJO7Z7R9WIA', iid='B004H8FN76', r_ui=4.0, est=3.62464636344863, details={'was_impossible': False}),
#  Prediction(uid='A3D822N1K2IAQD', iid='B004CLYEI2', r_ui=4.0, est=4.321836606435438, details={'was_impossible': False}),
#  Prediction(uid='A3CJ7MHAS9IMAM', iid='B00009V3FL', r_ui=5.0, est=4.427110481991981, details={'was_impossible': False}),
#  Prediction(uid='A27AF4DLLOBQDQ', iid='B00E055H5O', r_ui=4.0, est=4.435016796720667, details={'was_impossible': False}),
#  Prediction(uid='A15QYHQH80W30L', iid='B0038JEBIM', r_ui=5.0, est=4.299157417027477, details={'was_impossible': False}),
#  Prediction(uid='AT6CZDCP4TRGA', iid='B000EO55TI', r_ui=5.0, est=4.034243992246733, details={'was_impossible': False}),
#  Prediction(uid='A2JXS1JII6SAUD', iid='B0057Q4ADU', r_ui=5.0, est=4.570982221921101, details={'was_impossible': False}),
#  Prediction(uid='A1NJHKPHD4YWZV', iid='B004LCGQOW', r_ui=5.0, est=4.108554095720368, details={'was_impossible': False}),
#  Prediction(uid='ALUNVOQRXOZIA', iid='B005KUH670', r_ui=5.0, est=3.751608442024784, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B00E08OEGY', r_ui=4.0, est=4.463932313594203, details={'was_impossible': False}),
#  Prediction(uid='A2AY4YUOX2N1BQ', iid='B007G5NNOW', r_ui=5.0, est=4.454052593354644, details={'was_impossible': False}),
#  Prediction(uid='A17V9XL4CWTQ6G', iid='B007UT2LB0', r_ui=5.0, est=4.682531833532472, details={'was_impossible': False}),
#  Prediction(uid='A2ZRMCRLDSUX6R', iid='B002KMIZIU', r_ui=5.0, est=4.5246368745924865, details={'was_impossible': False}),
#  Prediction(uid='A2WF58BAWLVI95', iid='B003MTTJOY', r_ui=5.0, est=3.8011437036955367, details={'was_impossible': False}),
#  Prediction(uid='APQQK1V695AUE', iid='B002ISV344', r_ui=5.0, est=4.609608049575299, details={'was_impossible': False}),
#  Prediction(uid='A35IX2GE0VC0JP', iid='B0002RRVQW', r_ui=2.0, est=3.513087951420738, details={'was_impossible': False}),
#  Prediction(uid='A17HMM1M7T9PJ1', iid='B00009XVBY', r_ui=5.0, est=4.253423619357975, details={'was_impossible': False}),
#  Prediction(uid='A2JMJVNTBL7K7E', iid='B002J9HBIO', r_ui=4.0, est=3.9965500294834695, details={'was_impossible': False}),
#  Prediction(uid='A20DZX38KRBIT8', iid='B000O656FE', r_ui=5.0, est=2.9418017783938137, details={'was_impossible': False}),
#  Prediction(uid='A3IUW081KXD3PE', iid='B00BP5KOPA', r_ui=5.0, est=4.532670053835705, details={'was_impossible': False}),
#  Prediction(uid='A15T9G38F589KM', iid='B001XUQP5A', r_ui=5.0, est=4.416476909408085, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B001WGX15W', r_ui=5.0, est=4.506754894316045, details={'was_impossible': False}),
#  Prediction(uid='A39K52QDP4C3ZS', iid='B003SX0RMW', r_ui=4.0, est=4.390469275859095, details={'was_impossible': False}),
#  Prediction(uid='A2FRKEXDXDN1KI', iid='B004GAHXVO', r_ui=3.0, est=4.287307103354834, details={'was_impossible': False}),
#  Prediction(uid='A24P4E3RJ6AX94', iid='B006Q4EK7S', r_ui=5.0, est=4.504984578633651, details={'was_impossible': False}),
# ...
#  Prediction(uid='A257X1MQJO82P2', iid='B008EC4O76', r_ui=5.0, est=4.807871915347381, details={'was_impossible': False}),
#  Prediction(uid='A209G57KXCBF4C', iid='B00K7Y3RCC', r_ui=4.0, est=3.930454240056074, details={'was_impossible': False}),
#  Prediction(uid='A2NYK9KWFMJV4Y', iid='B00K6ZAKCW', r_ui=4.0, est=4.611952315042458, details={'was_impossible': False}),
#  Prediction(uid='A2JKM8KF3296CW', iid='B00DQZQCUI', r_ui=5.0, est=4.166428098594471, details={'was_impossible': False}),
#  Prediction(uid='A1A306IAZ3TM1', iid='B00304DZ7I', r_ui=1.0, est=3.1721297352736992, details={'was_impossible': False}),
#  Prediction(uid='A2GYV87WW0DMSN', iid='B007PMJVS8', r_ui=5.0, est=4.451819715398172, details={'was_impossible': False}),
#  Prediction(uid='A2V1J3JT5OOZFO', iid='B0011Z2402', r_ui=5.0, est=4.383817522606758, details={'was_impossible': False}),
#  Prediction(uid='A1R377IPZOKLMM', iid='B000EWHEM6', r_ui=4.0, est=4.332952156963827, details={'was_impossible': False}),
#  Prediction(uid='AOMEH9W6LHC4S', iid='B005EJH6RW', r_ui=4.0, est=4.00155195942939, details={'was_impossible': False}),
#  Prediction(uid='A37IRE9GZ0CZ7I', iid='B005COF1BM', r_ui=5.0, est=4.284504916318102, details={'was_impossible': False}),
#  Prediction(uid='A2OKRGHIYTBQ6P', iid='B000I991LM', r_ui=5.0, est=4.476686280402849, details={'was_impossible': False}),
#  Prediction(uid='AKT8TGIT6VVZ5', iid='B00005LEOH', r_ui=5.0, est=4.756869444618722, details={'was_impossible': False}),
#  Prediction(uid='A39K52QDP4C3ZS', iid='B009IM6RWQ', r_ui=5.0, est=4.538784679125126, details={'was_impossible': False}),
#  Prediction(uid='AHQRU3MRORIWQ', iid='B001U5YZ4G', r_ui=3.0, est=4.160132497183358, details={'was_impossible': False}),
#  Prediction(uid='A18A5VSD0IPN14', iid='B000KH2M7C', r_ui=5.0, est=4.423091384489218, details={'was_impossible': False}),
#  Prediction(uid='A2MCRCK1V61FWQ', iid='B002NEFL8W', r_ui=5.0, est=4.647491565267791, details={'was_impossible': False}),
#  Prediction(uid='A3BACUOZV1M0WM', iid='B0006VY4KU', r_ui=4.0, est=4.301108200818461, details={'was_impossible': False}),
#  Prediction(uid='A3HXGSMCIOZEW8', iid='B00006HSML', r_ui=5.0, est=4.671063971206038, details={'was_impossible': False}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B00275XTSQ', r_ui=3.0, est=4.269786586300571, details={'was_impossible': False}),
#  Prediction(uid='A3HQAPXAJV7PRX', iid='B009LL9VDG', r_ui=5.0, est=4.371822412595721, details={'was_impossible': False}),
#  Prediction(uid='A3TNM3C9ENUCFW', iid='B000T9DHZW', r_ui=5.0, est=4.27529115281154, details={'was_impossible': False}),
#  Prediction(uid='A2AC6GQ24S45GA', iid='B000T8CWFE', r_ui=5.0, est=4.475437303082787, details={'was_impossible': False}),
#  Prediction(uid='AGOH8N902URMW', iid='B004C13VWC', r_ui=5.0, est=4.528963941844876, details={'was_impossible': False}),
#  Prediction(uid='A13WREJ05GMRA6', iid='B00IGHD876', r_ui=4.0, est=3.8631628619028304, details={'was_impossible': False}),
#  Prediction(uid='A36A1ZYZH8568P', iid='B00DDH4TYA', r_ui=5.0, est=4.357887087773092, details={'was_impossible': False}),
#  Prediction(uid='A3LGT6UZL99IW1', iid='B002BH3Z8E', r_ui=5.0, est=4.462896702292045, details={'was_impossible': False}),
#  Prediction(uid='A1D9V11QUHXENQ', iid='B005LSS1D4', r_ui=4.0, est=4.237770103861804, details={'was_impossible': False}),
#  Prediction(uid='A19UTUEBWKIZFT', iid='B00GGFP2DS', r_ui=4.0, est=4.509458034844202, details={'was_impossible': False}),
#  Prediction(uid='A2NN1KIYEM2SKS', iid='B00DR0PDNE', r_ui=3.0, est=3.6954966933161915, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B005IZ65G0', r_ui=3.0, est=4.203616132770693, details={'was_impossible': False}),
#  Prediction(uid='ACYZXQ2JKPZKT', iid='B0016P5ASK', r_ui=5.0, est=3.7832430597844984, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B007X3VEX4', r_ui=4.0, est=4.420604812537037, details={'was_impossible': False}),
#  Prediction(uid='A15XI2BEGGFEOW', iid='B00D78Q2AO', r_ui=5.0, est=4.298475765265896, details={'was_impossible': False}),
#  Prediction(uid='A3QMJMTLJC34QC', iid='B00005TQ08', r_ui=4.0, est=4.2761123314269405, details={'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B00HJ4GX10', r_ui=5.0, est=4.354822246990813, details={'was_impossible': False}),
#  Prediction(uid='A32482Z7XIKDQX', iid='B000Y138EK', r_ui=5.0, est=4.5800731936358625, details={'was_impossible': False}),
#  Prediction(uid='A1CM4HI4S5P0WO', iid='B001QTXKF6', r_ui=4.0, est=3.888347914212433, details={'was_impossible': False}),
#  Prediction(uid='A3TBMAWIIHKHFN', iid='B002K4E7TE', r_ui=5.0, est=3.774243460889996, details={'was_impossible': False}),
#  Prediction(uid='A2EW01G2LNJN06', iid='B001769L24', r_ui=5.0, est=4.503285019975213, details={'was_impossible': False}),
#  Prediction(uid='A250AXLRBVYKB4', iid='B001ISK6GG', r_ui=3.0, est=4.071972096294609, details={'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B00264NZWS', r_ui=4.0, est=4.198944673310285, details={'was_impossible': False}),
#  Prediction(uid='AK3GKIV8DEY8B', iid='B0019FJM7W', r_ui=5.0, est=4.645020486442257, details={'was_impossible': False}),
#  Prediction(uid='A3QNX5KWHDV0GD', iid='B001GIPMO4', r_ui=5.0, est=3.724019723842693, details={'was_impossible': False}),
#  Prediction(uid='A2L90SGUP36KGA', iid='B004ZCS2Z4', r_ui=4.0, est=4.05287204485443, details={'was_impossible': False}),
#  Prediction(uid='A2D1ZQEFS1NBH2', iid='B002C7481G', r_ui=5.0, est=4.252552399959561, details={'was_impossible': False}),
#  Prediction(uid='A2ED50E3KWKUKW', iid='B0015VW3BM', r_ui=5.0, est=4.766509010786188, details={'was_impossible': False}),
#  Prediction(uid='A3FPSY1M6G7XIB', iid='B000EMUGGW', r_ui=5.0, est=4.411602223223731, details={'was_impossible': False}),
#  Prediction(uid='A1A5KUIIIHFF4U', iid='B0035H4164', r_ui=5.0, est=4.088641793459875, details={'was_impossible': False}),
#  Prediction(uid='A3J2YU2D9BH2J7', iid='B0056VP0KS', r_ui=5.0, est=4.371924666766796, details={'was_impossible': False}),
#  Prediction(uid='A1ZXMMQPYC3Z9I', iid='B0038JECKY', r_ui=3.0, est=4.0280026033534195, details={'was_impossible': False}),
#  Prediction(uid='A197T2N6RU7K56', iid='B00160MV8W', r_ui=5.0, est=4.636291476208861, details={'was_impossible': False}),
#  Prediction(uid='A1GNYV0RA0EQSS', iid='B008MF3X9K', r_ui=5.0, est=4.323332321603271, details={'was_impossible': False}),
#  Prediction(uid='A3TA1UJWRJF9NC', iid='B000NDHIKY', r_ui=2.0, est=4.283408357652206, details={'was_impossible': False}),
#  Prediction(uid='A2ZRG5NOFZ47RK', iid='B0041NPZE8', r_ui=4.0, est=4.506478984131696, details={'was_impossible': False}),
#  Prediction(uid='AVTJEWTCJ3PBE', iid='B001LK8P14', r_ui=4.0, est=4.400011206387176, details={'was_impossible': False}),
#  Prediction(uid='A1A306IAZ3TM1', iid='B000ND75C0', r_ui=1.0, est=2.8380945672085716, details={'was_impossible': False}),
#  Prediction(uid='A3TAS1AG6FMBQW', iid='B0080EBMM8', r_ui=5.0, est=4.675730081495262, details={'was_impossible': False}),
#  Prediction(uid='A1MCH5RXDOH87H', iid='B000B75RDW', r_ui=4.0, est=3.822807183271784, details={'was_impossible': False}),
#  Prediction(uid='AAR7CEPXYJA0T', iid='B0009N544A', r_ui=2.0, est=3.807637435209691, details={'was_impossible': False}),
#  Prediction(uid='A3D0UM4ZD2CMAW', iid='B004GCIZ5A', r_ui=5.0, est=4.755600940323828, details={'was_impossible': False}),
#  Prediction(uid='A35IX2GE0VC0JP', iid='B002V88HFE', r_ui=4.0, est=4.1614768594602936, details={'was_impossible': False}),
#  Prediction(uid='A3775OP5VTX5ON', iid='B001GNC7RY', r_ui=4.0, est=3.8454191822051236, details={'was_impossible': False}),
#  Prediction(uid='A3R19YKNL641X3', iid='B000VRYLU2', r_ui=3.0, est=3.993413667490143, details={'was_impossible': False}),
#  Prediction(uid='AOEDWQLH2WKKW', iid='B000IHN89A', r_ui=5.0, est=4.189806865784101, details={'was_impossible': False}),
#  Prediction(uid='A2YEZ8Z3BW2SKG', iid='B00009R6TA', r_ui=3.0, est=4.579010981354035, details={'was_impossible': False}),
#  Prediction(uid='A1RL1OTV8IJMVD', iid='B008DWCRQW', r_ui=5.0, est=4.067206044390228, details={'was_impossible': False}),
#  Prediction(uid='A3E3EQ39FZTZEK', iid='B007PJ4Q4A', r_ui=4.0, est=3.818028498038041, details={'was_impossible': False}),
#  Prediction(uid='AMVXR3NPL0GWX', iid='B0019CSVMW', r_ui=4.0, est=4.435456634322008, details={'was_impossible': False}),
#  Prediction(uid='A1MCH5RXDOH87H', iid='B00622AG6S', r_ui=4.0, est=3.9403255800399033, details={'was_impossible': False}),
#  Prediction(uid='A3G5MOHY1U635N', iid='B000HDQ2G6', r_ui=5.0, est=4.142059800410111, details={'was_impossible': False}),
#  Prediction(uid='A1HBEQWSMVQEWJ', iid='B0046HJLJO', r_ui=1.0, est=3.7131383358593886, details={'was_impossible': False}),
#  Prediction(uid='AHF4I1FSIHABC', iid='B00013MSUQ', r_ui=5.0, est=4.615011181740374, details={'was_impossible': False}),
#  Prediction(uid='A16HXVNPU5TCGE', iid='B00DR0RBV6', r_ui=5.0, est=4.648870769505496, details={'was_impossible': False}),
#  Prediction(uid='A2HV76MYH7UL3S', iid='B0098WZW3Q', r_ui=5.0, est=4.550716875728107, details={'was_impossible': False}),
#  Prediction(uid='AKX9EQ37PAYMY', iid='B0012GK3MQ', r_ui=5.0, est=4.637373065723997, details={'was_impossible': False}),
#  Prediction(uid='ACHTDPEQYSEQL', iid='B00D429Y12', r_ui=4.0, est=4.243348710797963, details={'was_impossible': False}),
#  Prediction(uid='AMZCZBK1EF1PV', iid='B00005OMZM', r_ui=5.0, est=4.008771741090632, details={'was_impossible': False}),
#  Prediction(uid='A1CSRR7FCKBL9M', iid='B009USAJCC', r_ui=5.0, est=4.592169983603215, details={'was_impossible': False}),
#  Prediction(uid='A3KCETSIJNOK56', iid='B007IIT8KU', r_ui=1.0, est=3.869344143609669, details={'was_impossible': False}),
#  Prediction(uid='A3N4VTNFPMTHEF', iid='B005KG44V0', r_ui=4.0, est=4.176205290457476, details={'was_impossible': False}),
#  Prediction(uid='A3QNQQKJTL76H0', iid='B004GGWOSK', r_ui=4.0, est=4.179004147551913, details={'was_impossible': False}),
#  Prediction(uid='A7Y6AVS576M03', iid='B0001GYAA4', r_ui=4.0, est=4.5104780708578005, details={'was_impossible': False}),
#  Prediction(uid='A2YYHSORXIHZCS', iid='B000VE2RP6', r_ui=5.0, est=4.574217874952259, details={'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B0018P0S1M', r_ui=4.0, est=4.421913088112977, details={'was_impossible': False}),
#  Prediction(uid='AYOTEJ617O60K', iid='B007FUDKB4', r_ui=5.0, est=4.039954940017044, details={'was_impossible': False}),
#  Prediction(uid='A1KSNK256G46GX', iid='B001VO4MOY', r_ui=3.0, est=4.380214002606476, details={'was_impossible': False}),
#  Prediction(uid='A3V6QSTG2T9MIO', iid='B004G60APE', r_ui=5.0, est=4.207678588911078, details={'was_impossible': False}),
#  Prediction(uid='A2RW587355CMVA', iid='B004PA2B6C', r_ui=5.0, est=4.320432670655408, details={'was_impossible': False}),
#  Prediction(uid='A324X7RVDAV3FT', iid='B0002HMRL6', r_ui=4.0, est=4.305059178759237, details={'was_impossible': False}),
#  Prediction(uid='A200RY2ELZL2Q3', iid='B00CEB5QU2', r_ui=4.0, est=3.815442247785378, details={'was_impossible': False}),
#  Prediction(uid='A19RW25Q6206I3', iid='B00A0JUNYY', r_ui=5.0, est=4.240158334963108, details={'was_impossible': False}),
#  Prediction(uid='AB094YABX21WQ', iid='B0002E1RZQ', r_ui=5.0, est=4.482874579974874, details={'was_impossible': False}),
#  Prediction(uid='A1ATVMMJZP3Q4X', iid='B00007E7JU', r_ui=5.0, est=4.646329761875266, details={'was_impossible': False}),
#  Prediction(uid='AL9WKVMRI6GFB', iid='B00DQZRKY0', r_ui=4.0, est=4.061848796696618, details={'was_impossible': False}),
#  Prediction(uid='A3P1508PZ0UADD', iid='B0002Y5WZC', r_ui=5.0, est=4.16201488036357, details={'was_impossible': False}),
#  Prediction(uid='A2RTVGR9B1M600', iid='B0019M3FYQ', r_ui=5.0, est=4.295386089820094, details={'was_impossible': False}),
#  Prediction(uid='A2BYV7S1QP2YIG', iid='B00HNFPZF0', r_ui=5.0, est=4.654231622197852, details={'was_impossible': False}),
#  Prediction(uid='A3J6Q0Y0SKY7AR', iid='B001BEETV0', r_ui=5.0, est=4.44131709605211, details={'was_impossible': False}),
#  Prediction(uid='AOWF9T81XMX2S', iid='B001TH8OSI', r_ui=5.0, est=4.303915124766139, details={'was_impossible': False}),
#  Prediction(uid='A1X3DA7C61WZLQ', iid='B0000AZ67Z', r_ui=3.0, est=3.815768070494823, details={'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B004VS325W', r_ui=4.0, est=3.8989080435075474, details={'was_impossible': False}),
#  Prediction(uid='A1OH33MR6K4G5J', iid='B001MX5YWI', r_ui=5.0, est=4.227553020650748, details={'was_impossible': False}),
#  Prediction(uid='AELK0E5DK7LIZ', iid='B00007FS75', r_ui=5.0, est=4.409976806846881, details={'was_impossible': False}),
#  Prediction(uid='A2YHXGPCTENZY3', iid='B005CWJ76O', r_ui=1.0, est=2.7033232375304683, details={'was_impossible': False}),
#  Prediction(uid='A31N0XY2UTB25C', iid='B002WE4HE2', r_ui=5.0, est=4.79046606316295, details={'was_impossible': False}),
#  Prediction(uid='A1PM7HH4F77NEH', iid='B001KC579Q', r_ui=4.0, est=4.1564303724885425, details={'was_impossible': False}),
#  Prediction(uid='A1Y85GQ09Y95JL', iid='B001XURPR2', r_ui=5.0, est=3.7788379891165174, details={'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B00EHDTQQ0', r_ui=5.0, est=4.541796616214967, details={'was_impossible': False}),
#  Prediction(uid='A2BLFCOPSMBOZ9', iid='B003DZ1684', r_ui=5.0, est=4.245683187120294, details={'was_impossible': False}),
#  Prediction(uid='A6XDZ1MJ0B1A2', iid='B008RWRLUK', r_ui=4.0, est=3.489151939724293, details={'was_impossible': False}),
#  Prediction(uid='A1T7EHCMZ92TKC', iid='B004GUT1QO', r_ui=5.0, est=4.348351976385343, details={'was_impossible': False}),
#  Prediction(uid='AW63IRQWH10GF', iid='B00A9NE84C', r_ui=5.0, est=4.321550571953596, details={'was_impossible': False}),
#  Prediction(uid='A379DLIAF0MFM5', iid='B0045Y1IMQ', r_ui=5.0, est=4.3553427878898985, details={'was_impossible': False}),
#  Prediction(uid='A3D1TZH619NKHN', iid='B000M4PYKA', r_ui=5.0, est=3.884285181436544, details={'was_impossible': False}),
#  Prediction(uid='A26CPEEWB2WKRE', iid='B000JFJDAE', r_ui=5.0, est=4.212129169739786, details={'was_impossible': False}),
#  Prediction(uid='A3D0UM4ZD2CMAW', iid='B001E45XT4', r_ui=5.0, est=4.662772443779656, details={'was_impossible': False}),
#  Prediction(uid='A30KPB2ILF6K6J', iid='B00A9NE84C', r_ui=5.0, est=4.7178414325105935, details={'was_impossible': False}),
#  Prediction(uid='AAQ9NJ480N9W5', iid='B00004T70X', r_ui=5.0, est=4.49831429467628, details={'was_impossible': False}),
#  Prediction(uid='A1H4IVXNXWWBLV', iid='B007G5NNOW', r_ui=4.0, est=4.2381548943666045, details={'was_impossible': False}),
#  Prediction(uid='A1LYMYNURB9EWW', iid='B000IP0N0E', r_ui=4.0, est=3.954361957649135, details={'was_impossible': False}),
#  Prediction(uid='A2AY4YUOX2N1BQ', iid='B000RAGPI4', r_ui=5.0, est=4.478909727318401, details={'was_impossible': False}),
#  Prediction(uid='A3EXWV8FNSSFL6', iid='B003NVMEBQ', r_ui=3.0, est=4.27563252974053, details={'was_impossible': False}),
#  Prediction(uid='A203OCQQ12MAVT', iid='B00008VSL7', r_ui=4.0, est=4.402499312312988, details={'was_impossible': False}),
#  Prediction(uid='A24HWYHR28JJ7A', iid='B004RHPZTS', r_ui=5.0, est=4.4513424126300345, details={'was_impossible': False}),
#  Prediction(uid='A3CJOB7CHOSZUG', iid='B0046BGUVC', r_ui=5.0, est=4.466275074709459, details={'was_impossible': False}),
#  Prediction(uid='A1MZL91Z44RN06', iid='B0018O9JIG', r_ui=5.0, est=4.477500529055328, details={'was_impossible': False}),
#  Prediction(uid='A2FXBWR4T4OFQ', iid='B0026ZPFCK', r_ui=3.0, est=4.515234854827368, details={'was_impossible': False}),
#  Prediction(uid='AUITG1DJ3QUGK', iid='B005FVNGRI', r_ui=5.0, est=4.192323983018294, details={'was_impossible': False}),
#  Prediction(uid='A3LDLV1GWQJLEQ', iid='B007FPIQX6', r_ui=5.0, est=4.472334999458129, details={'was_impossible': False}),
#  Prediction(uid='A2NSMJVQY0RV9S', iid='B00009R87T', r_ui=5.0, est=4.4282819871020465, details={'was_impossible': False}),
#  Prediction(uid='A57Q87B0TC9IJ', iid='B00004SDFJ', r_ui=4.0, est=3.6289305993101584, details={'was_impossible': False}),
#  Prediction(uid='AQNSQW4495SG0', iid='B005HY4U46', r_ui=5.0, est=4.498860616042757, details={'was_impossible': False}),
#  ...]

# %%
from collections import defaultdict
def get_top_n(predictions,n=10):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
# Genrating top 5 recommendation for user 
top_n = get_top_n(predictions, n= 5)

# %%
# Print the recommended items for each user
user_list= []
for uid, user_ratings in top_n.items():
    single_user= (uid, [iid for (iid, _) in user_ratings])
    user_list.append(single_user)

# %%
recommendation_for_user = pd.DataFrame(user_list,columns=['userid','recommended electronics_id'])

# %%
# all recommendations for user
recommendation_for_user
# Out:
#               userid                         recommended electronics_id
# 0     A3VONQL7YW8UPM  [B001TH7GUA, B008EQYRRY, B008LCYIEI, B007SM7O2...
# 1     A1MRRMHGV3PN5W  [B002JCSV8A, B00DEQLDDU, B003HIXOOG, B003HIXP9...
# 2     A3F3B1JPACN215  [B003LVZO8S, B00829THEG, B001L1H0SC, B002NU5UW...
# 3     A38KK0SZYEH5UD  [B0019EHU8G, B000VDCT3C, B00429N18S, B005DIQ2O...
# 4     A2LFWJ8X817QGX  [B001QUA6RA, B002WE4HE2, B009NHAF5G, B008TCUXL...
# ...              ...                                                ...
# 1461  A1Z3598J0371ND  [B0019EHU8G, B008R6OPJQ, B008EO263I, B000I21Z4...
# 1462  A2RG1B0K8YBJ4A  [B00E3RH5W2, B002WE4HE2, B000UIA6YM, B006ODM76...
# 1463  A1AKW788238PWQ  [B0002BEQNE, B0069SGO48, B00139VKUG, B00474YRE...
# 1464  A3FS3FJPD3RJTD  [B004CLYE8C, B001VZ1W5U, B00B2G3R5G, B005X64MN...
# 1465   AY3D7DG5L5WCK  [B00FJWKYYG, B00IAV4S1I, B008ULPAT2, B00B2HCLL...
#
# [1466 rows x 2 columns]

# %%
def rec_5 (user_id):
    return recommendation_for_user[recommendation_for_user['userid']== user_id]['recommended electronics_id'].tolist()

# %%
user_id = 'A1NMM0RDRF6R84'

# %%
rec_5(user_id)
# Out:
# [['B0040JHVC2', 'B006MWJHZO', 'B00F6S0XGW', 'B001TIXH0C', 'B00166RWTE']]

# %% [markdown]
# >- Get top - K ( K = 5) recommendations. Since our goal is to recommend new products to each user based on his/her habits, we will recommend 5 new products

# %%
# Getting all the products rated by given user 
product_id_check = df_50_greater[df_50_greater['userid']== 'A1NMM0RDRF6R84']

# %%
# checking the recommended product exist in user rating history or not  
product_id_check[product_id_check['productid']== 'B000HZ9CCA' ]
# Out:
#                  userid   productid  rating
# 1015882  A1NMM0RDRF6R84  B000HZ9CCA     3.0

# %% [markdown]
# >- It is observed that we are not able to recommendan any new electronic product

# %%
#recommendation_for_user['recommended electronics_id']

# %%
reco_list= ['B000QUUFRW', 'B0040JHVC2', 'B00007IFED', 'B004WB8EYM', 'B002J9HBIO']

# %%
set(reco_list) - set(product_id_check['productid'])
# Out:
# set()

# %% [markdown]
# >- As we can observe that set is empty which gives us clear idea that no new electronic items were recommended new

# %%
## Creating Dataframe from predictions to fetch new products
def get_Iu(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
df_pred = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
df_pred['Iu'] = df_pred.uid.apply(get_Iu)
df_pred['Ui'] = df_pred.iid.apply(get_Ui)
df_pred['err'] = abs(df_pred.est - df_pred.rui)
best_predictions = df_pred.sort_values(by='err')[:]
#worst_predictions = df_pred.sort_values(by='err')[-10:]

# %%
best_predictions
# Out:
#                   uid         iid  rui       est                    details  \
# 31870  A1MFPAM9TTRTXN  B003ES5ZUU  5.0  5.000000  {'was_impossible': False}
# 22381  A1MFPAM9TTRTXN  B0046TJG1U  5.0  5.000000  {'was_impossible': False}
# 32159  A2NOW4U7W3F7RI  B00017LSPI  5.0  5.000000  {'was_impossible': False}
# 5906   A10O7THJ2O20AG  B00E3W15P0  5.0  5.000000  {'was_impossible': False}
# 29673  A1CMD08Z49PGKQ  B003ES5ZUU  5.0  5.000000  {'was_impossible': False}
# ...               ...         ...  ...       ...                        ...
# 9910   A3L9E0YI7C5G0W  B000QUUFRW  1.0  4.598145  {'was_impossible': False}
# 34545   AVPNQUVZWMDSX  B007WTAJTO  1.0  4.607130  {'was_impossible': False}
# 12302   A9BWUH9XKZ2DQ  B00006RVPW  1.0  4.661165  {'was_impossible': False}
# 21628  A1BZIM4WGZ6DZP  B0035ERKYW  1.0  4.679666  {'was_impossible': False}
# 13213  A17W0GMB0YY83M  B00834SJSK  1.0  4.785886  {'was_impossible': False}
#
#         Iu   Ui       err
# 31870   43  113  0.000000
# 22381   43   13  0.000000
# 32159  199   31  0.000000
# 5906    53   32  0.000000
# 29673  152  113  0.000000
# ...    ...  ...       ...
# 9910    86   62  3.598145
# 34545  145  108  3.607130
# 12302   32   19  3.661165
# 21628   32   10  3.679666
# 13213   55   78  3.785886
#
# [36652 rows x 8 columns]

# %%
#oo = best_predictions[best_predictions['uid'] == 'A32JCI4AK2JTTG']['iid']

# %%
#pp = best_predictions['iid']

# %%
#sq =pd.DataFrame(list(set(pp) - set(oo)),columns= ['prod_id'])

# %%
#sq

# %%
#ask = best_predictions[best_predictions['iid'].isin(sq['prod_id'])]

# %%
#ask['est'].sort_values(ascending = False)

# %%
#reco =(( ask.sort_values('est',na_position='first',ascending=False))[['iid','est']]).iloc[:5]

# %%
#reco = ask[['iid','est']]
#reco.iloc[:5]

# %%
def  recomendation (uid):
    # Finding those product which are not rated by user
    not_rated_items_byUser =pd.DataFrame(list(set(best_predictions['iid']) - 
                                              set(best_predictions[best_predictions['uid'] == uid]['iid']))
                                              ,columns= ['prod_id'])
    # creating New dataframe which consist of only those electronic item which are not rated by user
    Items_to_be_recommended_from = best_predictions[best_predictions['iid'].isin(not_rated_items_byUser['prod_id'])]
    # sorting electronic product in ascending order and slecting top 5 products as a recomendation to a perticular user
    top_5_recommendation = ((Items_to_be_recommended_from.sort_values('est',na_position='first'
                                                                      ,ascending=False))[['iid','est']]).iloc[:5]
    return top_5_recommendation

# %%
# Recommendation for a given user 
recomendation('A3CKI6VEH0HBMJ')
# Out:
#               iid  est
# 31870  B003ES5ZUU  5.0
# 4101   B001TH7GSW  5.0
# 33977  B000OGX5AM  5.0
# 3362   B0002LEMWE  5.0
# 15678  B006W8U2MU  5.0
